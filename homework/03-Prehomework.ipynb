# %% [markdown]
# Iowa
# ----
#
# <img src="https://github.com/computationaljournalism/columbia2020/blob/master/images/live.jpeg?raw=true" width=500>
#
# For homework, we are going to look at Iowa a little more closely (since the IDP was unable to pull it together Monday night). The New York Times has made a kind of dashboard for the Democatic primaries that you can examine [here](https://www.nytimes.com/interactive/2020/02/04/us/elections/results-iowa-caucus.html). As you scroll around, you see computation everywhere. From predictions (the dreaded needle) to maps of "live" results.
#
# Last time we wanted to find data from Iowa as it came in, and then perhaps repeat this process for the other primaries, looking county-by-county. First off, the page that the New York Times uses to show its results is continually updating. I mean every 10 seconds, not that the IDP is acting that quickly. How is the data being communicated?
#
# Let's look!
#
# Now that we've found the data source, we can pull the data into our notebook using the `requests` library. `requests` lets you, through Python, make the same kinds of file access as you can in your browser. We'll have A LOT to say about pulling data from the web, but for now `requests` will let you grap a file given its URL. Here's how easy it is.

# %%
from pprint import pprint
from requests import get

url = 'https://int.nyt.com/applications/elections/2020/data/api/2020-02-03/iowa/president/democrat.json'
response = get(url)

type(response)
# Out:
# requests.models.Response

# %% [markdown]
# the object that `get()` returns is a `Response`. It contains methosd and data, like any object. One type of data that's handy is a JSON object (JSON stands for JavaScript Object Notation) that, as we have seen, is essentially assembled from dictionaries and lists and other built-in types. The object is accessed with the call `.json()`.

# %%
demo = response.json()
type(demo)
# Out:
# dict

# %% [markdown]
# A dictionary! How do we see what's there?

# %%
demo.keys()
# Out:
# dict_keys(['data', 'meta'])

# %% [markdown]
# And let's dig in. We can look for the `.keys()` of this dictionary...

# %%
demo['data'].keys()
# Out:
# dict_keys(['races', 'liveUpdates', 'scoreboard'])

# %% [markdown]
# ... and see what's under `races`.

# %%
demo['data']['races']
# Out:
# [{'race_id': 'ia-17275-2020-02-03',
#   'race_slug': 'ia-president-caucus-democrat-2020-02-03',
#   'url': 'https://www.nytimes.com/interactive/2020/02/04/us/elections/results-iowa-caucus.html',
#   'race_type': 'president',
#   'election_type': 'caucus',
#   'election_date': '2020-02-03',
#   'runoff': False,
#   'race_name': 'President',
#   'office': 'President',
#   'officeid': 'P',
#   'race_call_note': '',
#   'race_text': '',
#   'nyt_measure_title': '',
#   'nyt_title': '',
#   'seat': '',
#   'seat_name': '',
#   'state_id': 'IA',
#   'state_slug': 'iowa',
#   'state_name': 'Iowa',
#   'state_nyt_abbrev': 'Iowa',
#   'party_id': 'democrat',
#   'uncontested': False,
#   'report': True,
#   'result': '',
#   'result_source': None,
#   'gain': False,
#   'lost_seat': '',
#   'votes': 1920,
#   'electoral_votes': 0,
#   'poll_display': 'First results expected after 5 p.m., Eastern time.',
#   'poll_countdown_display': 'Iowa caucuses start in',
#   'poll_time': '2020-02-04T01:00:00.000Z',
#   'precincts_reporting': 1520,
#   'precincts_total': 1765,
#   'reporting_display': '86% reporting',
#   'eevp': 83,
#   'incumbent_party': '',
#   'no_forecast': False,
#   'candidates': [{'candidate_id': 'buttigieg-67933',
#     'candidate_key': 'buttigiegp',
#     'first_name': 'Pete',
#     'last_name': 'Buttigieg',
#     'order': 4,
#     'name_display': 'Pete Buttigieg',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 512,
#     'percent': 26.7,
#     'percent_display': '26.7',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/pete-buttigieg.html',
#     'pronoun': 'he',
#     'votes_align1': 33687,
#     'percent_align1': 21.6,
#     'percent_display_align1': '21.6',
#     'winner_align1': False,
#     'votes_alignfinal': 39006,
#     'percent_alignfinal': 25.5,
#     'percent_display_alignfinal': '25.5',
#     'winner_alignfinal': False,
#     'delegates': 11},
#    {'candidate_id': 'sanders-1445',
#     'candidate_key': 'sandersb',
#     'first_name': 'Bernie',
#     'last_name': 'Sanders',
#     'order': 2,
#     'name_display': 'Bernie Sanders',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 488,
#     'percent': 25.4,
#     'percent_display': '25.4',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/bernie-sanders.html',
#     'pronoun': 'he',
#     'votes_align1': 37989,
#     'percent_align1': 24.3,
#     'percent_display_align1': '24.3',
#     'winner_align1': False,
#     'votes_alignfinal': 39954,
#     'percent_alignfinal': 26.1,
#     'percent_display_alignfinal': '26.1',
#     'winner_alignfinal': False,
#     'delegates': 11},
#    {'candidate_id': 'warren-62244',
#     'candidate_key': 'warrene',
#     'first_name': 'Elizabeth',
#     'last_name': 'Warren',
#     'order': 3,
#     'name_display': 'Elizabeth Warren',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 352,
#     'percent': 18.3,
#     'percent_display': '18.3',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/elizabeth-warren.html',
#     'pronoun': 'she',
#     'votes_align1': 29135,
#     'percent_align1': 18.6,
#     'percent_display_align1': '18.6',
#     'winner_align1': False,
#     'votes_alignfinal': 31264,
#     'percent_alignfinal': 20.4,
#     'percent_display_alignfinal': '20.4',
#     'winner_alignfinal': False,
#     'delegates': 5},
#    {'candidate_id': 'biden-1036',
#     'candidate_key': 'bidenj',
#     'first_name': 'Joseph R.',
#     'last_name': 'Biden',
#     'order': 1,
#     'name_display': 'Joseph R. Biden Jr.',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 306,
#     'percent': 15.9,
#     'percent_display': '15.9',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/joe-biden.html',
#     'pronoun': 'he',
#     'votes_align1': 23327,
#     'percent_align1': 14.9,
#     'percent_display_align1': '14.9',
#     'winner_align1': False,
#     'votes_alignfinal': 20992,
#     'percent_alignfinal': 13.7,
#     'percent_display_alignfinal': '13.7',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'klobuchar-51526',
#     'candidate_key': 'klobuchara',
#     'first_name': 'Amy',
#     'last_name': 'Klobuchar',
#     'order': 6,
#     'name_display': 'Amy Klobuchar',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 232,
#     'percent': 12.1,
#     'percent_display': '12.1',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/amy-klobuchar.html',
#     'pronoun': 'she',
#     'votes_align1': 19743,
#     'percent_align1': 12.6,
#     'percent_display_align1': '12.6',
#     'winner_align1': False,
#     'votes_alignfinal': 18251,
#     'percent_alignfinal': 11.9,
#     'percent_display_alignfinal': '11.9',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'yang-67936',
#     'candidate_key': 'yanga',
#     'first_name': 'Andrew',
#     'last_name': 'Yang',
#     'order': 7,
#     'name_display': 'Andrew Yang',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 19,
#     'percent': 1,
#     'percent_display': '1.0',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/andrew-yang.html',
#     'pronoun': 'he',
#     'votes_align1': 7907,
#     'percent_align1': 5.1,
#     'percent_display_align1': '5.1',
#     'winner_align1': False,
#     'votes_alignfinal': 1547,
#     'percent_alignfinal': 1,
#     'percent_display_alignfinal': '1.0',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'steyer-67935',
#     'candidate_key': 'steyert',
#     'first_name': 'Tom',
#     'last_name': 'Steyer',
#     'order': 8,
#     'name_display': 'Tom Steyer',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 6,
#     'percent': 0.3,
#     'percent_display': '0.3',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/tom-steyer.html',
#     'pronoun': 'he',
#     'votes_align1': 2761,
#     'percent_align1': 1.8,
#     'percent_display_align1': '1.8',
#     'winner_align1': False,
#     'votes_alignfinal': 368,
#     'percent_alignfinal': 0.2,
#     'percent_display_alignfinal': '0.2',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'bloomberg-32324',
#     'candidate_key': 'bloombergm',
#     'first_name': 'Michael',
#     'last_name': 'Bloomberg',
#     'order': 5,
#     'name_display': 'Michael Bloomberg',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 0,
#     'percent': 0,
#     'percent_display': '0.0',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/michael-bloomberg.html',
#     'pronoun': 'he',
#     'votes_align1': 178,
#     'percent_align1': 0.1,
#     'percent_display_align1': '0.1',
#     'winner_align1': False,
#     'votes_alignfinal': 10,
#     'percent_alignfinal': 0,
#     'percent_display_alignfinal': '0.0',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'gabbard-62589',
#     'candidate_key': 'gabbardt',
#     'first_name': 'Tulsi',
#     'last_name': 'Gabbard',
#     'order': 9,
#     'name_display': 'Tulsi Gabbard',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 0,
#     'percent': 0,
#     'percent_display': '0.0',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/tulsi-gabbard.html',
#     'pronoun': 'she',
#     'votes_align1': 305,
#     'percent_align1': 0.2,
#     'percent_display_align1': '0.2',
#     'winner_align1': False,
#     'votes_alignfinal': 15,
#     'percent_alignfinal': 0,
#     'percent_display_alignfinal': '0.0',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'patrick-51516',
#     'candidate_key': 'patrickd',
#     'first_name': 'Deval',
#     'last_name': 'Patrick',
#     'order': 11,
#     'name_display': 'Deval Patrick',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 0,
#     'percent': 0,
#     'percent_display': '0.0',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/deval-patrick.html',
#     'pronoun': 'he',
#     'votes_align1': 48,
#     'percent_align1': 0,
#     'percent_display_align1': '0.0',
#     'winner_align1': False,
#     'votes_alignfinal': 0,
#     'percent_alignfinal': 0,
#     'percent_display_alignfinal': '0.0',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'bennet-59911',
#     'candidate_key': 'bennetm',
#     'first_name': 'Michael',
#     'last_name': 'Bennet',
#     'order': 10,
#     'name_display': 'Michael Bennet',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 0,
#     'percent': 0,
#     'percent_display': '0.0',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/michael-bennet.html',
#     'pronoun': 'he',
#     'votes_align1': 129,
#     'percent_align1': 0.1,
#     'percent_display_align1': '0.1',
#     'winner_align1': False,
#     'votes_alignfinal': 1,
#     'percent_alignfinal': 0,
#     'percent_display_alignfinal': '0.0',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'delaney-61562',
#     'candidate_key': 'delaneyj',
#     'first_name': 'John',
#     'last_name': 'Delaney',
#     'order': 12,
#     'name_display': 'John Delaney',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 0,
#     'percent': 0,
#     'percent_display': '0.0',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/john-delaney.html',
#     'pronoun': 'he',
#     'votes_align1': 9,
#     'percent_align1': 0,
#     'percent_display_align1': '0.0',
#     'winner_align1': False,
#     'votes_alignfinal': 0,
#     'percent_alignfinal': 0,
#     'percent_display_alignfinal': '0.0',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'uncommitted-100004',
#     'candidate_key': 'uncommitted',
#     'last_name': 'Uncommitted',
#     'order': 13,
#     'name_display': 'Uncommitted',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 4,
#     'percent': 0.2,
#     'percent_display': '0.2',
#     'electoral_votes': 0,
#     'has_image': False,
#     'link': '',
#     'votes_align1': 871,
#     'percent_align1': 0.6,
#     'percent_display_align1': '0.6',
#     'winner_align1': False,
#     'votes_alignfinal': 1326,
#     'percent_alignfinal': 0.9,
#     'percent_display_alignfinal': '0.9',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'other-100007',
#     'candidate_key': 'other',
#     'last_name': 'Other',
#     'order': 14,
#     'name_display': 'Other',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 1,
#     'percent': 0.1,
#     'percent_display': '0.1',
#     'electoral_votes': 0,
#     'has_image': False,
#     'link': '',
#     'votes_align1': 144,
#     'percent_align1': 0.1,
#     'percent_display_align1': '0.1',
#     'winner_align1': False,
#     'votes_alignfinal': 165,
#     'percent_alignfinal': 0.1,
#     'percent_display_alignfinal': '0.1',
#     'winner_alignfinal': False,
#     'delegates': 0}],
#   'has_incumbent': False,
#   'counties': [{'fips': '19153',
#     'name': 'Polk',
#     'votes': 352.5499999999999,
#     'reporting': 159,
#     'precincts': 177,
#     'results': {'sandersb': 98.21,
#      'buttigiegp': 90.94,
#      'warrene': 74.71,
#      'bidenj': 51.48,
#      'klobuchara': 35.53,
#      'steyert': 0.28,
#      'yanga': 0.28,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 0.84,
#      'other': 0.28},
#     'votes_align1': 33660,
#     'results_align1': {'sandersb': 8420,
#      'buttigiegp': 7236,
#      'warrene': 6602,
#      'bidenj': 4739,
#      'klobuchara': 4065,
#      'yanga': 1598,
#      'steyert': 635,
#      'gabbardt': 66,
#      'bloombergm': 40,
#      'bennetm': 39,
#      'delaneyj': 9,
#      'patrickd': 1,
#      'uncommitted': 155,
#      'other': 55},
#     'votes_alignfinal': 33374,
#     'results_alignfinal': {'sandersb': 9031,
#      'buttigiegp': 8858,
#      'warrene': 7433,
#      'bidenj': 4400,
#      'klobuchara': 3353,
#      'yanga': 23,
#      'steyert': 14,
#      'gabbardt': 4,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 168,
#      'other': 90}},
#    {'fips': '19113',
#     'name': 'Linn',
#     'votes': 180.65,
#     'reporting': 83,
#     'precincts': 86,
#     'results': {'sandersb': 50.55,
#      'buttigiegp': 44.83,
#      'warrene': 38.24,
#      'bidenj': 27.25,
#      'klobuchara': 19.34,
#      'yanga': 0.44,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 14511,
#     'results_align1': {'sandersb': 3699,
#      'buttigiegp': 2872,
#      'warrene': 2812,
#      'bidenj': 2275,
#      'klobuchara': 1905,
#      'yanga': 602,
#      'steyert': 187,
#      'gabbardt': 31,
#      'bloombergm': 14,
#      'bennetm': 12,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 85,
#      'other': 17},
#     'votes_alignfinal': 14188,
#     'results_alignfinal': {'sandersb': 3825,
#      'buttigiegp': 3375,
#      'warrene': 3036,
#      'bidenj': 2129,
#      'klobuchara': 1639,
#      'yanga': 29,
#      'steyert': 4,
#      'bennetm': 1,
#      'gabbardt': 1,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 118,
#      'other': 31}},
#    {'fips': '19103',
#     'name': 'Johnson',
#     'votes': 156.74999999999997,
#     'reporting': 55,
#     'precincts': 57,
#     'results': {'warrene': 50.63,
#      'sandersb': 50.22,
#      'buttigiegp': 33.62,
#      'klobuchara': 16.61,
#      'bidenj': 5.67,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 20292,
#     'results_align1': {'sandersb': 5936,
#      'warrene': 5547,
#      'buttigiegp': 3365,
#      'klobuchara': 2172,
#      'bidenj': 1748,
#      'yanga': 1217,
#      'steyert': 176,
#      'gabbardt': 35,
#      'bennetm': 16,
#      'bloombergm': 5,
#      'patrickd': 3,
#      'delaneyj': 0,
#      'uncommitted': 57,
#      'other': 15},
#     'votes_alignfinal': 19083,
#     'results_alignfinal': {'warrene': 6361,
#      'sandersb': 6216,
#      'buttigiegp': 3718,
#      'klobuchara': 1954,
#      'bidenj': 604,
#      'yanga': 22,
#      'steyert': 7,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 199,
#      'other': 2}},
#    {'fips': '19163',
#     'name': 'Scott',
#     'votes': 99.61,
#     'reporting': 50,
#     'precincts': 63,
#     'results': {'sandersb': 26.45,
#      'buttigiegp': 25.63,
#      'bidenj': 16.95,
#      'warrene': 16.95,
#      'klobuchara': 12.81,
#      'yanga': 0.41,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0,
#      'other': 0.41},
#     'votes_align1': 7022,
#     'results_align1': {'sandersb': 1659,
#      'buttigiegp': 1481,
#      'warrene': 1190,
#      'bidenj': 1159,
#      'klobuchara': 975,
#      'yanga': 365,
#      'steyert': 126,
#      'bloombergm': 7,
#      'bennetm': 6,
#      'gabbardt': 1,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 51,
#      'other': 2},
#     'votes_alignfinal': 6882,
#     'results_alignfinal': {'buttigiegp': 1849,
#      'sandersb': 1750,
#      'warrene': 1169,
#      'bidenj': 1097,
#      'klobuchara': 904,
#      'yanga': 86,
#      'steyert': 6,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 17,
#      'other': 4}},
#    {'fips': '19013',
#     'name': 'Black Hawk',
#     'votes': 97.37,
#     'reporting': 59,
#     'precincts': 62,
#     'results': {'sandersb': 30.7,
#      'buttigiegp': 21.61,
#      'bidenj': 16.97,
#      'warrene': 16.77,
#      'klobuchara': 9.7,
#      'steyert': 0.81,
#      'yanga': 0.81,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 6921,
#     'results_align1': {'sandersb': 1935,
#      'buttigiegp': 1390,
#      'warrene': 1218,
#      'bidenj': 1012,
#      'klobuchara': 805,
#      'yanga': 310,
#      'steyert': 193,
#      'gabbardt': 22,
#      'bloombergm': 5,
#      'bennetm': 2,
#      'patrickd': 1,
#      'delaneyj': 0,
#      'uncommitted': 25,
#      'other': 3},
#     'votes_alignfinal': 6778,
#     'results_alignfinal': {'sandersb': 2125,
#      'buttigiegp': 1588,
#      'warrene': 1235,
#      'bidenj': 980,
#      'klobuchara': 748,
#      'steyert': 43,
#      'yanga': 43,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 14,
#      'other': 2}},
#    {'fips': '19169',
#     'name': 'Story',
#     'votes': 64.35,
#     'reporting': 33,
#     'precincts': 43,
#     'results': {'sandersb': 20.34,
#      'warrene': 16.6,
#      'klobuchara': 12.04,
#      'buttigiegp': 11.62,
#      'bidenj': 2.08,
#      'yanga': 1.25,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0.42,
#      'other': 0},
#     'votes_align1': 7661,
#     'results_align1': {'sandersb': 2400,
#      'warrene': 1600,
#      'buttigiegp': 1129,
#      'klobuchara': 1050,
#      'bidenj': 675,
#      'yanga': 634,
#      'steyert': 110,
#      'gabbardt': 12,
#      'bennetm': 4,
#      'bloombergm': 3,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 40,
#      'other': 4},
#     'votes_alignfinal': 7374,
#     'results_alignfinal': {'sandersb': 2648,
#      'warrene': 1874,
#      'klobuchara': 1208,
#      'buttigiegp': 1062,
#      'bidenj': 228,
#      'yanga': 173,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 181,
#      'other': 0}},
#    {'fips': '19049',
#     'name': 'Dallas',
#     'votes': 58.01,
#     'reporting': 34,
#     'precincts': 34,
#     'results': {'buttigiegp': 19.89,
#      'bidenj': 11.6,
#      'warrene': 11.19,
#      'sandersb': 8.29,
#      'klobuchara': 7.04,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 5804,
#     'results_align1': {'buttigiegp': 1639,
#      'bidenj': 1061,
#      'warrene': 1041,
#      'sandersb': 913,
#      'klobuchara': 759,
#      'yanga': 289,
#      'steyert': 60,
#      'bloombergm': 6,
#      'bennetm': 4,
#      'gabbardt': 2,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 23,
#      'other': 7},
#     'votes_alignfinal': 5728,
#     'results_alignfinal': {'buttigiegp': 1926,
#      'warrene': 1159,
#      'bidenj': 1085,
#      'sandersb': 840,
#      'klobuchara': 655,
#      'yanga': 48,
#      'steyert': 4,
#      'bloombergm': 1,
#      'bennetm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 10,
#      'other': 0}},
#    {'fips': '19061',
#     'name': 'Dubuque',
#     'votes': 53.07,
#     'reporting': 26,
#     'precincts': 35,
#     'results': {'buttigiegp': 15.47,
#      'bidenj': 12,
#      'sandersb': 12,
#      'warrene': 9.33,
#      'klobuchara': 4,
#      'yanga': 0.27,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 3758,
#     'results_align1': {'buttigiegp': 887,
#      'sandersb': 841,
#      'bidenj': 773,
#      'warrene': 604,
#      'klobuchara': 413,
#      'yanga': 159,
#      'steyert': 39,
#      'gabbardt': 16,
#      'bloombergm': 4,
#      'bennetm': 1,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 17,
#      'other': 4},
#     'votes_alignfinal': 3685,
#     'results_alignfinal': {'buttigiegp': 1023,
#      'sandersb': 832,
#      'bidenj': 826,
#      'warrene': 662,
#      'klobuchara': 283,
#      'yanga': 27,
#      'gabbardt': 1,
#      'steyert': 1,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 24,
#      'other': 6}},
#    {'fips': '19155',
#     'name': 'Pottawattamie',
#     'votes': 43.440000000000005,
#     'reporting': 35,
#     'precincts': 40,
#     'results': {'sandersb': 11.88,
#      'buttigiegp': 10.56,
#      'warrene': 8.04,
#      'bidenj': 5.88,
#      'klobuchara': 4.92,
#      'yanga': 1.92,
#      'steyert': 0.24,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 2790,
#     'results_align1': {'sandersb': 676,
#      'buttigiegp': 563,
#      'warrene': 467,
#      'bidenj': 443,
#      'klobuchara': 381,
#      'yanga': 172,
#      'steyert': 45,
#      'bloombergm': 25,
#      'gabbardt': 4,
#      'patrickd': 1,
#      'bennetm': 0,
#      'delaneyj': 0,
#      'uncommitted': 10,
#      'other': 3},
#     'votes_alignfinal': 2753,
#     'results_alignfinal': {'sandersb': 729,
#      'buttigiegp': 690,
#      'warrene': 471,
#      'bidenj': 352,
#      'klobuchara': 350,
#      'yanga': 114,
#      'steyert': 16,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 30,
#      'other': 1}},
#    {'fips': '19193',
#     'name': 'Woodbury',
#     'votes': 38.26,
#     'reporting': 33,
#     'precincts': 44,
#     'results': {'sandersb': 12.33,
#      'bidenj': 8.93,
#      'buttigiegp': 8.29,
#      'warrene': 6.16,
#      'klobuchara': 1.7,
#      'yanga': 0.64,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0.21,
#      'other': 0},
#     'votes_align1': 2354,
#     'results_align1': {'sandersb': 684,
#      'bidenj': 489,
#      'buttigiegp': 430,
#      'warrene': 342,
#      'klobuchara': 225,
#      'yanga': 127,
#      'steyert': 45,
#      'gabbardt': 3,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 8,
#      'other': 1},
#     'votes_alignfinal': 2294,
#     'results_alignfinal': {'sandersb': 705,
#      'bidenj': 542,
#      'buttigiegp': 495,
#      'warrene': 341,
#      'klobuchara': 124,
#      'yanga': 40,
#      'steyert': 4,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 39,
#      'other': 4}},
#    {'fips': '19181',
#     'name': 'Warren',
#     'votes': 31.97,
#     'reporting': 26,
#     'precincts': 31,
#     'results': {'buttigiegp': 11.2,
#      'warrene': 6.77,
#      'sandersb': 5.6,
#      'klobuchara': 4.43,
#      'bidenj': 3.97,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 2653,
#     'results_align1': {'buttigiegp': 840,
#      'warrene': 429,
#      'sandersb': 406,
#      'bidenj': 381,
#      'klobuchara': 342,
#      'steyert': 103,
#      'yanga': 82,
#      'patrickd': 41,
#      'gabbardt': 5,
#      'bennetm': 4,
#      'bloombergm': 2,
#      'delaneyj': 0,
#      'uncommitted': 17,
#      'other': 1},
#     'votes_alignfinal': 2642,
#     'results_alignfinal': {'buttigiegp': 983,
#      'warrene': 522,
#      'sandersb': 416,
#      'klobuchara': 358,
#      'bidenj': 324,
#      'yanga': 3,
#      'gabbardt': 1,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 28,
#      'other': 7}},
#    {'fips': '19045',
#     'name': 'Clinton',
#     'votes': 31,
#     'reporting': 26,
#     'precincts': 26,
#     'results': {'buttigiegp': 8.86,
#      'bidenj': 7.75,
#      'sandersb': 7.75,
#      'klobuchara': 3.32,
#      'warrene': 3.1,
#      'yanga': 0.22,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 1723,
#     'results_align1': {'buttigiegp': 384,
#      'sandersb': 376,
#      'bidenj': 364,
#      'warrene': 232,
#      'klobuchara': 197,
#      'yanga': 91,
#      'steyert': 53,
#      'bloombergm': 7,
#      'gabbardt': 4,
#      'bennetm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 15,
#      'other': 0},
#     'votes_alignfinal': 1684,
#     'results_alignfinal': {'buttigiegp': 468,
#      'sandersb': 415,
#      'bidenj': 406,
#      'klobuchara': 177,
#      'warrene': 170,
#      'yanga': 18,
#      'steyert': 16,
#      'bloombergm': 4,
#      'bennetm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 10,
#      'other': 0}},
#    {'fips': '19033',
#     'name': 'Cerro Gordo',
#     'votes': 29.06,
#     'reporting': 23,
#     'precincts': 26,
#     'results': {'buttigiegp': 8.86,
#      'klobuchara': 7.09,
#      'sandersb': 6.2,
#      'bidenj': 5.14,
#      'warrene': 1.59,
#      'yanga': 0.18,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 1738,
#     'results_align1': {'buttigiegp': 413,
#      'klobuchara': 360,
#      'sandersb': 350,
#      'bidenj': 304,
#      'warrene': 166,
#      'yanga': 112,
#      'steyert': 15,
#      'bloombergm': 7,
#      'gabbardt': 5,
#      'bennetm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 6,
#      'other': 0},
#     'votes_alignfinal': 1709,
#     'results_alignfinal': {'buttigiegp': 507,
#      'klobuchara': 400,
#      'sandersb': 362,
#      'bidenj': 311,
#      'warrene': 101,
#      'yanga': 16,
#      'steyert': 1,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 11,
#      'other': 0}},
#    {'fips': '19057',
#     'name': 'Des Moines',
#     'votes': 25.199999999999996,
#     'reporting': 15,
#     'precincts': 16,
#     'results': {'buttigiegp': 9,
#      'sandersb': 6.12,
#      'bidenj': 5.04,
#      'warrene': 3.24,
#      'klobuchara': 1.08,
#      'yanga': 0.72,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 1551,
#     'results_align1': {'buttigiegp': 448,
#      'sandersb': 317,
#      'bidenj': 298,
#      'warrene': 227,
#      'klobuchara': 120,
#      'yanga': 90,
#      'steyert': 28,
#      'gabbardt': 4,
#      'bennetm': 3,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 14,
#      'other': 2},
#     'votes_alignfinal': 1507,
#     'results_alignfinal': {'buttigiegp': 536,
#      'sandersb': 331,
#      'bidenj': 294,
#      'warrene': 229,
#      'klobuchara': 63,
#      'yanga': 40,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 14,
#      'other': 0}},
#    {'fips': '19127',
#     'name': 'Marshall',
#     'votes': 24,
#     'reporting': 19,
#     'precincts': 19,
#     'results': {'sandersb': 8.16,
#      'buttigiegp': 6.72,
#      'bidenj': 5.12,
#      'warrene': 2.4,
#      'klobuchara': 1.12,
#      'steyert': 0.16,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'yanga': 0,
#      'uncommitted': 0.32,
#      'other': 0},
#     'votes_align1': 1446,
#     'results_align1': {'sandersb': 439,
#      'buttigiegp': 340,
#      'bidenj': 261,
#      'warrene': 187,
#      'klobuchara': 139,
#      'yanga': 35,
#      'steyert': 31,
#      'bennetm': 5,
#      'bloombergm': 1,
#      'gabbardt': 1,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 6,
#      'other': 1},
#     'votes_alignfinal': 1429,
#     'results_alignfinal': {'sandersb': 489,
#      'buttigiegp': 421,
#      'bidenj': 266,
#      'warrene': 147,
#      'klobuchara': 59,
#      'steyert': 6,
#      'yanga': 1,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 40,
#      'other': 0}},
#    {'fips': '19139',
#     'name': 'Muscatine',
#     'votes': 23.010000000000005,
#     'reporting': 21,
#     'precincts': 23,
#     'results': {'sandersb': 8,
#      'buttigiegp': 5.67,
#      'bidenj': 4,
#      'warrene': 3.5,
#      'klobuchara': 1.67,
#      'yanga': 0.17,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 1651,
#     'results_align1': {'sandersb': 489,
#      'buttigiegp': 396,
#      'bidenj': 262,
#      'warrene': 244,
#      'klobuchara': 130,
#      'yanga': 80,
#      'steyert': 26,
#      'gabbardt': 6,
#      'bennetm': 4,
#      'bloombergm': 1,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 11,
#      'other': 2},
#     'votes_alignfinal': 1617,
#     'results_alignfinal': {'sandersb': 527,
#      'buttigiegp': 435,
#      'bidenj': 264,
#      'warrene': 252,
#      'klobuchara': 113,
#      'yanga': 15,
#      'steyert': 3,
#      'gabbardt': 1,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 7,
#      'other': 0}},
#    {'fips': '19099',
#     'name': 'Jasper',
#     'votes': 19.91,
#     'reporting': 17,
#     'precincts': 20,
#     'results': {'buttigiegp': 6.44,
#      'sandersb': 4.26,
#      'bidenj': 4.14,
#      'warrene': 2.76,
#      'klobuchara': 1.5,
#      'yanga': 0.58,
#      'steyert': 0.23,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 1348,
#     'results_align1': {'buttigiegp': 375,
#      'sandersb': 269,
#      'bidenj': 236,
#      'warrene': 193,
#      'klobuchara': 149,
#      'yanga': 64,
#      'steyert': 38,
#      'gabbardt': 6,
#      'bloombergm': 3,
#      'bennetm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 10,
#      'other': 5},
#     'votes_alignfinal': 1325,
#     'results_alignfinal': {'buttigiegp': 431,
#      'sandersb': 283,
#      'bidenj': 255,
#      'warrene': 187,
#      'klobuchara': 113,
#      'yanga': 33,
#      'steyert': 17,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 6,
#      'other': 0}},
#    {'fips': '19187',
#     'name': 'Webster',
#     'votes': 19.590000000000003,
#     'reporting': 26,
#     'precincts': 28,
#     'results': {'buttigiegp': 7.92,
#      'bidenj': 4.58,
#      'sandersb': 4.17,
#      'warrene': 1.5,
#      'klobuchara': 1.25,
#      'steyert': 0.17,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'yanga': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 1154,
#     'results_align1': {'buttigiegp': 375,
#      'bidenj': 228,
#      'sandersb': 206,
#      'warrene': 131,
#      'klobuchara': 124,
#      'steyert': 43,
#      'yanga': 33,
#      'bennetm': 5,
#      'gabbardt': 3,
#      'bloombergm': 1,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 4,
#      'other': 1},
#     'votes_alignfinal': 1179,
#     'results_alignfinal': {'buttigiegp': 474,
#      'bidenj': 272,
#      'sandersb': 231,
#      'warrene': 102,
#      'klobuchara': 86,
#      'steyert': 6,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'yanga': 0,
#      'uncommitted': 8,
#      'other': 0}},
#    {'fips': '19111',
#     'name': 'Lee',
#     'votes': 19.459999999999997,
#     'reporting': 18,
#     'precincts': 19,
#     'results': {'buttigiegp': 7.14,
#      'bidenj': 4.76,
#      'sandersb': 4.06,
#      'warrene': 1.96,
#      'klobuchara': 0.98,
#      'yanga': 0.56,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 1147,
#     'results_align1': {'buttigiegp': 358,
#      'bidenj': 256,
#      'sandersb': 226,
#      'warrene': 134,
#      'yanga': 71,
#      'klobuchara': 63,
#      'steyert': 18,
#      'gabbardt': 3,
#      'bennetm': 2,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 15,
#      'other': 1},
#     'votes_alignfinal': 1135,
#     'results_alignfinal': {'buttigiegp': 388,
#      'bidenj': 261,
#      'sandersb': 236,
#      'warrene': 128,
#      'klobuchara': 65,
#      'yanga': 40,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 17,
#      'other': 0}},
#    {'fips': '19015',
#     'name': 'Boone',
#     'votes': 19.000000000000004,
#     'reporting': 15,
#     'precincts': 15,
#     'results': {'buttigiegp': 5.89,
#      'sandersb': 5.32,
#      'warrene': 3.8,
#      'klobuchara': 2.28,
#      'bidenj': 1.52,
#      'steyert': 0.19,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'yanga': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 1356,
#     'results_align1': {'buttigiegp': 363,
#      'sandersb': 305,
#      'warrene': 235,
#      'klobuchara': 178,
#      'bidenj': 148,
#      'yanga': 79,
#      'steyert': 38,
#      'bennetm': 3,
#      'bloombergm': 1,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 6,
#      'other': 0},
#     'votes_alignfinal': 1351,
#     'results_alignfinal': {'buttigiegp': 436,
#      'sandersb': 339,
#      'warrene': 257,
#      'klobuchara': 172,
#      'bidenj': 107,
#      'steyert': 18,
#      'yanga': 14,
#      'bloombergm': 2,
#      'bennetm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 6,
#      'other': 0}},
#    {'fips': '19017',
#     'name': 'Bremer',
#     'votes': 17.01,
#     'reporting': 13,
#     'precincts': 13,
#     'results': {'buttigiegp': 5.67,
#      'warrene': 3.63,
#      'bidenj': 3.17,
#      'klobuchara': 2.72,
#      'sandersb': 1.59,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 0.23,
#      'other': 0},
#     'votes_align1': 1292,
#     'results_align1': {'buttigiegp': 369,
#      'warrene': 247,
#      'bidenj': 210,
#      'klobuchara': 196,
#      'sandersb': 189,
#      'yanga': 47,
#      'steyert': 24,
#      'gabbardt': 1,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 9,
#      'other': 0},
#     'votes_alignfinal': 1289,
#     'results_alignfinal': {'buttigiegp': 412,
#      'warrene': 288,
#      'bidenj': 195,
#      'klobuchara': 195,
#      'sandersb': 170,
#      'steyert': 8,
#      'yanga': 1,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 18,
#      'other': 2}},
#    {'fips': '19125',
#     'name': 'Marion',
#     'votes': 16.92,
#     'reporting': 16,
#     'precincts': 17,
#     'results': {'buttigiegp': 7.02,
#      'sandersb': 3.24,
#      'klobuchara': 2.7,
#      'bidenj': 1.98,
#      'warrene': 1.62,
#      'yanga': 0.36,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 1274,
#     'results_align1': {'buttigiegp': 390,
#      'sandersb': 234,
#      'klobuchara': 202,
#      'bidenj': 184,
#      'warrene': 161,
#      'yanga': 77,
#      'steyert': 11,
#      'bloombergm': 2,
#      'gabbardt': 1,
#      'bennetm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 12,
#      'other': 0},
#     'votes_alignfinal': 1253,
#     'results_alignfinal': {'buttigiegp': 476,
#      'sandersb': 242,
#      'klobuchara': 184,
#      'bidenj': 161,
#      'warrene': 144,
#      'yanga': 46,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0,
#      'other': 0}},
#    {'fips': '19179',
#     'name': 'Wapello',
#     'votes': 15.839999999999998,
#     'reporting': 19,
#     'precincts': 22,
#     'results': {'buttigiegp': 4.86,
#      'sandersb': 4.68,
#      'bidenj': 3.6,
#      'warrene': 2.34,
#      'yanga': 0.27,
#      'steyert': 0.09,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'patrickd': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 975,
#     'results_align1': {'buttigiegp': 260,
#      'sandersb': 258,
#      'bidenj': 211,
#      'warrene': 148,
#      'klobuchara': 34,
#      'yanga': 31,
#      'steyert': 26,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 4,
#      'other': 3},
#     'votes_alignfinal': 964,
#     'results_alignfinal': {'buttigiegp': 297,
#      'sandersb': 275,
#      'bidenj': 224,
#      'warrene': 149,
#      'yanga': 14,
#      'steyert': 1,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'patrickd': 0,
#      'uncommitted': 4,
#      'other': 0}},
#    {'fips': '19011',
#     'name': 'Benton',
#     'votes': 15.01,
#     'reporting': 19,
#     'precincts': 19,
#     'results': {'bidenj': 4.65,
#      'buttigiegp': 4.35,
#      'sandersb': 3.53,
#      'klobuchara': 1.5,
#      'warrene': 0.98,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 813,
#     'results_align1': {'bidenj': 226,
#      'buttigiegp': 194,
#      'sandersb': 159,
#      'warrene': 94,
#      'klobuchara': 93,
#      'steyert': 22,
#      'yanga': 17,
#      'gabbardt': 3,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 4,
#      'other': 1},
#     'votes_alignfinal': 803,
#     'results_alignfinal': {'bidenj': 245,
#      'buttigiegp': 228,
#      'sandersb': 179,
#      'klobuchara': 82,
#      'warrene': 65,
#      'yanga': 1,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 3,
#      'other': 0}},
#    {'fips': '19191',
#     'name': 'Winneshiek',
#     'votes': 14.33,
#     'reporting': 10,
#     'precincts': 11,
#     'results': {'buttigiegp': 4.35,
#      'klobuchara': 3.58,
#      'sandersb': 3.07,
#      'warrene': 2.18,
#      'bidenj': 0.64,
#      'yanga': 0.51,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 1644,
#     'results_align1': {'buttigiegp': 395,
#      'sandersb': 330,
#      'klobuchara': 319,
#      'warrene': 291,
#      'yanga': 151,
#      'bidenj': 137,
#      'steyert': 12,
#      'gabbardt': 3,
#      'bennetm': 1,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 5,
#      'other': 0},
#     'votes_alignfinal': 1619,
#     'results_alignfinal': {'buttigiegp': 471,
#      'klobuchara': 405,
#      'sandersb': 367,
#      'warrene': 290,
#      'yanga': 49,
#      'bidenj': 34,
#      'gabbardt': 2,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 1,
#      'other': 0}},
#    {'fips': '19157',
#     'name': 'Poweshiek',
#     'votes': 14.000000000000002,
#     'reporting': 10,
#     'precincts': 10,
#     'results': {'sandersb': 5.04,
#      'warrene': 3.92,
#      'klobuchara': 2.1,
#      'buttigiegp': 1.82,
#      'bidenj': 0.56,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 0.56,
#      'other': 0},
#     'votes_align1': 1768,
#     'results_align1': {'sandersb': 634,
#      'warrene': 514,
#      'buttigiegp': 207,
#      'klobuchara': 181,
#      'bidenj': 105,
#      'yanga': 91,
#      'steyert': 13,
#      'gabbardt': 3,
#      'bennetm': 1,
#      'bloombergm': 1,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 15,
#      'other': 3},
#     'votes_alignfinal': 1755,
#     'results_alignfinal': {'sandersb': 686,
#      'warrene': 590,
#      'klobuchara': 170,
#      'buttigiegp': 142,
#      'bidenj': 27,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 137,
#      'other': 3}},
#    {'fips': '19019',
#     'name': 'Buchanan',
#     'votes': 12.180000000000003,
#     'reporting': 14,
#     'precincts': 15,
#     'results': {'bidenj': 3.42,
#      'buttigiegp': 3.42,
#      'klobuchara': 2.05,
#      'sandersb': 1.37,
#      'warrene': 0.82,
#      'yanga': 0.41,
#      'steyert': 0.14,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 0.55,
#      'other': 0},
#     'votes_align1': 707,
#     'results_align1': {'bidenj': 194,
#      'buttigiegp': 177,
#      'klobuchara': 106,
#      'sandersb': 97,
#      'warrene': 69,
#      'yanga': 44,
#      'steyert': 10,
#      'gabbardt': 1,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 9,
#      'other': 0},
#     'votes_alignfinal': 691,
#     'results_alignfinal': {'bidenj': 204,
#      'buttigiegp': 176,
#      'klobuchara': 111,
#      'sandersb': 77,
#      'warrene': 49,
#      'yanga': 30,
#      'steyert': 9,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 34,
#      'other': 1}},
#    {'fips': '19065',
#     'name': 'Fayette',
#     'votes': 12.000000000000002,
#     'reporting': 25,
#     'precincts': 25,
#     'results': {'buttigiegp': 4.32,
#      'bidenj': 2.64,
#      'sandersb': 1.8,
#      'klobuchara': 1.32,
#      'warrene': 1.32,
#      'steyert': 0.48,
#      'yanga': 0.12,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 731,
#     'results_align1': {'buttigiegp': 222,
#      'bidenj': 149,
#      'sandersb': 111,
#      'warrene': 98,
#      'klobuchara': 87,
#      'yanga': 30,
#      'steyert': 25,
#      'gabbardt': 2,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 7,
#      'other': 0},
#     'votes_alignfinal': 712,
#     'results_alignfinal': {'buttigiegp': 258,
#      'bidenj': 153,
#      'sandersb': 103,
#      'warrene': 89,
#      'klobuchara': 82,
#      'steyert': 14,
#      'yanga': 7,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 6,
#      'other': 0}},
#    {'fips': '19097',
#     'name': 'Jackson',
#     'votes': 11.66,
#     'reporting': 15,
#     'precincts': 16,
#     'results': {'buttigiegp': 3.77,
#      'bidenj': 3.09,
#      'klobuchara': 1.89,
#      'warrene': 1.37,
#      'sandersb': 1.2,
#      'steyert': 0.17,
#      'yanga': 0.17,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 762,
#     'results_align1': {'buttigiegp': 225,
#      'bidenj': 177,
#      'sandersb': 113,
#      'klobuchara': 102,
#      'warrene': 97,
#      'yanga': 21,
#      'steyert': 9,
#      'gabbardt': 2,
#      'bloombergm': 1,
#      'bennetm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 15,
#      'other': 0},
#     'votes_alignfinal': 750,
#     'results_alignfinal': {'buttigiegp': 250,
#      'bidenj': 194,
#      'warrene': 105,
#      'klobuchara': 90,
#      'sandersb': 79,
#      'yanga': 14,
#      'steyert': 8,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 9,
#      'other': 1}},
#    {'fips': '19105',
#     'name': 'Jones',
#     'votes': 11.52,
#     'reporting': 13,
#     'precincts': 14,
#     'results': {'buttigiegp': 3.52,
#      'sandersb': 2.56,
#      'bidenj': 2.4,
#      'klobuchara': 1.92,
#      'warrene': 1.12,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 599,
#     'results_align1': {'buttigiegp': 143,
#      'sandersb': 128,
#      'bidenj': 120,
#      'klobuchara': 94,
#      'warrene': 78,
#      'steyert': 14,
#      'yanga': 13,
#      'gabbardt': 6,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 3,
#      'other': 0},
#     'votes_alignfinal': 594,
#     'results_alignfinal': {'buttigiegp': 169,
#      'sandersb': 133,
#      'bidenj': 127,
#      'klobuchara': 95,
#      'warrene': 66,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 4,
#      'other': 0}},
#    {'fips': '19031',
#     'name': 'Cedar',
#     'votes': 11.310000000000002,
#     'reporting': 11,
#     'precincts': 12,
#     'results': {'buttigiegp': 2.91,
#      'sandersb': 2.57,
#      'klobuchara': 2.23,
#      'warrene': 2.23,
#      'bidenj': 1.37,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 815,
#     'results_align1': {'buttigiegp': 196,
#      'sandersb': 196,
#      'warrene': 156,
#      'klobuchara': 128,
#      'bidenj': 103,
#      'yanga': 14,
#      'steyert': 12,
#      'bloombergm': 2,
#      'gabbardt': 2,
#      'bennetm': 1,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 5,
#      'other': 0},
#     'votes_alignfinal': 785,
#     'results_alignfinal': {'sandersb': 198,
#      'buttigiegp': 195,
#      'warrene': 154,
#      'klobuchara': 149,
#      'bidenj': 89,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 0,
#      'other': 0}},
#    {'fips': '19027',
#     'name': 'Carroll',
#     'votes': 11,
#     'reporting': 13,
#     'precincts': 13,
#     'results': {'buttigiegp': 3.74,
#      'bidenj': 2.75,
#      'klobuchara': 1.98,
#      'sandersb': 1.43,
#      'warrene': 0.99,
#      'yanga': 0.11,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 0,
#      'other': 0},
#     'votes_align1': 624,
#     'results_align1': {'buttigiegp': 161,
#      'bidenj': 155,
#      'klobuchara': 113,
#      'sandersb': 92,
#      'warrene': 70,
#      'yanga': 17,
#      'steyert': 6,
#      'bloombergm': 1,
#      'bennetm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'uncommitted': 9,
#      'other': 0},
#     'votes_alignfinal': 623,
#     'results_alignfinal': {'buttigiegp': 198,
#      'bidenj': 158,
#      'klobuchara': 120,
#      'sandersb': 87,
#      'warrene': 51,
#      'yanga': 7,
#      'bloombergm': 1,
#      'bennetm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'uncommitted': 1,
#      'other': 0}},
#    {'fips': '19101',
#     'name': 'Jefferson',
#     'votes': 10.91,
#     'reporting': 9,
#     'precincts': 12,
#     'results': {'sandersb': 5.45,
#      'warrene': 3.05,
#      'buttigiegp': 1.31,
#      'bidenj': 0.44,
#      'klobuchara': 0.44,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 0.22,
#      'other': 0},
#     'votes_align1': 1676,
#     'results_align1': {'sandersb': 722,
#      'warrene': 344,
#      'bidenj': 172,
#      'buttigiegp': 166,
#      'yanga': 121,
#      'klobuchara': 102,
#      'steyert': 26,
#      'gabbardt': 11,
#      'bloombergm': 8,
#      'bennetm': 0,
#      'delaneyj': 0,
#      'patrickd': 0,
#      'uncommitted': 4,
#      'other': 0},
#     'votes_alignfinal': 1558,
#     'results_alignfinal': {'sandersb': 796,
#      'warrene': 450,
#      'buttigiegp': 157,
#      'klobuchara': 86,
#      'bidenj': 64,
#      'bennetm': 0,
#      'bloombergm': 0,
#      'delaneyj': 0,
#      'gabbardt': 0,
#      'patrickd': 0,
#      'steyert': 0,
#      'yanga': 0,
#      'uncommitted': 3,
# ...
#        'warrene': {'prev_votes': 2.34, 'num_additional_votes': 0},
#        'yanga': {'prev_votes': 0.27, 'num_additional_votes': 0},
#        'steyert': {'prev_votes': 0.09, 'num_additional_votes': 0},
#        'bennetm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'bloombergm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'delaneyj': {'prev_votes': 0, 'num_additional_votes': 0},
#        'gabbardt': {'prev_votes': 0, 'num_additional_votes': 0},
#        'klobuchara': {'prev_votes': 0, 'num_additional_votes': 0},
#        'patrickd': {'prev_votes': 0, 'num_additional_votes': 0},
#        'uncommitted': {'prev_votes': 0, 'num_additional_votes': 0},
#        'other': {'prev_votes': 0, 'num_additional_votes': 0}}},
#      {'fips': '19181',
#       'num_additional_votes': 0,
#       'prev_votes': 31.97,
#       'num_additional_precincts': 0,
#       'prev_precincts': 31,
#       'candidate_changes': {'buttigiegp': {'prev_votes': 11.2,
#         'num_additional_votes': 0},
#        'warrene': {'prev_votes': 6.77, 'num_additional_votes': 0},
#        'sandersb': {'prev_votes': 5.6, 'num_additional_votes': 0},
#        'klobuchara': {'prev_votes': 4.43, 'num_additional_votes': 0},
#        'bidenj': {'prev_votes': 3.97, 'num_additional_votes': 0},
#        'bennetm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'bloombergm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'delaneyj': {'prev_votes': 0, 'num_additional_votes': 0},
#        'gabbardt': {'prev_votes': 0, 'num_additional_votes': 0},
#        'patrickd': {'prev_votes': 0, 'num_additional_votes': 0},
#        'steyert': {'prev_votes': 0, 'num_additional_votes': 0},
#        'yanga': {'prev_votes': 0, 'num_additional_votes': 0},
#        'uncommitted': {'prev_votes': 0, 'num_additional_votes': 0},
#        'other': {'prev_votes': 0, 'num_additional_votes': 0}}},
#      {'fips': '19183',
#       'num_additional_votes': 0,
#       'prev_votes': 10.21,
#       'num_additional_precincts': 0,
#       'prev_precincts': 10,
#       'candidate_changes': {'sandersb': {'prev_votes': 2.97,
#         'num_additional_votes': 0},
#        'warrene': {'prev_votes': 2.23, 'num_additional_votes': 0},
#        'buttigiegp': {'prev_votes': 2.04, 'num_additional_votes': 0},
#        'klobuchara': {'prev_votes': 1.67, 'num_additional_votes': 0},
#        'bidenj': {'prev_votes': 1.3, 'num_additional_votes': 0},
#        'bennetm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'bloombergm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'delaneyj': {'prev_votes': 0, 'num_additional_votes': 0},
#        'gabbardt': {'prev_votes': 0, 'num_additional_votes': 0},
#        'patrickd': {'prev_votes': 0, 'num_additional_votes': 0},
#        'steyert': {'prev_votes': 0, 'num_additional_votes': 0},
#        'yanga': {'prev_votes': 0, 'num_additional_votes': 0},
#        'uncommitted': {'prev_votes': 0, 'num_additional_votes': 0},
#        'other': {'prev_votes': 0, 'num_additional_votes': 0}}},
#      {'fips': '19185',
#       'num_additional_votes': 0,
#       'prev_votes': 3.0200000000000005,
#       'num_additional_precincts': 0,
#       'prev_precincts': 4,
#       'candidate_changes': {'klobuchara': {'prev_votes': 0.98,
#         'num_additional_votes': 0},
#        'warrene': {'prev_votes': 0.6, 'num_additional_votes': 0},
#        'buttigiegp': {'prev_votes': 0.53, 'num_additional_votes': 0},
#        'sandersb': {'prev_votes': 0.53, 'num_additional_votes': 0},
#        'bidenj': {'prev_votes': 0.38, 'num_additional_votes': 0},
#        'bennetm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'bloombergm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'delaneyj': {'prev_votes': 0, 'num_additional_votes': 0},
#        'gabbardt': {'prev_votes': 0, 'num_additional_votes': 0},
#        'patrickd': {'prev_votes': 0, 'num_additional_votes': 0},
#        'steyert': {'prev_votes': 0, 'num_additional_votes': 0},
#        'yanga': {'prev_votes': 0, 'num_additional_votes': 0},
#        'uncommitted': {'prev_votes': 0, 'num_additional_votes': 0},
#        'other': {'prev_votes': 0, 'num_additional_votes': 0}}},
#      {'fips': '19187',
#       'num_additional_votes': 0,
#       'prev_votes': 19.590000000000003,
#       'num_additional_precincts': 0,
#       'prev_precincts': 28,
#       'candidate_changes': {'buttigiegp': {'prev_votes': 7.92,
#         'num_additional_votes': 0},
#        'bidenj': {'prev_votes': 4.58, 'num_additional_votes': 0},
#        'sandersb': {'prev_votes': 4.17, 'num_additional_votes': 0},
#        'warrene': {'prev_votes': 1.5, 'num_additional_votes': 0},
#        'klobuchara': {'prev_votes': 1.25, 'num_additional_votes': 0},
#        'steyert': {'prev_votes': 0.17, 'num_additional_votes': 0},
#        'bennetm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'bloombergm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'delaneyj': {'prev_votes': 0, 'num_additional_votes': 0},
#        'gabbardt': {'prev_votes': 0, 'num_additional_votes': 0},
#        'patrickd': {'prev_votes': 0, 'num_additional_votes': 0},
#        'yanga': {'prev_votes': 0, 'num_additional_votes': 0},
#        'uncommitted': {'prev_votes': 0, 'num_additional_votes': 0},
#        'other': {'prev_votes': 0, 'num_additional_votes': 0}}},
#      {'fips': '19189',
#       'num_additional_votes': 0,
#       'prev_votes': 4.95,
#       'num_additional_precincts': 0,
#       'prev_precincts': 10,
#       'candidate_changes': {'buttigiegp': {'prev_votes': 1.8,
#         'num_additional_votes': 0},
#        'warrene': {'prev_votes': 0.9, 'num_additional_votes': 0},
#        'klobuchara': {'prev_votes': 0.75, 'num_additional_votes': 0},
#        'sandersb': {'prev_votes': 0.6, 'num_additional_votes': 0},
#        'bidenj': {'prev_votes': 0.45, 'num_additional_votes': 0},
#        'yanga': {'prev_votes': 0.45, 'num_additional_votes': 0},
#        'bennetm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'bloombergm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'delaneyj': {'prev_votes': 0, 'num_additional_votes': 0},
#        'gabbardt': {'prev_votes': 0, 'num_additional_votes': 0},
#        'patrickd': {'prev_votes': 0, 'num_additional_votes': 0},
#        'steyert': {'prev_votes': 0, 'num_additional_votes': 0},
#        'uncommitted': {'prev_votes': 0, 'num_additional_votes': 0},
#        'other': {'prev_votes': 0, 'num_additional_votes': 0}}},
#      {'fips': '19191',
#       'num_additional_votes': 0,
#       'prev_votes': 14.33,
#       'num_additional_precincts': 0,
#       'prev_precincts': 11,
#       'candidate_changes': {'buttigiegp': {'prev_votes': 4.35,
#         'num_additional_votes': 0},
#        'klobuchara': {'prev_votes': 3.58, 'num_additional_votes': 0},
#        'sandersb': {'prev_votes': 3.07, 'num_additional_votes': 0},
#        'warrene': {'prev_votes': 2.18, 'num_additional_votes': 0},
#        'bidenj': {'prev_votes': 0.64, 'num_additional_votes': 0},
#        'yanga': {'prev_votes': 0.51, 'num_additional_votes': 0},
#        'bennetm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'bloombergm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'delaneyj': {'prev_votes': 0, 'num_additional_votes': 0},
#        'gabbardt': {'prev_votes': 0, 'num_additional_votes': 0},
#        'patrickd': {'prev_votes': 0, 'num_additional_votes': 0},
#        'steyert': {'prev_votes': 0, 'num_additional_votes': 0},
#        'uncommitted': {'prev_votes': 0, 'num_additional_votes': 0},
#        'other': {'prev_votes': 0, 'num_additional_votes': 0}}},
#      {'fips': '19193',
#       'num_additional_votes': 0,
#       'prev_votes': 38.26,
#       'num_additional_precincts': 0,
#       'prev_precincts': 44,
#       'candidate_changes': {'sandersb': {'prev_votes': 12.33,
#         'num_additional_votes': 0},
#        'bidenj': {'prev_votes': 8.93, 'num_additional_votes': 0},
#        'buttigiegp': {'prev_votes': 8.29, 'num_additional_votes': 0},
#        'warrene': {'prev_votes': 6.16, 'num_additional_votes': 0},
#        'klobuchara': {'prev_votes': 1.7, 'num_additional_votes': 0},
#        'yanga': {'prev_votes': 0.64, 'num_additional_votes': 0},
#        'bennetm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'bloombergm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'delaneyj': {'prev_votes': 0, 'num_additional_votes': 0},
#        'gabbardt': {'prev_votes': 0, 'num_additional_votes': 0},
#        'patrickd': {'prev_votes': 0, 'num_additional_votes': 0},
#        'steyert': {'prev_votes': 0, 'num_additional_votes': 0},
#        'uncommitted': {'prev_votes': 0.21, 'num_additional_votes': 0},
#        'other': {'prev_votes': 0, 'num_additional_votes': 0}}},
#      {'fips': '19195',
#       'num_additional_votes': 0,
#       'prev_votes': 4.4,
#       'num_additional_precincts': 0,
#       'prev_precincts': 7,
#       'candidate_changes': {'klobuchara': {'prev_votes': 1.2,
#         'num_additional_votes': 0},
#        'buttigiegp': {'prev_votes': 0.87, 'num_additional_votes': 0},
#        'sandersb': {'prev_votes': 0.73, 'num_additional_votes': 0},
#        'bidenj': {'prev_votes': 0.6, 'num_additional_votes': 0},
#        'warrene': {'prev_votes': 0.6, 'num_additional_votes': 0},
#        'yanga': {'prev_votes': 0.4, 'num_additional_votes': 0},
#        'bennetm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'bloombergm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'delaneyj': {'prev_votes': 0, 'num_additional_votes': 0},
#        'gabbardt': {'prev_votes': 0, 'num_additional_votes': 0},
#        'patrickd': {'prev_votes': 0, 'num_additional_votes': 0},
#        'steyert': {'prev_votes': 0, 'num_additional_votes': 0},
#        'uncommitted': {'prev_votes': 0, 'num_additional_votes': 0},
#        'other': {'prev_votes': 0, 'num_additional_votes': 0}}},
#      {'fips': '19197',
#       'num_additional_votes': 0,
#       'prev_votes': 5.61,
#       'num_additional_precincts': 0,
#       'prev_precincts': 10,
#       'candidate_changes': {'buttigiegp': {'prev_votes': 2,
#         'num_additional_votes': 0},
#        'bidenj': {'prev_votes': 1.07, 'num_additional_votes': 0},
#        'klobuchara': {'prev_votes': 1.07, 'num_additional_votes': 0},
#        'sandersb': {'prev_votes': 1.07, 'num_additional_votes': 0},
#        'warrene': {'prev_votes': 0.27, 'num_additional_votes': 0},
#        'bloombergm': {'prev_votes': 0.13, 'num_additional_votes': 0},
#        'bennetm': {'prev_votes': 0, 'num_additional_votes': 0},
#        'delaneyj': {'prev_votes': 0, 'num_additional_votes': 0},
#        'gabbardt': {'prev_votes': 0, 'num_additional_votes': 0},
#        'patrickd': {'prev_votes': 0, 'num_additional_votes': 0},
#        'steyert': {'prev_votes': 0, 'num_additional_votes': 0},
#        'yanga': {'prev_votes': 0, 'num_additional_votes': 0},
#        'uncommitted': {'prev_votes': 0, 'num_additional_votes': 0},
#        'other': {'prev_votes': 0, 'num_additional_votes': 0}}}],
#     'num_additional_votes_and_percentage_points_by_candidate': [{'candidate_id': 'buttigieg-67933',
#       'num_additional_votes': 0,
#       'prev_votes': 512,
#       'num_additional_delegates': 0,
#       'prev_delegates': 11,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 39006,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 26.7},
#      {'candidate_id': 'sanders-1445',
#       'num_additional_votes': 0,
#       'prev_votes': 488,
#       'num_additional_delegates': 0,
#       'prev_delegates': 11,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 39954,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 25.4},
#      {'candidate_id': 'warren-62244',
#       'num_additional_votes': 0,
#       'prev_votes': 352,
#       'num_additional_delegates': 0,
#       'prev_delegates': 5,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 31264,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 18.3},
#      {'candidate_id': 'biden-1036',
#       'num_additional_votes': 0,
#       'prev_votes': 306,
#       'num_additional_delegates': 0,
#       'prev_delegates': 0,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 20992,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 15.9},
#      {'candidate_id': 'klobuchar-51526',
#       'num_additional_votes': 0,
#       'prev_votes': 232,
#       'num_additional_delegates': 0,
#       'prev_delegates': 0,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 18251,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 12.1},
#      {'candidate_id': 'yang-67936',
#       'num_additional_votes': 0,
#       'prev_votes': 19,
#       'num_additional_delegates': 0,
#       'prev_delegates': 0,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 1547,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 1},
#      {'candidate_id': 'steyer-67935',
#       'num_additional_votes': 0,
#       'prev_votes': 6,
#       'num_additional_delegates': 0,
#       'prev_delegates': 0,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 368,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 0.3},
#      {'candidate_id': 'bloomberg-32324',
#       'num_additional_votes': 0,
#       'prev_votes': 0,
#       'num_additional_delegates': 0,
#       'prev_delegates': 0,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 10,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 0},
#      {'candidate_id': 'gabbard-62589',
#       'num_additional_votes': 0,
#       'prev_votes': 0,
#       'num_additional_delegates': 0,
#       'prev_delegates': 0,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 15,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 0},
#      {'candidate_id': 'patrick-51516',
#       'num_additional_votes': 0,
#       'prev_votes': 0,
#       'num_additional_delegates': 0,
#       'prev_delegates': 0,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 0,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 0},
#      {'candidate_id': 'bennet-59911',
#       'num_additional_votes': 0,
#       'prev_votes': 0,
#       'num_additional_delegates': 0,
#       'prev_delegates': 0,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 1,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 0},
#      {'candidate_id': 'delaney-61562',
#       'num_additional_votes': 0,
#       'prev_votes': 0,
#       'num_additional_delegates': 0,
#       'prev_delegates': 0,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 0,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 0},
#      {'candidate_id': 'uncommitted-100004',
#       'num_additional_votes': 0,
#       'prev_votes': 4,
#       'num_additional_delegates': 0,
#       'prev_delegates': 0,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 1326,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 0.2},
#      {'candidate_id': 'other-100007',
#       'num_additional_votes': 0,
#       'prev_votes': 1,
#       'num_additional_delegates': 0,
#       'prev_delegates': 0,
#       'num_additional_final_alignment': 0,
#       'prev_final_alignment': 165,
#       'num_additional_percentage_points': 0,
#       'prev_percent': 0.1}]}},
#   'update_sentences': {'top_level': {'sentence': 'The Iowa Democratic Party released a new set of results: Buttigieg leads Sanders by 1.3 percentage points with 86 percent of precincts reporting.',
#     'timestamp': 1580940812781,
#     'is_new': False},
#    'counties': {'sentence': 'Buttigieg now leads in 60 counties, while Sanders leads in 18 counties. We’re still waiting on precincts in 57 counties.',
#     'timestamp': 1580940562891,
#     'is_new': True},
#    'multi_vote': {'sentence': 'Buttigieg leads Sanders by 24 state delegate equivalents. Sanders leads the first and final alignment votes.',
#     'timestamp': 1580940562891,
#     'is_new': True}},
#   'model_metadata': {'latest_url': 'https://int.nyt.com/applications/elections/2020/data/liveModel/2020-02-03/ia-17275-2020-02-03.json',
#    'preview_latest_url': '/api/2020-02-03/liveModel/ia-17275-2020-02-03.json',
#    'model_note': ''}}]

# %% [markdown]
# Whoa. What's that?

# %%
type(demo["data"]["races"])
# Out:
# list

# %%
len(demo["data"]["races"])
# Out:
# 1

# %% [markdown]
# OK a list of one entry. (Only one race so far maybe?) What is that one entry?

# %%
type(demo['data']['races'][0])
# Out:
# dict

# %% [markdown]
# So all that is a dictionary. Let's look at the keys.

# %%
sorted(demo['data']['races'][0].keys())
# Out:
# ['candidates',
#  'counties',
#  'delegates',
#  'delegates_allocated',
#  'eevp',
#  'election_date',
#  'election_type',
#  'electoral_votes',
#  'gain',
#  'has_incumbent',
#  'incumbent_party',
#  'lost_seat',
#  'model_metadata',
#  'no_forecast',
#  'nyt_measure_title',
#  'nyt_title',
#  'office',
#  'officeid',
#  'party_id',
#  'poll_countdown_display',
#  'poll_display',
#  'poll_time',
#  'precinct_filters',
#  'precinct_map_bounds',
#  'precinct_map_toggles',
#  'precinct_metadata',
#  'precinct_tileset',
#  'precincts_reporting',
#  'precincts_total',
#  'race_call_note',
#  'race_diff',
#  'race_id',
#  'race_name',
#  'race_slug',
#  'race_text',
#  'race_type',
#  'report',
#  'reporting_display',
#  'result',
#  'result_source',
#  'runoff',
#  'seat',
#  'seat_name',
#  'show_precinct_filters',
#  'state_id',
#  'state_name',
#  'state_nyt_abbrev',
#  'state_slug',
#  'uncontested',
#  'update_sentences',
#  'url',
#  'votes',
#  'votes_align1',
#  'votes_alignfinal']

# %% [markdown]
# And we can sample around a little.

# %%
demo['data']['races'][0]['candidates']
# Out:
# [{'candidate_id': 'buttigieg-67933',
#   'candidate_key': 'buttigiegp',
#   'first_name': 'Pete',
#   'last_name': 'Buttigieg',
#   'order': 4,
#   'name_display': 'Pete Buttigieg',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 512,
#   'percent': 26.7,
#   'percent_display': '26.7',
#   'electoral_votes': 0,
#   'has_image': True,
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/pete-buttigieg.html',
#   'pronoun': 'he',
#   'votes_align1': 33687,
#   'percent_align1': 21.6,
#   'percent_display_align1': '21.6',
#   'winner_align1': False,
#   'votes_alignfinal': 39006,
#   'percent_alignfinal': 25.5,
#   'percent_display_alignfinal': '25.5',
#   'winner_alignfinal': False,
#   'delegates': 11},
#  {'candidate_id': 'sanders-1445',
#   'candidate_key': 'sandersb',
#   'first_name': 'Bernie',
#   'last_name': 'Sanders',
#   'order': 2,
#   'name_display': 'Bernie Sanders',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 488,
#   'percent': 25.4,
#   'percent_display': '25.4',
#   'electoral_votes': 0,
#   'has_image': True,
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/bernie-sanders.html',
#   'pronoun': 'he',
#   'votes_align1': 37989,
#   'percent_align1': 24.3,
#   'percent_display_align1': '24.3',
#   'winner_align1': False,
#   'votes_alignfinal': 39954,
#   'percent_alignfinal': 26.1,
#   'percent_display_alignfinal': '26.1',
#   'winner_alignfinal': False,
#   'delegates': 11},
#  {'candidate_id': 'warren-62244',
#   'candidate_key': 'warrene',
#   'first_name': 'Elizabeth',
#   'last_name': 'Warren',
#   'order': 3,
#   'name_display': 'Elizabeth Warren',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 352,
#   'percent': 18.3,
#   'percent_display': '18.3',
#   'electoral_votes': 0,
#   'has_image': True,
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/elizabeth-warren.html',
#   'pronoun': 'she',
#   'votes_align1': 29135,
#   'percent_align1': 18.6,
#   'percent_display_align1': '18.6',
#   'winner_align1': False,
#   'votes_alignfinal': 31264,
#   'percent_alignfinal': 20.4,
#   'percent_display_alignfinal': '20.4',
#   'winner_alignfinal': False,
#   'delegates': 5},
#  {'candidate_id': 'biden-1036',
#   'candidate_key': 'bidenj',
#   'first_name': 'Joseph R.',
#   'last_name': 'Biden',
#   'order': 1,
#   'name_display': 'Joseph R. Biden Jr.',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 306,
#   'percent': 15.9,
#   'percent_display': '15.9',
#   'electoral_votes': 0,
#   'has_image': True,
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/joe-biden.html',
#   'pronoun': 'he',
#   'votes_align1': 23327,
#   'percent_align1': 14.9,
#   'percent_display_align1': '14.9',
#   'winner_align1': False,
#   'votes_alignfinal': 20992,
#   'percent_alignfinal': 13.7,
#   'percent_display_alignfinal': '13.7',
#   'winner_alignfinal': False,
#   'delegates': 0},
#  {'candidate_id': 'klobuchar-51526',
#   'candidate_key': 'klobuchara',
#   'first_name': 'Amy',
#   'last_name': 'Klobuchar',
#   'order': 6,
#   'name_display': 'Amy Klobuchar',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 232,
#   'percent': 12.1,
#   'percent_display': '12.1',
#   'electoral_votes': 0,
#   'has_image': True,
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/amy-klobuchar.html',
#   'pronoun': 'she',
#   'votes_align1': 19743,
#   'percent_align1': 12.6,
#   'percent_display_align1': '12.6',
#   'winner_align1': False,
#   'votes_alignfinal': 18251,
#   'percent_alignfinal': 11.9,
#   'percent_display_alignfinal': '11.9',
#   'winner_alignfinal': False,
#   'delegates': 0},
#  {'candidate_id': 'yang-67936',
#   'candidate_key': 'yanga',
#   'first_name': 'Andrew',
#   'last_name': 'Yang',
#   'order': 7,
#   'name_display': 'Andrew Yang',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 19,
#   'percent': 1,
#   'percent_display': '1.0',
#   'electoral_votes': 0,
#   'has_image': True,
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/andrew-yang.html',
#   'pronoun': 'he',
#   'votes_align1': 7907,
#   'percent_align1': 5.1,
#   'percent_display_align1': '5.1',
#   'winner_align1': False,
#   'votes_alignfinal': 1547,
#   'percent_alignfinal': 1,
#   'percent_display_alignfinal': '1.0',
#   'winner_alignfinal': False,
#   'delegates': 0},
#  {'candidate_id': 'steyer-67935',
#   'candidate_key': 'steyert',
#   'first_name': 'Tom',
#   'last_name': 'Steyer',
#   'order': 8,
#   'name_display': 'Tom Steyer',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 6,
#   'percent': 0.3,
#   'percent_display': '0.3',
#   'electoral_votes': 0,
#   'has_image': True,
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/tom-steyer.html',
#   'pronoun': 'he',
#   'votes_align1': 2761,
#   'percent_align1': 1.8,
#   'percent_display_align1': '1.8',
#   'winner_align1': False,
#   'votes_alignfinal': 368,
#   'percent_alignfinal': 0.2,
#   'percent_display_alignfinal': '0.2',
#   'winner_alignfinal': False,
#   'delegates': 0},
#  {'candidate_id': 'bloomberg-32324',
#   'candidate_key': 'bloombergm',
#   'first_name': 'Michael',
#   'last_name': 'Bloomberg',
#   'order': 5,
#   'name_display': 'Michael Bloomberg',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 0,
#   'percent': 0,
#   'percent_display': '0.0',
#   'electoral_votes': 0,
#   'has_image': True,
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/michael-bloomberg.html',
#   'pronoun': 'he',
#   'votes_align1': 178,
#   'percent_align1': 0.1,
#   'percent_display_align1': '0.1',
#   'winner_align1': False,
#   'votes_alignfinal': 10,
#   'percent_alignfinal': 0,
#   'percent_display_alignfinal': '0.0',
#   'winner_alignfinal': False,
#   'delegates': 0},
#  {'candidate_id': 'gabbard-62589',
#   'candidate_key': 'gabbardt',
#   'first_name': 'Tulsi',
#   'last_name': 'Gabbard',
#   'order': 9,
#   'name_display': 'Tulsi Gabbard',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 0,
#   'percent': 0,
#   'percent_display': '0.0',
#   'electoral_votes': 0,
#   'has_image': True,
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/tulsi-gabbard.html',
#   'pronoun': 'she',
#   'votes_align1': 305,
#   'percent_align1': 0.2,
#   'percent_display_align1': '0.2',
#   'winner_align1': False,
#   'votes_alignfinal': 15,
#   'percent_alignfinal': 0,
#   'percent_display_alignfinal': '0.0',
#   'winner_alignfinal': False,
#   'delegates': 0},
#  {'candidate_id': 'patrick-51516',
#   'candidate_key': 'patrickd',
#   'first_name': 'Deval',
#   'last_name': 'Patrick',
#   'order': 11,
#   'name_display': 'Deval Patrick',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 0,
#   'percent': 0,
#   'percent_display': '0.0',
#   'electoral_votes': 0,
#   'has_image': True,
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/deval-patrick.html',
#   'pronoun': 'he',
#   'votes_align1': 48,
#   'percent_align1': 0,
#   'percent_display_align1': '0.0',
#   'winner_align1': False,
#   'votes_alignfinal': 0,
#   'percent_alignfinal': 0,
#   'percent_display_alignfinal': '0.0',
#   'winner_alignfinal': False,
#   'delegates': 0},
#  {'candidate_id': 'bennet-59911',
#   'candidate_key': 'bennetm',
#   'first_name': 'Michael',
#   'last_name': 'Bennet',
#   'order': 10,
#   'name_display': 'Michael Bennet',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 0,
#   'percent': 0,
#   'percent_display': '0.0',
#   'electoral_votes': 0,
#   'has_image': True,
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/michael-bennet.html',
#   'pronoun': 'he',
#   'votes_align1': 129,
#   'percent_align1': 0.1,
#   'percent_display_align1': '0.1',
#   'winner_align1': False,
#   'votes_alignfinal': 1,
#   'percent_alignfinal': 0,
#   'percent_display_alignfinal': '0.0',
#   'winner_alignfinal': False,
#   'delegates': 0},
#  {'candidate_id': 'delaney-61562',
#   'candidate_key': 'delaneyj',
#   'first_name': 'John',
#   'last_name': 'Delaney',
#   'order': 12,
#   'name_display': 'John Delaney',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 0,
#   'percent': 0,
#   'percent_display': '0.0',
#   'electoral_votes': 0,
#   'has_image': True,
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/john-delaney.html',
#   'pronoun': 'he',
#   'votes_align1': 9,
#   'percent_align1': 0,
#   'percent_display_align1': '0.0',
#   'winner_align1': False,
#   'votes_alignfinal': 0,
#   'percent_alignfinal': 0,
#   'percent_display_alignfinal': '0.0',
#   'winner_alignfinal': False,
#   'delegates': 0},
#  {'candidate_id': 'uncommitted-100004',
#   'candidate_key': 'uncommitted',
#   'last_name': 'Uncommitted',
#   'order': 13,
#   'name_display': 'Uncommitted',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 4,
#   'percent': 0.2,
#   'percent_display': '0.2',
#   'electoral_votes': 0,
#   'has_image': False,
#   'link': '',
#   'votes_align1': 871,
#   'percent_align1': 0.6,
#   'percent_display_align1': '0.6',
#   'winner_align1': False,
#   'votes_alignfinal': 1326,
#   'percent_alignfinal': 0.9,
#   'percent_display_alignfinal': '0.9',
#   'winner_alignfinal': False,
#   'delegates': 0},
#  {'candidate_id': 'other-100007',
#   'candidate_key': 'other',
#   'last_name': 'Other',
#   'order': 14,
#   'name_display': 'Other',
#   'party_id': 'democrat',
#   'incumbent': False,
#   'runoff': False,
#   'winner': False,
#   'votes': 1,
#   'percent': 0.1,
#   'percent_display': '0.1',
#   'electoral_votes': 0,
#   'has_image': False,
#   'link': '',
#   'votes_align1': 144,
#   'percent_align1': 0.1,
#   'percent_display_align1': '0.1',
#   'winner_align1': False,
#   'votes_alignfinal': 165,
#   'percent_alignfinal': 0.1,
#   'percent_display_alignfinal': '0.1',
#   'winner_alignfinal': False,
#   'delegates': 0}]

# %%
demo['data']['races'][0]['counties']
# Out:
# [{'fips': '19001',
#   'name': 'Adair',
#   'votes': 2.5300000000000002,
#   'reporting': 3,
#   'precincts': 5,
#   'results': {'klobuchara': 0.71,
#    'sandersb': 0.71,
#    'buttigiegp': 0.55,
#    'steyert': 0.16,
#    'warrene': 0.16,
#    'yanga': 0.16,
#    'bidenj': 0.08,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 161,
#   'results_align1': {'klobuchara': 43,
#    'sandersb': 35,
#    'buttigiegp': 28,
#    'bidenj': 20,
#    'warrene': 15,
#    'yanga': 13,
#    'steyert': 7,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 161,
#   'results_alignfinal': {'klobuchara': 50,
#    'sandersb': 40,
#    'buttigiegp': 35,
#    'yanga': 14,
#    'warrene': 9,
#    'steyert': 7,
#    'bidenj': 6,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19003',
#   'name': 'Adams',
#   'votes': 1.72,
#   'reporting': 3,
#   'precincts': 5,
#   'results': {'buttigiegp': 0.43,
#    'klobuchara': 0.43,
#    'bidenj': 0.34,
#    'sandersb': 0.26,
#    'warrene': 0.26,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 62,
#   'results_align1': {'bidenj': 15,
#    'buttigiegp': 15,
#    'klobuchara': 12,
#    'sandersb': 12,
#    'warrene': 8,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 62,
#   'results_alignfinal': {'bidenj': 15,
#    'buttigiegp': 15,
#    'klobuchara': 12,
#    'sandersb': 10,
#    'warrene': 10,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19005',
#   'name': 'Allamakee',
#   'votes': 5.52,
#   'reporting': 8,
#   'precincts': 11,
#   'results': {'buttigiegp': 2.02,
#    'klobuchara': 1.17,
#    'sandersb': 0.93,
#    'bidenj': 0.62,
#    'yanga': 0.39,
#    'warrene': 0.31,
#    'steyert': 0.08,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 384,
#   'results_align1': {'buttigiegp': 119,
#    'klobuchara': 59,
#    'sandersb': 57,
#    'bidenj': 51,
#    'warrene': 36,
#    'yanga': 31,
#    'steyert': 25,
#    'bennetm': 1,
#    'gabbardt': 1,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 4,
#    'other': 0},
#   'votes_alignfinal': 382,
#   'results_alignfinal': {'buttigiegp': 138,
#    'klobuchara': 80,
#    'sandersb': 63,
#    'bidenj': 38,
#    'warrene': 25,
#    'yanga': 23,
#    'steyert': 9,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 4,
#    'other': 2}},
#  {'fips': '19007',
#   'name': 'Appanoose',
#   'votes': 5.680000000000001,
#   'reporting': 11,
#   'precincts': 12,
#   'results': {'buttigiegp': 2.24,
#    'bidenj': 1.68,
#    'sandersb': 0.96,
#    'klobuchara': 0.4,
#    'steyert': 0.24,
#    'warrene': 0.08,
#    'yanga': 0.08,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 347,
#   'results_align1': {'buttigiegp': 119,
#    'bidenj': 80,
#    'sandersb': 61,
#    'warrene': 35,
#    'klobuchara': 30,
#    'steyert': 15,
#    'yanga': 4,
#    'gabbardt': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 2,
#    'other': 0},
#   'votes_alignfinal': 346,
#   'results_alignfinal': {'buttigiegp': 140,
#    'bidenj': 96,
#    'sandersb': 57,
#    'klobuchara': 22,
#    'steyert': 12,
#    'warrene': 7,
#    'yanga': 4,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 8,
#    'other': 0}},
#  {'fips': 'atlarge-satellite-caucus',
#   'name': 'At-Large Satellite Caucus',
#   'votes': 0,
#   'reporting': 0,
#   'precincts': 27,
#   'results': {'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'sandersb': 0,
#    'steyert': 0,
#    'warrene': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 556,
#   'results_align1': {'warrene': 133,
#    'klobuchara': 129,
#    'buttigiegp': 97,
#    'sandersb': 92,
#    'bidenj': 88,
#    'yanga': 7,
#    'bloombergm': 4,
#    'steyert': 4,
#    'gabbardt': 1,
#    'patrickd': 1,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 540,
#   'results_alignfinal': {'klobuchara': 128,
#    'warrene': 124,
#    'buttigiegp': 105,
#    'bidenj': 98,
#    'sandersb': 85,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19009',
#   'name': 'Audubon',
#   'votes': 2.9999999999999996,
#   'reporting': 2,
#   'precincts': 2,
#   'results': {'bidenj': 0.9,
#    'klobuchara': 0.9,
#    'sandersb': 0.5,
#    'buttigiegp': 0.4,
#    'warrene': 0.3,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 203,
#   'results_align1': {'bidenj': 45,
#    'klobuchara': 42,
#    'warrene': 32,
#    'buttigiegp': 31,
#    'sandersb': 31,
#    'steyert': 11,
#    'yanga': 9,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 2,
#    'other': 0},
#   'votes_alignfinal': 203,
#   'results_alignfinal': {'bidenj': 61,
#    'klobuchara': 55,
#    'sandersb': 35,
#    'buttigiegp': 31,
#    'warrene': 21,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19011',
#   'name': 'Benton',
#   'votes': 14.26,
#   'reporting': 18,
#   'precincts': 19,
#   'results': {'bidenj': 4.65,
#    'buttigiegp': 3.98,
#    'sandersb': 3.3,
#    'klobuchara': 1.35,
#    'warrene': 0.98,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 803,
#   'results_align1': {'bidenj': 226,
#    'buttigiegp': 189,
#    'sandersb': 156,
#    'warrene': 94,
#    'klobuchara': 91,
#    'steyert': 22,
#    'yanga': 17,
#    'gabbardt': 3,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 4,
#    'other': 1},
#   'votes_alignfinal': 773,
#   'results_alignfinal': {'bidenj': 245,
#    'buttigiegp': 212,
#    'sandersb': 170,
#    'klobuchara': 77,
#    'warrene': 65,
#    'yanga': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 3,
#    'other': 0}},
#  {'fips': '19013',
#   'name': 'Black Hawk',
#   'votes': 56.970000000000006,
#   'reporting': 35,
#   'precincts': 62,
#   'results': {'sandersb': 17.98,
#    'buttigiegp': 13.74,
#    'warrene': 9.09,
#    'bidenj': 8.48,
#    'klobuchara': 6.67,
#    'steyert': 0.61,
#    'yanga': 0.4,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 4154,
#   'results_align1': {'sandersb': 1154,
#    'buttigiegp': 861,
#    'warrene': 724,
#    'bidenj': 565,
#    'klobuchara': 512,
#    'yanga': 180,
#    'steyert': 111,
#    'gabbardt': 18,
#    'bloombergm': 5,
#    'bennetm': 1,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 21,
#    'other': 2},
#   'votes_alignfinal': 4041,
#   'results_alignfinal': {'sandersb': 1265,
#    'buttigiegp': 986,
#    'warrene': 708,
#    'bidenj': 515,
#    'klobuchara': 514,
#    'steyert': 24,
#    'yanga': 16,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 11,
#    'other': 2}},
#  {'fips': '19015',
#   'name': 'Boone',
#   'votes': 16.72,
#   'reporting': 14,
#   'precincts': 15,
#   'results': {'buttigiegp': 5.32,
#    'sandersb': 4.56,
#    'warrene': 3.23,
#    'klobuchara': 2.28,
#    'bidenj': 1.14,
#    'steyert': 0.19,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 1217,
#   'results_align1': {'buttigiegp': 334,
#    'sandersb': 264,
#    'warrene': 210,
#    'klobuchara': 167,
#    'bidenj': 126,
#    'yanga': 71,
#    'steyert': 36,
#    'bennetm': 3,
#    'bloombergm': 1,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 5,
#    'other': 0},
#   'votes_alignfinal': 1210,
#   'results_alignfinal': {'buttigiegp': 400,
#    'sandersb': 292,
#    'warrene': 226,
#    'klobuchara': 172,
#    'bidenj': 80,
#    'steyert': 18,
#    'yanga': 14,
#    'bloombergm': 2,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 6,
#    'other': 0}},
#  {'fips': '19017',
#   'name': 'Bremer',
#   'votes': 15.41,
#   'reporting': 11,
#   'precincts': 13,
#   'results': {'buttigiegp': 5.21,
#    'warrene': 3.4,
#    'bidenj': 2.72,
#    'klobuchara': 2.49,
#    'sandersb': 1.59,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 1221,
#   'results_align1': {'buttigiegp': 352,
#    'warrene': 239,
#    'bidenj': 197,
#    'klobuchara': 185,
#    'sandersb': 181,
#    'yanga': 43,
#    'steyert': 18,
#    'gabbardt': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 5,
#    'other': 0},
#   'votes_alignfinal': 1218,
#   'results_alignfinal': {'buttigiegp': 390,
#    'warrene': 282,
#    'klobuchara': 188,
#    'bidenj': 178,
#    'sandersb': 164,
#    'steyert': 2,
#    'yanga': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 11,
#    'other': 2}},
#  {'fips': '19019',
#   'name': 'Buchanan',
#   'votes': 9.570000000000002,
#   'reporting': 11,
#   'precincts': 15,
#   'results': {'buttigiegp': 2.87,
#    'bidenj': 2.6,
#    'klobuchara': 1.78,
#    'sandersb': 1.09,
#    'warrene': 0.55,
#    'yanga': 0.41,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0.27,
#    'other': 0},
#   'votes_align1': 549,
#   'results_align1': {'bidenj': 146,
#    'buttigiegp': 145,
#    'klobuchara': 86,
#    'sandersb': 72,
#    'warrene': 49,
#    'yanga': 42,
#    'steyert': 5,
#    'gabbardt': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 3,
#    'other': 0},
#   'votes_alignfinal': 532,
#   'results_alignfinal': {'bidenj': 153,
#    'buttigiegp': 142,
#    'klobuchara': 98,
#    'sandersb': 61,
#    'warrene': 31,
#    'yanga': 30,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 16,
#    'other': 1}},
#  {'fips': '19021',
#   'name': 'Buena Vista',
#   'votes': 6.200000000000001,
#   'reporting': 6,
#   'precincts': 10,
#   'results': {'sandersb': 2,
#    'buttigiegp': 1.2,
#    'bidenj': 1,
#    'warrene': 1,
#    'klobuchara': 0.4,
#    'yanga': 0.4,
#    'steyert': 0.2,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 364,
#   'results_align1': {'sandersb': 87,
#    'buttigiegp': 70,
#    'bidenj': 63,
#    'warrene': 61,
#    'yanga': 48,
#    'klobuchara': 25,
#    'steyert': 9,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 1,
#    'other': 0},
#   'votes_alignfinal': 349,
#   'results_alignfinal': {'sandersb': 102,
#    'buttigiegp': 72,
#    'bidenj': 63,
#    'warrene': 59,
#    'klobuchara': 22,
#    'yanga': 22,
#    'steyert': 9,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19023',
#   'name': 'Butler',
#   'votes': 7,
#   'reporting': 8,
#   'precincts': 8,
#   'results': {'sandersb': 1.75,
#    'bidenj': 1.4,
#    'buttigiegp': 1.28,
#    'warrene': 1.28,
#    'klobuchara': 1.17,
#    'yanga': 0.12,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 428,
#   'results_align1': {'sandersb': 103,
#    'bidenj': 87,
#    'buttigiegp': 77,
#    'warrene': 69,
#    'klobuchara': 65,
#    'yanga': 14,
#    'steyert': 4,
#    'gabbardt': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 8,
#    'other': 0},
#   'votes_alignfinal': 428,
#   'results_alignfinal': {'sandersb': 109,
#    'bidenj': 86,
#    'buttigiegp': 83,
#    'warrene': 68,
#    'klobuchara': 67,
#    'yanga': 10,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 5,
#    'other': 0}},
#  {'fips': 'cd1-satellite-caucus',
#   'name': 'District 1 Satellite Caucus',
#   'votes': 0,
#   'reporting': 0,
#   'precincts': 12,
#   'results': {'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'sandersb': 0,
#    'steyert': 0,
#    'warrene': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 0,
#   'results_align1': {'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'sandersb': 0,
#    'steyert': 0,
#    'warrene': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 0,
#   'results_alignfinal': {'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'sandersb': 0,
#    'steyert': 0,
#    'warrene': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': 'cd2-satellite-caucus',
#   'name': 'District 2 Satellite Caucus',
#   'votes': 0,
#   'reporting': 0,
#   'precincts': 17,
#   'results': {'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'sandersb': 0,
#    'steyert': 0,
#    'warrene': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 15,
#   'results_align1': {'sandersb': 14,
#    'warrene': 1,
#    'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 14,
#   'results_alignfinal': {'sandersb': 14,
#    'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'warrene': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': 'cd3-satellite-caucus',
#   'name': 'District 3 Satellite Caucus',
#   'votes': 0,
#   'reporting': 0,
#   'precincts': 20,
#   'results': {'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'sandersb': 0,
#    'steyert': 0,
#    'warrene': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 0,
#   'results_align1': {'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'sandersb': 0,
#    'steyert': 0,
#    'warrene': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 0,
#   'results_alignfinal': {'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'sandersb': 0,
#    'steyert': 0,
#    'warrene': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': 'cd4-satellite-caucus',
#   'name': 'District 4 Satellite Caucus',
#   'votes': 0,
#   'reporting': 0,
#   'precincts': 11,
#   'results': {'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'sandersb': 0,
#    'steyert': 0,
#    'warrene': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 0,
#   'results_align1': {'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'sandersb': 0,
#    'steyert': 0,
#    'warrene': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 0,
#   'results_alignfinal': {'bennetm': 0,
#    'bidenj': 0,
#    'bloombergm': 0,
#    'buttigiegp': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'sandersb': 0,
#    'steyert': 0,
#    'warrene': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19025',
#   'name': 'Calhoun',
#   'votes': 4.83,
#   'reporting': 9,
#   'precincts': 10,
#   'results': {'buttigiegp': 1.83,
#    'bidenj': 1,
#    'sandersb': 0.75,
#    'warrene': 0.67,
#    'klobuchara': 0.58,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 241,
#   'results_align1': {'buttigiegp': 81,
#    'bidenj': 51,
#    'warrene': 42,
#    'sandersb': 32,
#    'klobuchara': 27,
#    'yanga': 4,
#    'bloombergm': 1,
#    'gabbardt': 1,
#    'steyert': 1,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 1,
#    'other': 0},
#   'votes_alignfinal': 240,
#   'results_alignfinal': {'buttigiegp': 89,
#    'bidenj': 51,
#    'sandersb': 37,
#    'warrene': 34,
#    'klobuchara': 28,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 1,
#    'other': 0}},
#  {'fips': '19027',
#   'name': 'Carroll',
#   'votes': 8.36,
#   'reporting': 10,
#   'precincts': 13,
#   'results': {'buttigiegp': 2.64,
#    'bidenj': 2.31,
#    'klobuchara': 1.43,
#    'sandersb': 1.32,
#    'warrene': 0.55,
#    'yanga': 0.11,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 475,
#   'results_align1': {'bidenj': 127,
#    'buttigiegp': 113,
#    'klobuchara': 85,
#    'sandersb': 74,
#    'warrene': 52,
#    'yanga': 14,
#    'steyert': 6,
#    'bloombergm': 1,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 3,
#    'other': 0},
#   'votes_alignfinal': 474,
#   'results_alignfinal': {'buttigiegp': 146,
#    'bidenj': 128,
#    'klobuchara': 90,
#    'sandersb': 73,
#    'warrene': 30,
#    'yanga': 5,
#    'bloombergm': 1,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 1,
#    'other': 0}},
#  {'fips': '19029',
#   'name': 'Cass',
#   'votes': 4.68,
#   'reporting': 11,
#   'precincts': 13,
#   'results': {'buttigiegp': 1.44,
#    'bidenj': 0.96,
#    'warrene': 0.96,
#    'klobuchara': 0.72,
#    'sandersb': 0.6,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 288,
#   'results_align1': {'buttigiegp': 68,
#    'bidenj': 58,
#    'warrene': 56,
#    'sandersb': 52,
#    'klobuchara': 42,
#    'yanga': 7,
#    'bloombergm': 1,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 4,
#    'other': 0},
#   'votes_alignfinal': 286,
#   'results_alignfinal': {'buttigiegp': 74,
#    'bidenj': 60,
#    'warrene': 60,
#    'sandersb': 48,
#    'klobuchara': 42,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 2,
#    'other': 0}},
#  {'fips': '19031',
#   'name': 'Cedar',
#   'votes': 10.970000000000002,
#   'reporting': 10,
#   'precincts': 12,
#   'results': {'buttigiegp': 2.91,
#    'sandersb': 2.4,
#    'warrene': 2.23,
#    'klobuchara': 2.06,
#    'bidenj': 1.37,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 797,
#   'results_align1': {'buttigiegp': 191,
#    'sandersb': 190,
#    'warrene': 154,
#    'klobuchara': 123,
#    'bidenj': 103,
#    'yanga': 14,
#    'steyert': 12,
#    'bloombergm': 2,
#    'gabbardt': 2,
#    'bennetm': 1,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 5,
#    'other': 0},
#   'votes_alignfinal': 767,
#   'results_alignfinal': {'sandersb': 192,
#    'buttigiegp': 190,
#    'warrene': 154,
#    'klobuchara': 142,
#    'bidenj': 89,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19033',
#   'name': 'Cerro Gordo',
#   'votes': 25.869999999999997,
#   'reporting': 19,
#   'precincts': 26,
#   'results': {'buttigiegp': 7.97,
#    'klobuchara': 6.73,
#    'sandersb': 4.96,
#    'bidenj': 4.61,
#    'warrene': 1.42,
#    'yanga': 0.18,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 1569,
#   'results_align1': {'buttigiegp': 377,
#    'klobuchara': 339,
#    'sandersb': 294,
#    'bidenj': 275,
#    'warrene': 152,
#    'yanga': 100,
#    'steyert': 15,
#    'bloombergm': 7,
#    'gabbardt': 5,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 5,
#    'other': 0},
#   'votes_alignfinal': 1545,
#   'results_alignfinal': {'buttigiegp': 461,
#    'klobuchara': 387,
#    'sandersb': 302,
#    'bidenj': 273,
#    'warrene': 95,
#    'yanga': 16,
#    'steyert': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 10,
#    'other': 0}},
#  {'fips': '19035',
#   'name': 'Cherokee',
#   'votes': 2.52,
#   'reporting': 3,
#   'precincts': 7,
#   'results': {'bidenj': 0.76,
#    'sandersb': 0.55,
#    'buttigiegp': 0.44,
#    'klobuchara': 0.22,
#    'warrene': 0.22,
#    'yanga': 0.22,
#    'steyert': 0.11,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 125,
#   'results_align1': {'bidenj': 31,
#    'sandersb': 31,
#    'buttigiegp': 20,
#    'klobuchara': 17,
#    'yanga': 10,
#    'warrene': 9,
#    'steyert': 6,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 1,
#    'other': 0},
#   'votes_alignfinal': 122,
#   'results_alignfinal': {'bidenj': 39,
#    'sandersb': 25,
#    'buttigiegp': 21,
#    'klobuchara': 13,
#    'yanga': 11,
#    'warrene': 8,
#    'steyert': 4,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 1,
#    'other': 0}},
#  {'fips': '19037',
#   'name': 'Chickasaw',
#   'votes': 5.32,
#   'reporting': 10,
#   'precincts': 13,
#   'results': {'buttigiegp': 1.82,
#    'warrene': 1.12,
#    'bidenj': 1.05,
#    'klobuchara': 0.7,
#    'sandersb': 0.42,
#    'steyert': 0.21,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 271,
#   'results_align1': {'buttigiegp': 83,
#    'bidenj': 53,
#    'warrene': 50,
#    'klobuchara': 33,
#    'sandersb': 27,
#    'steyert': 16,
#    'yanga': 6,
#    'bloombergm': 1,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 2,
#    'other': 0},
#   'votes_alignfinal': 271,
#   'results_alignfinal': {'buttigiegp': 98,
#    'warrene': 58,
#    'bidenj': 53,
#    'klobuchara': 33,
#    'sandersb': 19,
#    'steyert': 10,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19039',
#   'name': 'Clarke',
#   'votes': 3.5199999999999996,
#   'reporting': 6,
#   'precincts': 7,
#   'results': {'buttigiegp': 1.04,
#    'sandersb': 0.88,
#    'klobuchara': 0.72,
#    'bidenj': 0.4,
#    'yanga': 0.32,
#    'warrene': 0.16,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 227,
#   'results_align1': {'buttigiegp': 54,
#    'sandersb': 52,
#    'bidenj': 33,
#    'klobuchara': 33,
#    'warrene': 27,
#    'yanga': 22,
#    'steyert': 6,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 226,
#   'results_alignfinal': {'buttigiegp': 63,
#    'sandersb': 58,
#    'klobuchara': 48,
#    'yanga': 26,
#    'bidenj': 24,
#    'warrene': 7,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19041',
#   'name': 'Clay',
#   'votes': 7.0600000000000005,
#   'reporting': 9,
#   'precincts': 12,
#   'results': {'bidenj': 1.79,
#    'buttigiegp': 1.79,
#    'sandersb': 1.51,
#    'klobuchara': 1.32,
#    'warrene': 0.56,
#    'yanga': 0.09,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 460,
#   'results_align1': {'bidenj': 105,
#    'sandersb': 96,
#    'buttigiegp': 92,
#    'klobuchara': 80,
#    'warrene': 63,
#    'yanga': 20,
#    'steyert': 2,
#    'bennetm': 1,
#    'bloombergm': 1,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 450,
#   'results_alignfinal': {'bidenj': 116,
#    'buttigiegp': 106,
#    'sandersb': 96,
#    'klobuchara': 88,
#    'warrene': 37,
#    'yanga': 6,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 1,
#    'other': 0}},
#  {'fips': '19043',
#   'name': 'Clayton',
#   'votes': 9,
#   'reporting': 11,
#   'precincts': 14,
#   'results': {'buttigiegp': 3.5,
#    'klobuchara': 2,
#    'sandersb': 1.67,
#    'bidenj': 1.5,
#    'warrene': 0.33,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 583,
#   'results_align1': {'buttigiegp': 199,
#    'klobuchara': 101,
#    'bidenj': 98,
#    'sandersb': 98,
#    'warrene': 56,
#    'steyert': 19,
#    'yanga': 3,
#    'gabbardt': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 7,
#    'other': 1},
#   'votes_alignfinal': 569,
#   'results_alignfinal': {'buttigiegp': 211,
#    'klobuchara': 127,
#    'sandersb': 110,
#    'bidenj': 92,
#    'warrene': 18,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 11,
#    'other': 0}},
#  {'fips': '19045',
#   'name': 'Clinton',
#   'votes': 29.229999999999997,
#   'reporting': 24,
#   'precincts': 26,
#   'results': {'buttigiegp': 8.41,
#    'sandersb': 7.53,
#    'bidenj': 7.31,
#    'klobuchara': 2.88,
#    'warrene': 2.88,
#    'yanga': 0.22,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 1609,
#   'results_align1': {'sandersb': 367,
#    'buttigiegp': 351,
#    'bidenj': 342,
#    'warrene': 219,
#    'klobuchara': 174,
#    'yanga': 88,
#    'steyert': 47,
#    'bloombergm': 3,
#    'gabbardt': 3,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 15,
#    'other': 0},
#   'votes_alignfinal': 1571,
#   'results_alignfinal': {'buttigiegp': 435,
#    'sandersb': 405,
#    'bidenj': 381,
#    'warrene': 161,
#    'klobuchara': 152,
#    'yanga': 18,
#    'steyert': 9,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 10,
#    'other': 0}},
#  {'fips': '19047',
#   'name': 'Crawford',
#   'votes': 3.9000000000000004,
#   'reporting': 5,
#   'precincts': 8,
#   'results': {'bidenj': 1.8,
#    'sandersb': 0.9,
#    'buttigiegp': 0.45,
#    'klobuchara': 0.45,
#    'warrene': 0.15,
#    'yanga': 0.15,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 220,
#   'results_align1': {'bidenj': 73,
#    'sandersb': 62,
#    'buttigiegp': 26,
#    'yanga': 22,
#    'klobuchara': 18,
#    'warrene': 11,
#    'steyert': 4,
#    'gabbardt': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 3,
#    'other': 0},
#   'votes_alignfinal': 219,
#   'results_alignfinal': {'bidenj': 86,
#    'sandersb': 60,
#    'buttigiegp': 32,
#    'klobuchara': 16,
#    'yanga': 16,
#    'warrene': 9,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19049',
#   'name': 'Dallas',
#   'votes': 52.199999999999996,
#   'reporting': 29,
#   'precincts': 34,
#   'results': {'buttigiegp': 18.23,
#    'warrene': 10.77,
#    'bidenj': 10.36,
#    'sandersb': 7.04,
#    'klobuchara': 5.8,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 5294,
#   'results_align1': {'buttigiegp': 1518,
#    'bidenj': 961,
#    'warrene': 952,
#    'sandersb': 848,
#    'klobuchara': 660,
#    'yanga': 271,
#    'steyert': 45,
#    'bloombergm': 6,
#    'bennetm': 3,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 23,
#    'other': 7},
#   'votes_alignfinal': 5236,
#   'results_alignfinal': {'buttigiegp': 1780,
#    'warrene': 1079,
#    'bidenj': 1000,
#    'sandersb': 774,
#    'klobuchara': 541,
#    'yanga': 48,
#    'steyert': 4,
#    'bloombergm': 1,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 9,
#    'other': 0}},
#  {'fips': '19051',
#   'name': 'Davis',
#   'votes': 2.6399999999999997,
#   'reporting': 7,
#   'precincts': 8,
#   'results': {'buttigiegp': 0.96,
#    'bidenj': 0.75,
#    'warrene': 0.39,
#    'klobuchara': 0.3,
#    'sandersb': 0.24,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 172,
#   'results_align1': {'bidenj': 50,
#    'buttigiegp': 48,
#    'klobuchara': 24,
#    'sandersb': 24,
#    'warrene': 20,
#    'steyert': 4,
#    'bloombergm': 1,
#    'gabbardt': 1,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 172,
#   'results_alignfinal': {'buttigiegp': 55,
#    'bidenj': 51,
#    'warrene': 28,
#    'klobuchara': 21,
#    'sandersb': 16,
#    'gabbardt': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19053',
#   'name': 'Decatur',
#   'votes': 2.8200000000000003,
#   'reporting': 5,
#   'precincts': 7,
#   'results': {'buttigiegp': 0.75,
#    'sandersb': 0.75,
#    'warrene': 0.56,
#    'klobuchara': 0.52,
#    'bidenj': 0.24,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 272,
#   'results_align1': {'warrene': 62,
#    'sandersb': 59,
#    'buttigiegp': 55,
#    'klobuchara': 45,
#    'bidenj': 27,
#    'yanga': 10,
#    'steyert': 8,
#    'gabbardt': 2,
#    'bennetm': 1,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 1,
#    'other': 2},
#   'votes_alignfinal': 272,
#   'results_alignfinal': {'sandersb': 69,
#    'warrene': 68,
#    'klobuchara': 63,
#    'buttigiegp': 61,
#    'bidenj': 8,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 1,
#    'other': 2}},
#  {'fips': '19055',
#   'name': 'Delaware',
#   'votes': 7.66,
#   'reporting': 10,
#   'precincts': 12,
#   'results': {'buttigiegp': 2.03,
#    'klobuchara': 1.8,
#    'warrene': 1.8,
#    'bidenj': 1.5,
#    'sandersb': 0.38,
#    'steyert': 0.15,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 376,
#   'results_align1': {'bidenj': 87,
#    'buttigiegp': 84,
#    'klobuchara': 71,
#    'warrene': 70,
#    'sandersb': 37,
#    'steyert': 24,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'yanga': 0,
#    'uncommitted': 3,
#    'other': 0},
#   'votes_alignfinal': 367,
#   'results_alignfinal': {'buttigiegp': 97,
#    'klobuchara': 84,
#    'warrene': 81,
#    'bidenj': 74,
#    'sandersb': 18,
#    'steyert': 9,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'yanga': 0,
#    'uncommitted': 4,
#    'other': 0}},
#  {'fips': '19057',
#   'name': 'Des Moines',
#   'votes': 20.16,
#   'reporting': 12,
#   'precincts': 16,
#   'results': {'buttigiegp': 7.2,
#    'sandersb': 5.04,
#    'bidenj': 4.32,
#    'warrene': 2.52,
#    'yanga': 0.72,
#    'klobuchara': 0.36,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 1198,
#   'results_align1': {'buttigiegp': 344,
#    'sandersb': 256,
#    'bidenj': 236,
#    'warrene': 177,
#    'klobuchara': 76,
#    'yanga': 65,
#    'steyert': 23,
#    'gabbardt': 4,
#    'bennetm': 3,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 12,
#    'other': 2},
#   'votes_alignfinal': 1171,
#   'results_alignfinal': {'buttigiegp': 407,
#    'sandersb': 266,
#    'bidenj': 253,
#    'warrene': 184,
#    'yanga': 32,
#    'klobuchara': 15,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 14,
#    'other': 0}},
#  {'fips': '19059',
#   'name': 'Dickinson',
#   'votes': 7.01,
#   'reporting': 12,
#   'precincts': 15,
#   'results': {'buttigiegp': 1.88,
#    'sandersb': 1.75,
#    'bidenj': 1.5,
#    'klobuchara': 1.38,
#    'warrene': 0.5,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 447,
#   'results_align1': {'buttigiegp': 110,
#    'bidenj': 95,
#    'sandersb': 90,
#    'klobuchara': 82,
#    'warrene': 47,
#    'steyert': 12,
#    'yanga': 11,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 445,
#   'results_alignfinal': {'buttigiegp': 127,
#    'bidenj': 102,
#    'sandersb': 97,
#    'klobuchara': 85,
#    'warrene': 30,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 4,
#    'other': 0}},
#  {'fips': '19061',
#   'name': 'Dubuque',
#   'votes': 44.800000000000004,
#   'reporting': 22,
#   'precincts': 35,
#   'results': {'buttigiegp': 12.8,
#    'sandersb': 10.93,
#    'bidenj': 9.87,
#    'warrene': 8,
#    'klobuchara': 2.93,
#    'yanga': 0.27,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 3255,
#   'results_align1': {'sandersb': 754,
#    'buttigiegp': 751,
#    'bidenj': 637,
#    'warrene': 545,
#    'klobuchara': 340,
#    'yanga': 154,
#    'steyert': 36,
#    'gabbardt': 16,
#    'bloombergm': 4,
#    'bennetm': 1,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 13,
#    'other': 4},
#   'votes_alignfinal': 3189,
#   'results_alignfinal': {'buttigiegp': 868,
#    'sandersb': 778,
#    'bidenj': 682,
#    'warrene': 577,
#    'klobuchara': 229,
#    'yanga': 27,
#    'gabbardt': 1,
#    'steyert': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 20,
#    'other': 6}},
#  {'fips': '19063',
#   'name': 'Emmet',
#   'votes': 3.4299999999999997,
#   'reporting': 8,
#   'precincts': 11,
#   'results': {'buttigiegp': 1.14,
#    'sandersb': 0.8,
#    'bidenj': 0.46,
#    'warrene': 0.46,
#    'klobuchara': 0.34,
#    'steyert': 0.23,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 211,
#   'results_align1': {'sandersb': 58,
#    'buttigiegp': 46,
#    'klobuchara': 33,
#    'bidenj': 29,
#    'warrene': 27,
#    'steyert': 11,
#    'yanga': 5,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 2,
#    'other': 0},
#   'votes_alignfinal': 208,
#   'results_alignfinal': {'buttigiegp': 66,
#    'sandersb': 58,
#    'warrene': 28,
#    'bidenj': 24,
#    'klobuchara': 21,
#    'steyert': 11,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19065',
#   'name': 'Fayette',
#   'votes': 9.959999999999997,
#   'reporting': 19,
#   'precincts': 25,
#   'results': {'buttigiegp': 3.6,
#    'bidenj': 2.16,
#    'sandersb': 1.68,
#    'klobuchara': 1.2,
#    'warrene': 0.84,
#    'steyert': 0.36,
#    'yanga': 0.12,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 583,
#   'results_align1': {'buttigiegp': 177,
#    'bidenj': 116,
#    'sandersb': 90,
#    'klobuchara': 77,
#    'warrene': 68,
#    'yanga': 28,
#    'steyert': 18,
#    'gabbardt': 2,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 7,
#    'other': 0},
#   'votes_alignfinal': 574,
#   'results_alignfinal': {'buttigiegp': 211,
#    'bidenj': 119,
#    'sandersb': 93,
#    'klobuchara': 74,
#    'warrene': 51,
#    'steyert': 13,
#    'yanga': 7,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 6,
#    'other': 0}},
#  {'fips': '19067',
#   'name': 'Floyd',
#   'votes': 9.11,
#   'reporting': 7,
#   'precincts': 8,
#   'results': {'buttigiegp': 2.22,
#    'klobuchara': 2.11,
#    'bidenj': 1.89,
#    'sandersb': 1.56,
#    'warrene': 1.33,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 557,
#   'results_align1': {'buttigiegp': 122,
#    'klobuchara': 117,
#    'bidenj': 115,
#    'warrene': 92,
#    'sandersb': 78,
#    'yanga': 21,
#    'steyert': 5,
#    'bloombergm': 2,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 5,
#    'other': 0},
#   'votes_alignfinal': 553,
#   'results_alignfinal': {'buttigiegp': 133,
#    'klobuchara': 132,
#    'bidenj': 110,
#    'warrene': 91,
#    'sandersb': 81,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 6,
#    'other': 0}},
#  {'fips': '19069',
#   'name': 'Franklin',
#   'votes': 4.779999999999999,
#   'reporting': 11,
#   'precincts': 12,
#   'results': {'buttigiegp': 1.28,
#    'sandersb': 1.28,
#    'bidenj': 0.94,
#    'klobuchara': 0.72,
#    'warrene': 0.39,
#    'steyert': 0.11,
#    'yanga': 0.06,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 245,
#   'results_align1': {'sandersb': 63,
#    'buttigiegp': 61,
#    'bidenj': 45,
#    'klobuchara': 35,
#    'warrene': 27,
#    'steyert': 7,
#    'yanga': 7,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 243,
#   'results_alignfinal': {'sandersb': 72,
#    'buttigiegp': 65,
#    'bidenj': 44,
#    'klobuchara': 37,
#    'warrene': 19,
#    'steyert': 3,
#    'yanga': 3,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19071',
#   'name': 'Fremont',
#   'votes': 2.49,
#   'reporting': 4,
#   'precincts': 5,
#   'results': {'buttigiegp': 0.68,
#    'klobuchara': 0.6,
#    'sandersb': 0.6,
#    'bidenj': 0.53,
#    'warrene': 0.08,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 161,
#   'results_align1': {'buttigiegp': 39,
#    'klobuchara': 35,
#    'bidenj': 33,
#    'sandersb': 31,
#    'warrene': 19,
#    'bennetm': 1,
#    'yanga': 1,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 2,
#    'other': 0},
#   'votes_alignfinal': 161,
#   'results_alignfinal': {'buttigiegp': 44,
#    'klobuchara': 39,
#    'sandersb': 39,
#    'bidenj': 38,
#    'warrene': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19073',
#   'name': 'Greene',
#   'votes': 6,
#   'reporting': 7,
#   'precincts': 7,
#   'results': {'buttigiegp': 2.04,
#    'sandersb': 1.8,
#    'klobuchara': 1.2,
#    'bidenj': 0.72,
#    'steyert': 0.12,
#    'warrene': 0.12,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 362,
#   'results_align1': {'buttigiegp': 99,
#    'sandersb': 82,
#    'klobuchara': 62,
#    'bidenj': 54,
#    'warrene': 34,
#    'yanga': 15,
#    'steyert': 10,
#    'bennetm': 2,
#    'bloombergm': 1,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 3,
#    'other': 0},
#   'votes_alignfinal': 358,
#   'results_alignfinal': {'buttigiegp': 112,
#    'sandersb': 94,
#    'klobuchara': 76,
#    'bidenj': 53,
#    'warrene': 16,
#    'steyert': 5,
#    'yanga': 2,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19075',
#   'name': 'Grundy',
#   'votes': 3.2,
#   'reporting': 5,
#   'precincts': 7,
#   'results': {'buttigiegp': 1,
#    'bidenj': 0.7,
#    'klobuchara': 0.6,
#    'sandersb': 0.6,
#    'warrene': 0.2,
#    'yanga': 0.1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 185,
#   'results_align1': {'buttigiegp': 43,
#    'sandersb': 37,
#    'bidenj': 27,
#    'klobuchara': 27,
#    'warrene': 22,
#    'steyert': 11,
#    'yanga': 9,
#    'gabbardt': 2,
#    'patrickd': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'uncommitted': 6,
#    'other': 0},
#   'votes_alignfinal': 179,
#   'results_alignfinal': {'buttigiegp': 50,
#    'sandersb': 44,
#    'bidenj': 38,
#    'klobuchara': 30,
#    'warrene': 11,
#    'yanga': 6,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19077',
#   'name': 'Guthrie',
#   'votes': 4.630000000000001,
#   'reporting': 6,
#   'precincts': 8,
#   'results': {'buttigiegp': 1.29,
#    'klobuchara': 1.2,
#    'warrene': 1.03,
#    'yanga': 0.43,
#    'bidenj': 0.34,
#    'sandersb': 0.34,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 286,
#   'results_align1': {'klobuchara': 69,
#    'buttigiegp': 64,
#    'warrene': 55,
#    'bidenj': 41,
#    'sandersb': 33,
#    'yanga': 13,
#    'steyert': 8,
#    'bennetm': 1,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 2,
#    'other': 0},
#   'votes_alignfinal': 279,
#   'results_alignfinal': {'klobuchara': 77,
#    'buttigiegp': 69,
#    'warrene': 61,
#    'yanga': 29,
#    'bidenj': 23,
#    'sandersb': 19,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 1,
#    'other': 0}},
#  {'fips': '19079',
#   'name': 'Hamilton',
#   'votes': 9,
#   'reporting': 8,
#   'precincts': 8,
#   'results': {'buttigiegp': 2.7,
#    'bidenj': 1.9,
#    'warrene': 1.7,
#    'sandersb': 1.5,
#    'klobuchara': 1.2,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 543,
#   'results_align1': {'buttigiegp': 147,
#    'warrene': 103,
#    'bidenj': 99,
#    'sandersb': 91,
#    'klobuchara': 77,
#    'steyert': 12,
#    'yanga': 4,
#    'bloombergm': 1,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 8,
#    'other': 1},
#   'votes_alignfinal': 541,
#   'results_alignfinal': {'buttigiegp': 162,
#    'bidenj': 107,
#    'warrene': 101,
#    'sandersb': 95,
#    'klobuchara': 74,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 2,
#    'other': 0}},
#  {'fips': '19081',
#   'name': 'Hancock',
#   'votes': 4.9,
#   'reporting': 9,
#   'precincts': 10,
#   'results': {'buttigiegp': 1.7,
#    'klobuchara': 1.2,
#    'bidenj': 0.8,
#    'sandersb': 0.8,
#    'warrene': 0.4,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 266,
#   'results_align1': {'buttigiegp': 77,
#    'klobuchara': 61,
#    'sandersb': 47,
#    'bidenj': 38,
#    'warrene': 29,
#    'yanga': 10,
#    'steyert': 2,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 2},
#   'votes_alignfinal': 261,
#   'results_alignfinal': {'buttigiegp': 85,
#    'klobuchara': 70,
#    'sandersb': 44,
#    'bidenj': 41,
#    'warrene': 20,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 1,
#    'other': 0}},
#  {'fips': '19083',
#   'name': 'Hardin',
#   'votes': 7.409999999999999,
#   'reporting': 7,
#   'precincts': 8,
#   'results': {'buttigiegp': 2.09,
#    'bidenj': 1.58,
#    'klobuchara': 1.44,
#    'warrene': 1.22,
#    'sandersb': 1.08,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 448,
#   'results_align1': {'buttigiegp': 115,
#    'bidenj': 94,
#    'klobuchara': 78,
#    'sandersb': 69,
#    'warrene': 69,
#    'yanga': 12,
#    'steyert': 11,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 448,
#   'results_alignfinal': {'buttigiegp': 125,
#    'bidenj': 96,
#    'warrene': 82,
#    'klobuchara': 75,
#    'sandersb': 68,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 2,
#    'other': 0}},
#  {'fips': '19085',
#   'name': 'Harrison',
#   'votes': 4.7700000000000005,
#   'reporting': 10,
#   'precincts': 13,
#   'results': {'buttigiegp': 1.31,
#    'sandersb': 1.31,
#    'bidenj': 0.93,
#    'klobuchara': 0.75,
#    'warrene': 0.47,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 285,
#   'results_align1': {'buttigiegp': 71,
#    'sandersb': 63,
#    'bidenj': 52,
#    'klobuchara': 44,
#    'warrene': 36,
#    'yanga': 13,
#    'steyert': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 5,
#    'other': 0},
#   'votes_alignfinal': 277,
#   'results_alignfinal': {'buttigiegp': 76,
#    'sandersb': 71,
#    'bidenj': 54,
#    'klobuchara': 46,
#    'warrene': 30,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19087',
#   'name': 'Henry',
#   'votes': 7.130000000000001,
#   'reporting': 7,
#   'precincts': 9,
#   'results': {'buttigiegp': 1.8,
#    'sandersb': 1.33,
#    'bidenj': 1.27,
#    'warrene': 1.2,
#    'yanga': 0.8,
#    'klobuchara': 0.73,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 503,
#   'results_align1': {'buttigiegp': 108,
#    'sandersb': 97,
#    'bidenj': 92,
#    'warrene': 86,
#    'yanga': 62,
#    'klobuchara': 46,
#    'steyert': 6,
#    'bennetm': 1,
#    'bloombergm': 1,
#    'gabbardt': 1,
#    'delaneyj': 0,
# ...
#    'sandersb': 42,
#    'bidenj': 41,
#    'warrene': 40,
#    'yanga': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 3,
#    'other': 0}},
#  {'fips': '19167',
#   'name': 'Sioux',
#   'votes': 4.82,
#   'reporting': 13,
#   'precincts': 16,
#   'results': {'klobuchara': 1.4,
#    'warrene': 1.14,
#    'buttigiegp': 0.7,
#    'sandersb': 0.61,
#    'bidenj': 0.53,
#    'yanga': 0.44,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 471,
#   'results_align1': {'klobuchara': 118,
#    'warrene': 109,
#    'buttigiegp': 68,
#    'yanga': 64,
#    'sandersb': 61,
#    'bidenj': 48,
#    'steyert': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 1,
#    'other': 1},
#   'votes_alignfinal': 467,
#   'results_alignfinal': {'klobuchara': 134,
#    'warrene': 133,
#    'buttigiegp': 62,
#    'yanga': 56,
#    'sandersb': 42,
#    'bidenj': 38,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 2,
#    'other': 0}},
#  {'fips': '19169',
#   'name': 'Story',
#   'votes': 64.35,
#   'reporting': 33,
#   'precincts': 43,
#   'results': {'sandersb': 20.34,
#    'warrene': 16.6,
#    'klobuchara': 12.04,
#    'buttigiegp': 11.62,
#    'bidenj': 2.08,
#    'yanga': 1.25,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0.42,
#    'other': 0},
#   'votes_align1': 7661,
#   'results_align1': {'sandersb': 2400,
#    'warrene': 1600,
#    'buttigiegp': 1129,
#    'klobuchara': 1050,
#    'bidenj': 675,
#    'yanga': 634,
#    'steyert': 110,
#    'gabbardt': 12,
#    'bennetm': 4,
#    'bloombergm': 3,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 40,
#    'other': 4},
#   'votes_alignfinal': 7374,
#   'results_alignfinal': {'sandersb': 2648,
#    'warrene': 1874,
#    'klobuchara': 1208,
#    'buttigiegp': 1062,
#    'bidenj': 228,
#    'yanga': 173,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 181,
#    'other': 0}},
#  {'fips': '19171',
#   'name': 'Tama',
#   'votes': 9.46,
#   'reporting': 11,
#   'precincts': 15,
#   'results': {'sandersb': 2.72,
#    'buttigiegp': 2.59,
#    'bidenj': 2.07,
#    'warrene': 1.04,
#    'klobuchara': 0.52,
#    'steyert': 0.26,
#    'yanga': 0.26,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 515,
#   'results_align1': {'sandersb': 140,
#    'buttigiegp': 108,
#    'bidenj': 97,
#    'warrene': 70,
#    'klobuchara': 44,
#    'steyert': 25,
#    'yanga': 15,
#    'bennetm': 2,
#    'gabbardt': 2,
#    'bloombergm': 1,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 11,
#    'other': 0},
#   'votes_alignfinal': 505,
#   'results_alignfinal': {'sandersb': 150,
#    'buttigiegp': 137,
#    'bidenj': 110,
#    'warrene': 57,
#    'klobuchara': 22,
#    'yanga': 14,
#    'steyert': 12,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 3,
#    'other': 0}},
#  {'fips': '19173',
#   'name': 'Taylor',
#   'votes': 3,
#   'reporting': 7,
#   'precincts': 7,
#   'results': {'buttigiegp': 0.9,
#    'bidenj': 0.6,
#    'sandersb': 0.5,
#    'klobuchara': 0.4,
#    'warrene': 0.4,
#    'yanga': 0.2,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 97,
#   'results_align1': {'buttigiegp': 29,
#    'bidenj': 24,
#    'sandersb': 13,
#    'klobuchara': 12,
#    'warrene': 11,
#    'yanga': 7,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 1,
#    'other': 0},
#   'votes_alignfinal': 96,
#   'results_alignfinal': {'buttigiegp': 30,
#    'bidenj': 22,
#    'sandersb': 14,
#    'klobuchara': 12,
#    'warrene': 11,
#    'yanga': 6,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 1,
#    'other': 0}},
#  {'fips': '19175',
#   'name': 'Union',
#   'votes': 5.87,
#   'reporting': 7,
#   'precincts': 8,
#   'results': {'sandersb': 1.88,
#    'buttigiegp': 1.58,
#    'warrene': 0.83,
#    'klobuchara': 0.75,
#    'bidenj': 0.68,
#    'yanga': 0.15,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 337,
#   'results_align1': {'buttigiegp': 85,
#    'sandersb': 82,
#    'bidenj': 48,
#    'warrene': 45,
#    'klobuchara': 36,
#    'yanga': 26,
#    'steyert': 12,
#    'gabbardt': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 2,
#    'other': 0},
#   'votes_alignfinal': 328,
#   'results_alignfinal': {'sandersb': 98,
#    'buttigiegp': 92,
#    'warrene': 48,
#    'bidenj': 41,
#    'klobuchara': 38,
#    'yanga': 7,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 4,
#    'other': 0}},
#  {'fips': '19177',
#   'name': 'Van Buren',
#   'votes': 0.8,
#   'reporting': 3,
#   'precincts': 8,
#   'results': {'bidenj': 0.2,
#    'buttigiegp': 0.2,
#    'sandersb': 0.2,
#    'warrene': 0.2,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 35,
#   'results_align1': {'sandersb': 11,
#    'buttigiegp': 10,
#    'bidenj': 7,
#    'warrene': 5,
#    'klobuchara': 2,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_alignfinal': 33,
#   'results_alignfinal': {'buttigiegp': 10,
#    'sandersb': 10,
#    'bidenj': 9,
#    'warrene': 4,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0}},
#  {'fips': '19179',
#   'name': 'Wapello',
#   'votes': 15.479999999999999,
#   'reporting': 17,
#   'precincts': 22,
#   'results': {'buttigiegp': 4.77,
#    'sandersb': 4.68,
#    'bidenj': 3.51,
#    'warrene': 2.16,
#    'yanga': 0.27,
#    'steyert': 0.09,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 940,
#   'results_align1': {'sandersb': 257,
#    'buttigiegp': 250,
#    'bidenj': 201,
#    'warrene': 141,
#    'klobuchara': 33,
#    'yanga': 31,
#    'steyert': 22,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 4,
#    'other': 1},
#   'votes_alignfinal': 931,
#   'results_alignfinal': {'buttigiegp': 286,
#    'sandersb': 274,
#    'bidenj': 211,
#    'warrene': 141,
#    'yanga': 14,
#    'steyert': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'klobuchara': 0,
#    'patrickd': 0,
#    'uncommitted': 4,
#    'other': 0}},
#  {'fips': '19181',
#   'name': 'Warren',
#   'votes': 31.97,
#   'reporting': 26,
#   'precincts': 31,
#   'results': {'buttigiegp': 11.2,
#    'warrene': 6.77,
#    'sandersb': 5.6,
#    'klobuchara': 4.43,
#    'bidenj': 3.97,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 2653,
#   'results_align1': {'buttigiegp': 840,
#    'warrene': 429,
#    'sandersb': 406,
#    'bidenj': 381,
#    'klobuchara': 342,
#    'steyert': 103,
#    'yanga': 82,
#    'patrickd': 41,
#    'gabbardt': 5,
#    'bennetm': 4,
#    'bloombergm': 2,
#    'delaneyj': 0,
#    'uncommitted': 17,
#    'other': 1},
#   'votes_alignfinal': 2642,
#   'results_alignfinal': {'buttigiegp': 983,
#    'warrene': 522,
#    'sandersb': 416,
#    'klobuchara': 358,
#    'bidenj': 324,
#    'yanga': 3,
#    'gabbardt': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 28,
#    'other': 7}},
#  {'fips': '19183',
#   'name': 'Washington',
#   'votes': 8.73,
#   'reporting': 7,
#   'precincts': 10,
#   'results': {'sandersb': 2.6,
#    'warrene': 1.86,
#    'buttigiegp': 1.67,
#    'klobuchara': 1.67,
#    'bidenj': 0.93,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 696,
#   'results_align1': {'sandersb': 186,
#    'warrene': 135,
#    'buttigiegp': 123,
#    'klobuchara': 112,
#    'bidenj': 92,
#    'yanga': 20,
#    'steyert': 19,
#    'gabbardt': 2,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 7,
#    'other': 0},
#   'votes_alignfinal': 690,
#   'results_alignfinal': {'sandersb': 188,
#    'warrene': 151,
#    'klobuchara': 139,
#    'buttigiegp': 137,
#    'bidenj': 70,
#    'gabbardt': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 1,
#    'other': 3}},
#  {'fips': '19185',
#   'name': 'Wayne',
#   'votes': 3.0200000000000005,
#   'reporting': 4,
#   'precincts': 4,
#   'results': {'klobuchara': 0.98,
#    'warrene': 0.6,
#    'buttigiegp': 0.53,
#    'sandersb': 0.53,
#    'bidenj': 0.38,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 135,
#   'results_align1': {'klobuchara': 37,
#    'buttigiegp': 25,
#    'sandersb': 25,
#    'warrene': 23,
#    'bidenj': 19,
#    'yanga': 3,
#    'steyert': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 2,
#    'other': 0},
#   'votes_alignfinal': 135,
#   'results_alignfinal': {'klobuchara': 41,
#    'buttigiegp': 26,
#    'warrene': 26,
#    'sandersb': 25,
#    'bidenj': 16,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 1,
#    'other': 0}},
#  {'fips': '19187',
#   'name': 'Webster',
#   'votes': 18.840000000000003,
#   'reporting': 25,
#   'precincts': 28,
#   'results': {'buttigiegp': 7.58,
#    'bidenj': 4.42,
#    'sandersb': 3.92,
#    'warrene': 1.5,
#    'klobuchara': 1.25,
#    'steyert': 0.17,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 1103,
#   'results_align1': {'buttigiegp': 354,
#    'bidenj': 223,
#    'sandersb': 197,
#    'warrene': 127,
#    'klobuchara': 119,
#    'steyert': 38,
#    'yanga': 31,
#    'bennetm': 5,
#    'gabbardt': 3,
#    'bloombergm': 1,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 4,
#    'other': 1},
#   'votes_alignfinal': 1132,
#   'results_alignfinal': {'buttigiegp': 449,
#    'bidenj': 263,
#    'sandersb': 218,
#    'warrene': 102,
#    'klobuchara': 86,
#    'steyert': 6,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'yanga': 0,
#    'uncommitted': 8,
#    'other': 0}},
#  {'fips': '19189',
#   'name': 'Winnebago',
#   'votes': 4.95,
#   'reporting': 8,
#   'precincts': 10,
#   'results': {'buttigiegp': 1.8,
#    'warrene': 0.9,
#    'klobuchara': 0.75,
#    'sandersb': 0.6,
#    'bidenj': 0.45,
#    'yanga': 0.45,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 325,
#   'results_align1': {'buttigiegp': 96,
#    'klobuchara': 55,
#    'warrene': 54,
#    'sandersb': 42,
#    'bidenj': 41,
#    'yanga': 30,
#    'gabbardt': 1,
#    'steyert': 1,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 5,
#    'other': 0},
#   'votes_alignfinal': 324,
#   'results_alignfinal': {'buttigiegp': 105,
#    'warrene': 69,
#    'klobuchara': 58,
#    'sandersb': 33,
#    'yanga': 29,
#    'bidenj': 24,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 6,
#    'other': 0}},
#  {'fips': '19191',
#   'name': 'Winneshiek',
#   'votes': 13.44,
#   'reporting': 8,
#   'precincts': 11,
#   'results': {'buttigiegp': 3.97,
#    'klobuchara': 3.46,
#    'sandersb': 2.94,
#    'warrene': 2.18,
#    'yanga': 0.51,
#    'bidenj': 0.38,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 1590,
#   'results_align1': {'buttigiegp': 375,
#    'sandersb': 325,
#    'klobuchara': 311,
#    'warrene': 286,
#    'yanga': 142,
#    'bidenj': 130,
#    'steyert': 12,
#    'gabbardt': 3,
#    'bennetm': 1,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 5,
#    'other': 0},
#   'votes_alignfinal': 1565,
#   'results_alignfinal': {'buttigiegp': 448,
#    'klobuchara': 397,
#    'sandersb': 358,
#    'warrene': 290,
#    'yanga': 44,
#    'bidenj': 25,
#    'gabbardt': 2,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 1,
#    'other': 0}},
#  {'fips': '19193',
#   'name': 'Woodbury',
#   'votes': 37.84,
#   'reporting': 32,
#   'precincts': 44,
#   'results': {'sandersb': 12.33,
#    'bidenj': 8.93,
#    'buttigiegp': 8.08,
#    'warrene': 5.95,
#    'klobuchara': 1.7,
#    'yanga': 0.64,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0.21,
#    'other': 0},
#   'votes_align1': 2330,
#   'results_align1': {'sandersb': 684,
#    'bidenj': 489,
#    'buttigiegp': 423,
#    'warrene': 332,
#    'klobuchara': 218,
#    'yanga': 127,
#    'steyert': 45,
#    'gabbardt': 3,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'patrickd': 0,
#    'uncommitted': 8,
#    'other': 1},
#   'votes_alignfinal': 2270,
#   'results_alignfinal': {'sandersb': 705,
#    'bidenj': 542,
#    'buttigiegp': 488,
#    'warrene': 331,
#    'klobuchara': 117,
#    'yanga': 40,
#    'steyert': 4,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 39,
#    'other': 4}},
#  {'fips': '19195',
#   'name': 'Worth',
#   'votes': 4.4,
#   'reporting': 6,
#   'precincts': 7,
#   'results': {'klobuchara': 1.2,
#    'buttigiegp': 0.87,
#    'sandersb': 0.73,
#    'bidenj': 0.6,
#    'warrene': 0.6,
#    'yanga': 0.4,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 256,
#   'results_align1': {'buttigiegp': 53,
#    'klobuchara': 50,
#    'sandersb': 40,
#    'warrene': 38,
#    'bidenj': 33,
#    'yanga': 27,
#    'steyert': 12,
#    'bloombergm': 2,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'uncommitted': 1,
#    'other': 0},
#   'votes_alignfinal': 256,
#   'results_alignfinal': {'klobuchara': 69,
#    'buttigiegp': 52,
#    'sandersb': 41,
#    'bidenj': 35,
#    'warrene': 35,
#    'yanga': 23,
#    'bennetm': 0,
#    'bloombergm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 1,
#    'other': 0}},
#  {'fips': '19197',
#   'name': 'Wright',
#   'votes': 5.61,
#   'reporting': 9,
#   'precincts': 10,
#   'results': {'buttigiegp': 2,
#    'bidenj': 1.07,
#    'klobuchara': 1.07,
#    'sandersb': 1.07,
#    'warrene': 0.27,
#    'bloombergm': 0.13,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 0,
#    'other': 0},
#   'votes_align1': 312,
#   'results_align1': {'buttigiegp': 91,
#    'sandersb': 58,
#    'bidenj': 55,
#    'klobuchara': 54,
#    'warrene': 37,
#    'yanga': 5,
#    'bloombergm': 2,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'uncommitted': 10,
#    'other': 0},
#   'votes_alignfinal': 312,
#   'results_alignfinal': {'buttigiegp': 108,
#    'sandersb': 68,
#    'klobuchara': 67,
#    'bidenj': 51,
#    'warrene': 14,
#    'bloombergm': 2,
#    'bennetm': 0,
#    'delaneyj': 0,
#    'gabbardt': 0,
#    'patrickd': 0,
#    'steyert': 0,
#    'yanga': 0,
#    'uncommitted': 1,
#    'other': 1}}]

# %% [markdown]
# What's here? Have a look...

# %% [markdown]
# What do we know about the counties?

# %%
type(demo['data']['races'][0]['counties'])
# Out:
# list

# %%
len(data['data']['races'][0]['counties'])
# Out:
# 104

# %%
for county in data['data']['races'][0]['counties']:
    print(county['name'])
    pprint.pprint(county)
    break
# Out:
# Adair
# {'fips': '19001',
#  'name': 'Adair',
#  'precincts': 5,
#  'reporting': 3,
#  'results': {'bennetm': 0,
#              'bidenj': 0.08,
#              'bloombergm': 0,
#              'buttigiegp': 0.55,
#              'delaneyj': 0,
#              'gabbardt': 0,
#              'klobuchara': 0.71,
#              'other': 0,
#              'patrickd': 0,
#              'sandersb': 0.71,
#              'steyert': 0.16,
#              'uncommitted': 0,
#              'warrene': 0.16,
#              'yanga': 0.16},
#  'results_align1': {'bennetm': 0,
#                     'bidenj': 20,
#                     'bloombergm': 0,
#                     'buttigiegp': 28,
#                     'delaneyj': 0,
#                     'gabbardt': 0,
#                     'klobuchara': 43,
#                     'other': 0,
#                     'patrickd': 0,
#                     'sandersb': 35,
#                     'steyert': 7,
#                     'uncommitted': 0,
#                     'warrene': 15,
#                     'yanga': 13},
#  'results_alignfinal': {'bennetm': 0,
#                         'bidenj': 6,
#                         'bloombergm': 0,
#                         'buttigiegp': 35,
#                         'delaneyj': 0,
#                         'gabbardt': 0,
#                         'klobuchara': 50,
#                         'other': 0,
#                         'patrickd': 0,
#                         'sandersb': 40,
#                         'steyert': 7,
#                         'uncommitted': 0,
#                         'warrene': 9,
#                         'yanga': 14},
#  'votes': 2.5300000000000002,
#  'votes_align1': 161,
#  'votes_alignfinal': 161}

# %%
url = 'https://int.nyt.com/applications/elections/2020/data/liveModel/2020-02-03/ia-17275-2020-02-03.json'

response = requests.get(url)

# %%
data = response.json()

# %%
data.keys()
# Out:
# dict_keys(['races', 'seats', 'timestamp'])

# %%
data['races']
# Out:
# [{'race_id': 'ia-17275-2020-02-03',
#   'race_slug': 'ia-president-caucus-democrat-2020-02-03',
#   'url': 'https://www.nytimes.com/interactive/2020/02/04/us/elections/results-iowa-caucus.html',
#   'race_type': 'president',
#   'election_type': 'caucus',
#   'election_date': '2020-02-03',
#   'runoff': False,
#   'race_name': 'President',
#   'office': 'President',
#   'officeid': 'P',
#   'race_call_note': '',
#   'race_text': '',
#   'nyt_measure_title': '',
#   'nyt_title': '',
#   'seat': '',
#   'seat_name': '',
#   'state_id': 'IA',
#   'state_slug': 'iowa',
#   'state_name': 'Iowa',
#   'state_nyt_abbrev': 'Iowa',
#   'party_id': 'democrat',
#   'uncontested': False,
#   'report': True,
#   'result': '',
#   'gain': False,
#   'lost_seat': '',
#   'electoral_votes': 0,
#   'poll_display': 'First results expected after 5 p.m., Eastern time.',
#   'poll_countdown_display': 'Iowa caucuses start in',
#   'poll_time': '2020-02-04T01:00:00.000Z',
#   'precincts_reporting': 1320,
#   'precincts_total': 1765,
#   'reporting_display': '75% reporting',
#   'eevp': 71,
#   'incumbent_party': '',
#   'no_forecast': False,
#   'has_incumbent': False,
#   'precinct_tileset': 'mapbox://nytgraphics.1f3d32qu',
#   'precinct_map_bounds': '[[-97.07,40.37], [-89.73,43.73]]',
#   'show_precinct_filters': '',
#   'delegates': 41,
#   'delegates_allocated': 27,
#   'timestamp_api': '2020-02-05T19:26:36.570Z',
#   'runoff_eligible': False,
#   'votetype': '',
#   'votes': 1643,
#   'leader': 'buttigiegp',
#   'leader_align1': 'sandersb',
#   'leader_alignfinal': 'sandersb',
#   'leader_delegates': 'buttigiegp',
#   'margin': [-0.008, 0.0061, 0.0157, 0.0247, 0.0368],
#   'margin_align1': [-0.0009, 0.0148, 0.0249, 0.0366, 0.0511],
#   'margin_alignfinal': [-0.0235, -0.0082, 0.0042, 0.017, 0.0363],
#   'margin_delegates': [-0.0488, 0, 0.0244, 0.0549, 0.0976],
#   'bennetm_align1_quantile': [137, 217, 360.755, 457.5, 744.35],
#   'bennetm_alignfinal_quantile': [6.95, 78, 214.8663, 286.5, 581.5],
#   'bennetm_delegates_quantile': [0, 0, 0, 0, 0],
#   'bennetm_quantile': [0.0451, 0.7831, 1.9643, 2.7803, 5.1015],
#   'bidenj_align1_quantile': [26095.95, 27328.5, 28455.4137, 29421.75, 31153],
#   'bidenj_alignfinal_quantile': [22744.15,
#    24127,
#    25230.4562,
#    26200.75,
#    27975.4],
#   'bidenj_delegates_quantile': [2, 2, 4.4375, 6, 8],
#   'bidenj_quantile': [305.1851, 317.0558, 326.0285, 334.0287, 347.7292],
#   'bloombergm_align1_quantile': [205.95, 273, 429.4563, 524, 859.5],
#   'bloombergm_alignfinal_quantile': [30.95, 104, 244.8113, 325.5, 628.25],
#   'bloombergm_delegates_quantile': [0, 0, 0, 0, 0],
#   'bloombergm_quantile': [0.3763, 1.0998, 2.2843, 3.079, 5.3904],
#   'buttigiegp_align1_quantile': [37671.85,
#    39385.75,
#    40652.13,
#    41889.75,
#    43779.15],
#   'buttigiegp_alignfinal_quantile': [43530.85,
#    45850,
#    47298.665,
#    48778,
#    50723.4],
#   'buttigiegp_delegates_quantile': [12, 13, 13.8875, 15, 16],
#   'buttigiegp_quantile': [543.7845, 560.0161, 571.5546, 584.1202, 600.5315],
#   'gabbardt_align1_quantile': [332, 417, 555.125, 639.25, 938.3],
#   'gabbardt_alignfinal_quantile': [41.9, 114, 266.235, 364.5, 662.5],
#   'gabbardt_delegates_quantile': [0, 0, 0, 0, 0],
#   'gabbardt_quantile': [0.3444, 1.1371, 2.3681, 3.2259, 5.6603],
#   'klobuchara_align1_quantile': [21863.65, 22997, 24033.7588, 24915, 26669.15],
#   'klobuchara_alignfinal_quantile': [20398.85,
#    21516.25,
#    22620.2537,
#    23532.5,
#    25335.5],
#   'klobuchara_delegates_quantile': [0, 0, 0.7538, 1, 1],
#   'klobuchara_quantile': [245.7807, 254.8018, 263.6173, 271.0316, 285.114],
#   'other_align1_quantile': [952, 1072, 1272.1512, 1427.25, 1790.2],
#   'other_alignfinal_quantile': [1404.95, 1611, 1855.0412, 2026, 2489],
#   'other_delegates_quantile': [0, 0, 0, 0, 0],
#   'other_quantile': [4.4797, 6.3094, 8.2026, 9.7369, 12.9627],
#   'patrickd_align1_quantile': [57.95, 105, 244.82, 332.75, 612.3],
#   'patrickd_alignfinal_quantile': [0, 50.75, 191.45, 272.5, 583.05],
#   'patrickd_delegates_quantile': [0, 0, 0, 0, 0],
#   'patrickd_quantile': [0, 0.5196, 1.6983, 2.4675, 4.7953],
#   'sandersb_align1_quantile': [42288.4, 44137.5, 45480.7887, 46788, 48683.2],
#   'sandersb_alignfinal_quantile': [44861,
#    46579.75,
#    48179.7262,
#    49657,
#    51759.55],
#   'sandersb_delegates_quantile': [10, 11, 12.6387, 14, 15],
#   'sandersb_quantile': [510.6896, 526.1656, 538.5244, 550.7606, 569.5351],
#   'steyert_align1_quantile': [2860, 3077, 3344.1975, 3546.5, 4025.2],
#   'steyert_alignfinal_quantile': [434.75, 582, 771.1037, 904, 1264.15],
#   'steyert_delegates_quantile': [0, 0, 0, 0, 0],
#   'steyert_quantile': [6.6542, 8.1121, 9.9014, 11.4065, 14.0835],
#   'warrene_align1_quantile': [32350.9,
#    34065.25,
#    35366.8788,
#    36613.5,
#    38331.75],
#   'warrene_alignfinal_quantile': [34633.45,
#    36347,
#    37834.2475,
#    39229.5,
#    41231.55],
#   'warrene_delegates_quantile': [8, 9, 9.2825, 10, 11],
#   'warrene_quantile': [370.0301, 383.4324, 395.3441, 406.6099, 422.9146],
#   'yanga_align1_quantile': [8577.4, 9185.75, 9728.7087, 10201.25, 11066.25],
#   'yanga_alignfinal_quantile': [1523.75, 1718, 1985.65, 2189, 2694.05],
#   'yanga_delegates_quantile': [0, 0, 0, 0, 0],
#   'yanga_quantile': [18.4918, 20.2661, 22.2521, 23.9423, 27.1329],
#   'vote_align1_counted': 134210,
#   'vote_align1_estimate': 189855,
#   'vote_align1_remaining': 55645,
#   'vote_alignfinal_counted': 130567,
#   'vote_alignfinal_estimate': 186722,
#   'vote_alignfinal_remaining': 56155,
#   'vote_counted': 1644.1919,
#   'vote_estimate': 2143.7587,
#   'vote_remaining': 499.5668,
#   'bennetm_align1_voteshare': [0.0007, 0.0011, 0.0019, 0.0024, 0.0039],
#   'bennetm_alignfinal_voteshare': [0, 0.0004, 0.0012, 0.0016, 0.0031],
#   'bennetm_delegates_voteshare': [0, 0, 0, 0, 0],
#   'bennetm_voteshare': [0, 0.0004, 0.0009, 0.0013, 0.0024],
#   'bidenj_align1_voteshare': [0.1375, 0.144, 0.1498, 0.1547, 0.1639],
#   'bidenj_alignfinal_voteshare': [0.1225, 0.1295, 0.1351, 0.1401, 0.1487],
#   'bidenj_delegates_voteshare': [0.0488, 0.0488, 0.1082, 0.1463, 0.1951],
#   'bidenj_voteshare': [0.1424, 0.1479, 0.1521, 0.1558, 0.1622],
#   'bloombergm_align1_voteshare': [0.0011, 0.0014, 0.0023, 0.0028, 0.0045],
#   'bloombergm_alignfinal_voteshare': [0.0002, 0.0006, 0.0013, 0.0017, 0.0034],
#   'bloombergm_delegates_voteshare': [0, 0, 0, 0, 0],
#   'bloombergm_voteshare': [0.0002, 0.0005, 0.0011, 0.0014, 0.0025],
#   'buttigiegp_align1_voteshare': [0.1986, 0.2073, 0.2141, 0.2205, 0.2303],
#   'buttigiegp_alignfinal_voteshare': [0.2345, 0.2464, 0.2534, 0.2605, 0.2713],
#   'buttigiegp_delegates_voteshare': [0.2927, 0.3171, 0.3387, 0.3659, 0.3902],
#   'buttigiegp_voteshare': [0.2536, 0.2612, 0.2666, 0.2725, 0.2801],
#   'gabbardt_align1_voteshare': [0.0018, 0.0022, 0.0029, 0.0034, 0.0049],
#   'gabbardt_alignfinal_voteshare': [0.0002, 0.0006, 0.0014, 0.002, 0.0036],
#   'gabbardt_delegates_voteshare': [0, 0, 0, 0, 0],
#   'gabbardt_voteshare': [0.0002, 0.0005, 0.0011, 0.0015, 0.0026],
#   'klobuchara_align1_voteshare': [0.1153, 0.1211, 0.1265, 0.1309, 0.1401],
#   'klobuchara_alignfinal_voteshare': [0.11, 0.1155, 0.1212, 0.1259, 0.1356],
#   'klobuchara_delegates_voteshare': [0, 0, 0.0184, 0.0244, 0.0244],
#   'klobuchara_voteshare': [0.1146, 0.1189, 0.123, 0.1265, 0.133],
#   'other_align1_voteshare': [0.005, 0.0056, 0.0067, 0.0075, 0.0094],
#   'other_alignfinal_voteshare': [0.0076, 0.0086, 0.0099, 0.0108, 0.0133],
#   'other_delegates_voteshare': [0, 0, 0, 0, 0],
#   'other_voteshare': [0.0021, 0.0029, 0.0038, 0.0045, 0.0061],
#   'patrickd_align1_voteshare': [0.0003, 0.0006, 0.0013, 0.0017, 0.0032],
#   'patrickd_alignfinal_voteshare': [0, 0.0003, 0.001, 0.0015, 0.0031],
#   'patrickd_delegates_voteshare': [0, 0, 0, 0, 0],
#   'patrickd_voteshare': [0, 0.0002, 0.0008, 0.0012, 0.0022],
#   'sandersb_align1_voteshare': [0.2234, 0.2323, 0.2395, 0.2465, 0.2564],
#   'sandersb_alignfinal_voteshare': [0.2409, 0.2503, 0.2581, 0.2658, 0.2773],
#   'sandersb_delegates_voteshare': [0.2439, 0.2683, 0.3083, 0.3415, 0.3659],
#   'sandersb_voteshare': [0.2382, 0.2455, 0.2512, 0.2569, 0.2656],
#   'steyert_align1_voteshare': [0.0151, 0.0162, 0.0176, 0.0187, 0.0212],
#   'steyert_alignfinal_voteshare': [0.0023, 0.0031, 0.0041, 0.0048, 0.0068],
#   'steyert_delegates_voteshare': [0, 0, 0, 0, 0],
#   'steyert_voteshare': [0.0031, 0.0038, 0.0046, 0.0053, 0.0066],
#   'warrene_align1_voteshare': [0.1709, 0.1801, 0.1862, 0.1924, 0.2012],
#   'warrene_alignfinal_voteshare': [0.1862, 0.1953, 0.2027, 0.2097, 0.2205],
#   'warrene_delegates_voteshare': [0.1951, 0.2195, 0.2264, 0.2439, 0.2683],
#   'warrene_voteshare': [0.1726, 0.1789, 0.1844, 0.1896, 0.1972],
#   'yanga_align1_voteshare': [0.0453, 0.0483, 0.0512, 0.0537, 0.0582],
#   'yanga_alignfinal_voteshare': [0.0082, 0.0092, 0.0106, 0.0117, 0.0143],
#   'yanga_delegates_voteshare': [0, 0, 0, 0, 0],
#   'yanga_voteshare': [0.0086, 0.0095, 0.0104, 0.0112, 0.0127],
#   'bennetm_vote_counted': 0,
#   'bennetm_vote_estimate': 0,
#   'bennetm_vote_remaining': 0,
#   'bidenj_vote_counted': 257.0809,
#   'bidenj_vote_estimate': 312.1642,
#   'bidenj_vote_remaining': 55.0833,
#   'bloombergm_vote_counted': 0.1333,
#   'bloombergm_vote_estimate': 0.183,
#   'bloombergm_vote_remaining': 0.0497,
#   'buttigiegp_vote_counted': 442.1974,
#   'buttigiegp_vote_estimate': 561.9213,
#   'buttigiegp_vote_remaining': 119.7239,
#   'gabbardt_vote_counted': 0.1143,
#   'gabbardt_vote_estimate': 0.2393,
#   'gabbardt_vote_remaining': 0.125,
#   'klobuchara_vote_counted': 205.9686,
#   'klobuchara_vote_estimate': 249.1344,
#   'klobuchara_vote_remaining': 43.1658,
#   'other_vote_counted': 3.0459,
#   'other_vote_estimate': 4.0295,
#   'other_vote_remaining': 0.9836,
#   'patrickd_vote_counted': 0,
#   'patrickd_vote_estimate': 0,
#   'patrickd_vote_remaining': 0,
#   'sandersb_vote_counted': 413.6006,
#   'sandersb_vote_estimate': 527.846,
#   'sandersb_vote_remaining': 114.2454,
#   'steyert_vote_counted': 5.1427,
#   'steyert_vote_estimate': 5.9061,
#   'steyert_vote_remaining': 0.7634,
#   'warrene_vote_counted': 299.4945,
#   'warrene_vote_estimate': 382.9416,
#   'warrene_vote_remaining': 83.4471,
#   'yanga_vote_counted': 17.4137,
#   'yanga_vote_estimate': 18.5708,
#   'yanga_vote_remaining': 1.1571,
#   'bennetm_align1_wp': 0,
#   'bennetm_alignfinal_wp': 0,
#   'bennetm_delegates_wp': 0,
#   'bennetm_wp': 0,
#   'bidenj_align1_wp': 0,
#   'bidenj_alignfinal_wp': 0,
#   'bidenj_delegates_wp': 0,
#   'bidenj_wp': 0,
#   'bloombergm_align1_wp': 0,
#   'bloombergm_alignfinal_wp': 0,
#   'bloombergm_delegates_wp': 0,
#   'bloombergm_wp': 0,
#   'buttigiegp_align1_wp': 0.055,
#   'buttigiegp_alignfinal_wp': 0.4038,
#   'buttigiegp_delegates_wp': 0.76,
#   'buttigiegp_wp': 0.8638,
#   'gabbardt_align1_wp': 0,
#   'gabbardt_alignfinal_wp': 0,
#   'gabbardt_delegates_wp': 0,
#   'gabbardt_wp': 0,
#   'klobuchara_align1_wp': 0,
#   'klobuchara_alignfinal_wp': 0,
#   'klobuchara_delegates_wp': 0,
#   'klobuchara_wp': 0,
#   'other_align1_wp': 0,
#   'other_alignfinal_wp': 0,
#   'other_delegates_wp': 0,
#   'other_wp': 0,
#   'patrickd_align1_wp': 0,
#   'patrickd_alignfinal_wp': 0,
#   'patrickd_delegates_wp': 0,
#   'patrickd_wp': 0,
#   'sandersb_align1_wp': 0.945,
#   'sandersb_alignfinal_wp': 0.595,
#   'sandersb_delegates_wp': 0.24,
#   'sandersb_wp': 0.1362,
#   'steyert_align1_wp': 0,
#   'steyert_alignfinal_wp': 0,
#   'steyert_delegates_wp': 0,
#   'steyert_wp': 0,
#   'warrene_align1_wp': 0,
#   'warrene_alignfinal_wp': 0.0012,
#   'warrene_delegates_wp': 0,
#   'warrene_wp': 0,
#   'yanga_align1_wp': 0,
#   'yanga_alignfinal_wp': 0,
#   'yanga_delegates_wp': 0,
#   'yanga_wp': 0,
#   'candidates': [{'candidate_id': 'buttigieg-67933',
#     'candidate_key': 'buttigiegp',
#     'first_name': 'Pete',
#     'last_name': 'Buttigieg',
#     'order': 4,
#     'name_display': 'Pete Buttigieg',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 442,
#     'percent': 26.9,
#     'percent_display': '26.9',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/pete-buttigieg.html',
#     'pronoun': 'he',
#     'votes_align1': 28825,
#     'percent_align1': 21.5,
#     'percent_display_align1': '21.5',
#     'winner_align1': False,
#     'votes_alignfinal': 33094,
#     'percent_alignfinal': 25.3,
#     'percent_display_alignfinal': '25.3',
#     'winner_alignfinal': False,
#     'delegates': 11},
#    {'candidate_id': 'sanders-1445',
#     'candidate_key': 'sandersb',
#     'first_name': 'Bernie',
#     'last_name': 'Sanders',
#     'order': 2,
#     'name_display': 'Bernie Sanders',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 414,
#     'percent': 25.2,
#     'percent_display': '25.2',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/bernie-sanders.html',
#     'pronoun': 'he',
#     'votes_align1': 32638,
#     'percent_align1': 24.3,
#     'percent_display_align1': '24.3',
#     'winner_align1': False,
#     'votes_alignfinal': 34136,
#     'percent_alignfinal': 26.1,
#     'percent_display_alignfinal': '26.1',
#     'winner_alignfinal': False,
#     'delegates': 11},
#    {'candidate_id': 'warren-62244',
#     'candidate_key': 'warrene',
#     'first_name': 'Elizabeth',
#     'last_name': 'Warren',
#     'order': 3,
#     'name_display': 'Elizabeth Warren',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 299,
#     'percent': 18.2,
#     'percent_display': '18.2',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/elizabeth-warren.html',
#     'pronoun': 'she',
#     'votes_align1': 25025,
#     'percent_align1': 18.6,
#     'percent_display_align1': '18.6',
#     'winner_align1': False,
#     'votes_alignfinal': 26613,
#     'percent_alignfinal': 20.4,
#     'percent_display_alignfinal': '20.4',
#     'winner_alignfinal': False,
#     'delegates': 5},
#    {'candidate_id': 'biden-1036',
#     'candidate_key': 'bidenj',
#     'first_name': 'Joseph R.',
#     'last_name': 'Biden',
#     'order': 1,
#     'name_display': 'Joseph R. Biden Jr.',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 257,
#     'percent': 15.6,
#     'percent_display': '15.6',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/joe-biden.html',
#     'pronoun': 'he',
#     'votes_align1': 19878,
#     'percent_align1': 14.8,
#     'percent_display_align1': '14.8',
#     'winner_align1': False,
#     'votes_alignfinal': 17623,
#     'percent_alignfinal': 13.5,
#     'percent_display_alignfinal': '13.5',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'klobuchar-51526',
#     'candidate_key': 'klobuchara',
#     'first_name': 'Amy',
#     'last_name': 'Klobuchar',
#     'order': 6,
#     'name_display': 'Amy Klobuchar',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 206,
#     'percent': 12.5,
#     'percent_display': '12.5',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/amy-klobuchar.html',
#     'pronoun': 'she',
#     'votes_align1': 17050,
#     'percent_align1': 12.7,
#     'percent_display_align1': '12.7',
#     'winner_align1': False,
#     'votes_alignfinal': 16116,
#     'percent_alignfinal': 12.3,
#     'percent_display_alignfinal': '12.3',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'yang-67936',
#     'candidate_key': 'yanga',
#     'first_name': 'Andrew',
#     'last_name': 'Yang',
#     'order': 7,
#     'name_display': 'Andrew Yang',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 17,
#     'percent': 1,
#     'percent_display': '1.0',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/andrew-yang.html',
#     'pronoun': 'he',
#     'votes_align1': 7011,
#     'percent_align1': 5.2,
#     'percent_display_align1': '5.2',
#     'winner_align1': False,
#     'votes_alignfinal': 1409,
#     'percent_alignfinal': 1.1,
#     'percent_display_alignfinal': '1.1',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'steyer-67935',
#     'candidate_key': 'steyert',
#     'first_name': 'Tom',
#     'last_name': 'Steyer',
#     'order': 8,
#     'name_display': 'Tom Steyer',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 5,
#     'percent': 0.3,
#     'percent_display': '0.3',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/tom-steyer.html',
#     'pronoun': 'he',
#     'votes_align1': 2334,
#     'percent_align1': 1.7,
#     'percent_display_align1': '1.7',
#     'winner_align1': False,
#     'votes_alignfinal': 285,
#     'percent_alignfinal': 0.2,
#     'percent_display_alignfinal': '0.2',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'bloomberg-32324',
#     'candidate_key': 'bloombergm',
#     'first_name': 'Michael',
#     'last_name': 'Bloomberg',
#     'order': 5,
#     'name_display': 'Michael Bloomberg',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 0,
#     'percent': 0,
#     'percent_display': '0.0',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/michael-bloomberg.html',
#     'pronoun': 'he',
#     'votes_align1': 158,
#     'percent_align1': 0.1,
#     'percent_display_align1': '0.1',
#     'winner_align1': False,
#     'votes_alignfinal': 6,
#     'percent_alignfinal': 0,
#     'percent_display_alignfinal': '0.0',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'gabbard-62589',
#     'candidate_key': 'gabbardt',
#     'first_name': 'Tulsi',
#     'last_name': 'Gabbard',
#     'order': 9,
#     'name_display': 'Tulsi Gabbard',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 0,
#     'percent': 0,
#     'percent_display': '0.0',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/tulsi-gabbard.html',
#     'pronoun': 'she',
#     'votes_align1': 272,
#     'percent_align1': 0.2,
#     'percent_display_align1': '0.2',
#     'winner_align1': False,
#     'votes_alignfinal': 14,
#     'percent_alignfinal': 0,
#     'percent_display_alignfinal': '0.0',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'patrick-51516',
#     'candidate_key': 'patrickd',
#     'first_name': 'Deval',
#     'last_name': 'Patrick',
#     'order': 11,
#     'name_display': 'Deval Patrick',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 0,
#     'percent': 0,
#     'percent_display': '0.0',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/deval-patrick.html',
#     'pronoun': 'he',
#     'votes_align1': 46,
#     'percent_align1': 0,
#     'percent_display_align1': '0.0',
#     'winner_align1': False,
#     'votes_alignfinal': 0,
#     'percent_alignfinal': 0,
#     'percent_display_alignfinal': '0.0',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'bennet-59911',
#     'candidate_key': 'bennetm',
#     'first_name': 'Michael',
#     'last_name': 'Bennet',
#     'order': 10,
#     'name_display': 'Michael Bennet',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 0,
#     'percent': 0,
#     'percent_display': '0.0',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/michael-bennet.html',
#     'pronoun': 'he',
#     'votes_align1': 109,
#     'percent_align1': 0.1,
#     'percent_display_align1': '0.1',
#     'winner_align1': False,
#     'votes_alignfinal': 1,
#     'percent_alignfinal': 0,
#     'percent_display_alignfinal': '0.0',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'delaney-61562',
#     'candidate_key': 'delaneyj',
#     'first_name': 'John',
#     'last_name': 'Delaney',
#     'order': 12,
#     'name_display': 'John Delaney',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 0,
#     'percent': 0,
#     'percent_display': '0.0',
#     'electoral_votes': 0,
#     'has_image': True,
#     'link': 'https://www.nytimes.com/interactive/2020/us/elections/john-delaney.html',
#     'pronoun': 'he',
#     'votes_align1': 0,
#     'percent_align1': 0,
#     'percent_display_align1': '0.0',
#     'winner_align1': False,
#     'votes_alignfinal': 0,
#     'percent_alignfinal': 0,
#     'percent_display_alignfinal': '0.0',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'uncommitted-100004',
#     'candidate_key': 'uncommitted',
#     'last_name': 'Uncommitted',
#     'order': 13,
#     'name_display': 'Uncommitted',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 3,
#     'percent': 0.2,
#     'percent_display': '0.2',
#     'electoral_votes': 0,
#     'has_image': False,
#     'link': '',
#     'votes_align1': 747,
#     'percent_align1': 0.6,
#     'percent_display_align1': '0.6',
#     'winner_align1': False,
#     'votes_alignfinal': 1119,
#     'percent_alignfinal': 0.9,
#     'percent_display_alignfinal': '0.9',
#     'winner_alignfinal': False,
#     'delegates': 0},
#    {'candidate_id': 'other-100007',
#     'candidate_key': 'other',
#     'last_name': 'Other',
#     'order': 14,
#     'name_display': 'Other',
#     'party_id': 'democrat',
#     'incumbent': False,
#     'runoff': False,
#     'winner': False,
#     'votes': 0,
#     'percent': 0,
#     'percent_display': '0.0',
#     'electoral_votes': 0,
#     'has_image': False,
#     'link': '',
#     'votes_align1': 117,
#     'percent_align1': 0.1,
#     'percent_display_align1': '0.1',
#     'winner_align1': False,
#     'votes_alignfinal': 151,
#     'percent_alignfinal': 0.1,
#     'percent_display_alignfinal': '0.1',
#     'winner_alignfinal': False,
#     'delegates': 0}],
#   'counties': [{'fips': '19001',
#     'name': 'Adair',
#     'votes': 2.53,
#     'precincts': 5,
#     'votes_align1': 161,
#     'votes_alignfinal': 161,
#     'reporting': 3,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.0784,
#      'bloombergm': 0,
#      'buttigiegp': 0.549,
#      'gabbardt': 0,
#      'klobuchara': 0.706,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.7059,
#      'steyert': 0.1569,
#      'warrene': 0.1569,
#      'yanga': 0.1569},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.1569,
#      'bloombergm': 0,
#      'buttigiegp': 0.4706,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.1569,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19003',
#     'name': 'Adams',
#     'votes': 1.72,
#     'precincts': 5,
#     'votes_align1': 62,
#     'votes_alignfinal': 62,
#     'reporting': 3,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.3428,
#      'bloombergm': 0,
#      'buttigiegp': 0.4285,
#      'gabbardt': 0,
#      'klobuchara': 0.4285,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.2571,
#      'steyert': 0,
#      'warrene': 0.2571,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.1714,
#      'bloombergm': 0,
#      'buttigiegp': 0.4286,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.0857,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19005',
#     'name': 'Allamakee',
#     'votes': 5.52,
#     'precincts': 11,
#     'votes_align1': 384,
#     'votes_alignfinal': 382,
#     'reporting': 8,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.6223,
#      'bloombergm': 0,
#      'buttigiegp': 2.0222,
#      'gabbardt': 0,
#      'klobuchara': 1.1668,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.9334,
#      'steyert': 0.0778,
#      'warrene': 0.3112,
#      'yanga': 0.3889},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.1556,
#      'bloombergm': 0,
#      'buttigiegp': 0.3889,
#      'gabbardt': 0,
#      'klobuchara': 0.0778,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.2333,
#      'steyert': 0,
#      'warrene': 0.1556,
#      'yanga': 0}},
#    {'fips': '19007',
#     'name': 'Appanoose',
#     'votes': 5.68,
#     'precincts': 12,
#     'votes_align1': 347,
#     'votes_alignfinal': 346,
#     'reporting': 11,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1.68,
#      'bloombergm': 0,
#      'buttigiegp': 2.24,
#      'gabbardt': 0,
#      'klobuchara': 0.4,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.96,
#      'steyert': 0.24,
#      'warrene': 0.08,
#      'yanga': 0.08},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19009',
#     'name': 'Audubon',
#     'votes': 3,
#     'precincts': 2,
#     'votes_align1': 203,
#     'votes_alignfinal': 203,
#     'reporting': 2,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.9,
#      'bloombergm': 0,
#      'buttigiegp': 0.4,
#      'gabbardt': 0,
#      'klobuchara': 0.9,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.5,
#      'steyert': 0,
#      'warrene': 0.3,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19011',
#     'name': 'Benton',
#     'votes': 14.26,
#     'precincts': 19,
#     'votes_align1': 803,
#     'votes_alignfinal': 773,
#     'reporting': 18,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 4.65,
#      'bloombergm': 0,
#      'buttigiegp': 3.975,
#      'gabbardt': 0,
#      'klobuchara': 1.35,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 3.3,
#      'steyert': 0,
#      'warrene': 0.975,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19013',
#     'name': 'Black Hawk',
#     'votes': 56.97,
#     'precincts': 62,
#     'votes_align1': 4154,
#     'votes_alignfinal': 4041,
#     'reporting': 35,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 8.484,
#      'bloombergm': 0,
#      'buttigiegp': 13.736,
#      'gabbardt': 0,
#      'klobuchara': 6.666,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 17.978,
#      'steyert': 0.606,
#      'warrene': 9.09,
#      'yanga': 0.404},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 4.646,
#      'bloombergm': 0,
#      'buttigiegp': 9.898,
#      'gabbardt': 0,
#      'klobuchara': 4.04,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 13.13,
#      'steyert': 0,
#      'warrene': 9.292,
#      'yanga': 0}},
#    {'fips': '19015',
#     'name': 'Boone',
#     'votes': 16.72,
#     'precincts': 15,
#     'votes_align1': 1217,
#     'votes_alignfinal': 1210,
#     'reporting': 14,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1.14,
#      'bloombergm': 0,
#      'buttigiegp': 5.32,
#      'gabbardt': 0,
#      'klobuchara': 2.28,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 4.56,
#      'steyert': 0.19,
#      'warrene': 3.23,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19017',
#     'name': 'Bremer',
#     'votes': 15.41,
#     'precincts': 13,
#     'votes_align1': 1221,
#     'votes_alignfinal': 1218,
#     'reporting': 11,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 2.72,
#      'bloombergm': 0,
#      'buttigiegp': 5.2133,
#      'gabbardt': 0,
#      'klobuchara': 2.4933,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.5868,
#      'steyert': 0,
#      'warrene': 3.4001,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0.4533,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.2267,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19019',
#     'name': 'Buchanan',
#     'votes': 9.57,
#     'precincts': 15,
#     'votes_align1': 549,
#     'votes_alignfinal': 532,
#     'reporting': 11,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 2.5999,
#      'bloombergm': 0,
#      'buttigiegp': 2.8736,
#      'gabbardt': 0,
#      'klobuchara': 1.7787,
#      'other': 0.2737,
#      'patrickd': 0,
#      'sandersb': 1.0945,
#      'steyert': 0,
#      'warrene': 0.5472,
#      'yanga': 0.4105},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.2737,
#      'bloombergm': 0,
#      'buttigiegp': 0.9579,
#      'gabbardt': 0,
#      'klobuchara': 0.2737,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.821,
#      'steyert': 0,
#      'warrene': 0.4105,
#      'yanga': 0}},
#    {'fips': '19021',
#     'name': 'Buena Vista',
#     'votes': 6.2,
#     'precincts': 10,
#     'votes_align1': 364,
#     'votes_alignfinal': 349,
#     'reporting': 6,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1,
#      'bloombergm': 0,
#      'buttigiegp': 1.2,
#      'gabbardt': 0,
#      'klobuchara': 0.4,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 2,
#      'steyert': 0.2,
#      'warrene': 1,
#      'yanga': 0.4},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.4,
#      'bloombergm': 0,
#      'buttigiegp': 0.8,
#      'gabbardt': 0,
#      'klobuchara': 0.2,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.4,
#      'steyert': 0,
#      'warrene': 0.2,
#      'yanga': 0}},
#    {'fips': '19023',
#     'name': 'Butler',
#     'votes': 7,
#     'precincts': 8,
#     'votes_align1': 428,
#     'votes_alignfinal': 428,
#     'reporting': 8,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1.3999,
#      'bloombergm': 0,
#      'buttigiegp': 1.2832,
#      'gabbardt': 0,
#      'klobuchara': 1.1666,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.75,
#      'steyert': 0,
#      'warrene': 1.2833,
#      'yanga': 0.1167},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19025',
#     'name': 'Calhoun',
#     'votes': 4.83,
#     'precincts': 10,
#     'votes_align1': 241,
#     'votes_alignfinal': 240,
#     'reporting': 9,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1,
#      'bloombergm': 0,
#      'buttigiegp': 1.8333,
#      'gabbardt': 0,
#      'klobuchara': 0.5833,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.75,
#      'steyert': 0,
#      'warrene': 0.6666,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19027',
#     'name': 'Carroll',
#     'votes': 8.36,
#     'precincts': 13,
#     'votes_align1': 475,
#     'votes_alignfinal': 474,
#     'reporting': 10,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 2.31,
#      'bloombergm': 0,
#      'buttigiegp': 2.64,
#      'gabbardt': 0,
#      'klobuchara': 1.43,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.32,
#      'steyert': 0,
#      'warrene': 0.55,
#      'yanga': 0.11},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.33,
#      'bloombergm': 0,
#      'buttigiegp': 0.44,
#      'gabbardt': 0,
#      'klobuchara': 0.11,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.11,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19029',
#     'name': 'Cass',
#     'votes': 4.68,
#     'precincts': 13,
#     'votes_align1': 288,
#     'votes_alignfinal': 286,
#     'reporting': 11,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.96,
#      'bloombergm': 0,
#      'buttigiegp': 1.44,
#      'gabbardt': 0,
#      'klobuchara': 0.72,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.6,
#      'steyert': 0,
#      'warrene': 0.96,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.24,
#      'bloombergm': 0,
#      'buttigiegp': 0.36,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19031',
#     'name': 'Cedar',
#     'votes': 10.97,
#     'precincts': 12,
#     'votes_align1': 797,
#     'votes_alignfinal': 767,
#     'reporting': 10,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1.3714,
#      'bloombergm': 0,
#      'buttigiegp': 2.9143,
#      'gabbardt': 0,
#      'klobuchara': 2.0571,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 2.3998,
#      'steyert': 0,
#      'warrene': 2.2285,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0.1714,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.1714,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19033',
#     'name': 'Cerro Gordo',
#     'votes': 25.87,
#     'precincts': 26,
#     'votes_align1': 1569,
#     'votes_alignfinal': 1545,
#     'reporting': 19,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 4.6056,
#      'bloombergm': 0,
#      'buttigiegp': 7.9714,
#      'gabbardt': 0,
#      'klobuchara': 6.7313,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 4.9599,
#      'steyert': 0,
#      'warrene': 1.417,
#      'yanga': 0.1771},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.5314,
#      'bloombergm': 0,
#      'buttigiegp': 1.24,
#      'gabbardt': 0,
#      'klobuchara': 0.3543,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.4171,
#      'steyert': 0,
#      'warrene': 0.8857,
#      'yanga': 0}},
#    {'fips': '19035',
#     'name': 'Cherokee',
#     'votes': 2.52,
#     'precincts': 7,
#     'votes_align1': 125,
#     'votes_alignfinal': 122,
#     'reporting': 3,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.7637,
#      'bloombergm': 0,
#      'buttigiegp': 0.4364,
#      'gabbardt': 0,
#      'klobuchara': 0.2182,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.5455,
#      'steyert': 0.1091,
#      'warrene': 0.2182,
#      'yanga': 0.2182},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.3273,
#      'bloombergm': 0,
#      'buttigiegp': 0.9818,
#      'gabbardt': 0,
#      'klobuchara': 0.3273,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.7636,
#      'steyert': 0,
#      'warrene': 0.3273,
#      'yanga': 0}},
#    {'fips': '19037',
#     'name': 'Chickasaw',
#     'votes': 5.32,
#     'precincts': 13,
#     'votes_align1': 271,
#     'votes_alignfinal': 271,
#     'reporting': 10,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1.05,
#      'bloombergm': 0,
#      'buttigiegp': 1.82,
#      'gabbardt': 0,
#      'klobuchara': 0.7,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.42,
#      'steyert': 0.21,
#      'warrene': 1.12,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.28,
#      'bloombergm': 0,
#      'buttigiegp': 0.42,
#      'gabbardt': 0,
#      'klobuchara': 0.14,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.14,
#      'steyert': 0,
#      'warrene': 0.14,
#      'yanga': 0}},
#    {'fips': '19039',
#     'name': 'Clarke',
#     'votes': 3.52,
#     'precincts': 7,
#     'votes_align1': 227,
#     'votes_alignfinal': 226,
#     'reporting': 6,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.4,
#      'bloombergm': 0,
#      'buttigiegp': 1.04,
#      'gabbardt': 0,
#      'klobuchara': 0.72,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.88,
#      'steyert': 0,
#      'warrene': 0.16,
#      'yanga': 0.32},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19041',
#     'name': 'Clay',
#     'votes': 7.06,
#     'precincts': 12,
#     'votes_align1': 460,
#     'votes_alignfinal': 450,
#     'reporting': 9,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1.7883,
#      'bloombergm': 0,
#      'buttigiegp': 1.7884,
#      'gabbardt': 0,
#      'klobuchara': 1.3177,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.506,
#      'steyert': 0,
#      'warrene': 0.5646,
#      'yanga': 0.0941},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0.2824,
#      'gabbardt': 0,
#      'klobuchara': 0.0941,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.1882,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19043',
#     'name': 'Clayton',
#     'votes': 9,
#     'precincts': 14,
#     'votes_align1': 583,
#     'votes_alignfinal': 569,
#     'reporting': 11,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1.5001,
#      'bloombergm': 0,
#      'buttigiegp': 3.5002,
#      'gabbardt': 0,
#      'klobuchara': 2.0001,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.6667,
#      'steyert': 0,
#      'warrene': 0.3334,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.1667,
#      'bloombergm': 0,
#      'buttigiegp': 0.3333,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.1667,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19045',
#     'name': 'Clinton',
#     'votes': 29.23,
#     'precincts': 26,
#     'votes_align1': 1609,
#     'votes_alignfinal': 1571,
#     'reporting': 24,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 7.3072,
#      'bloombergm': 0,
#      'buttigiegp': 8.4144,
#      'gabbardt': 0,
#      'klobuchara': 2.8786,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 7.5288,
#      'steyert': 0,
#      'warrene': 2.8787,
#      'yanga': 0.2214},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0.4429,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.4429,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19047',
#     'name': 'Crawford',
#     'votes': 3.9,
#     'precincts': 8,
#     'votes_align1': 220,
#     'votes_alignfinal': 219,
#     'reporting': 5,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1.8,
#      'bloombergm': 0,
#      'buttigiegp': 0.45,
#      'gabbardt': 0,
#      'klobuchara': 0.45,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.9,
#      'steyert': 0,
#      'warrene': 0.15,
#      'yanga': 0.15},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.15,
#      'bloombergm': 0,
#      'buttigiegp': 0.45,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.45,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19049',
#     'name': 'Dallas',
#     'votes': 52.2,
#     'precincts': 34,
#     'votes_align1': 5294,
#     'votes_alignfinal': 5236,
#     'reporting': 29,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 10.3575,
#      'bloombergm': 0,
#      'buttigiegp': 18.2292,
#      'gabbardt': 0,
#      'klobuchara': 5.8002,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 7.0431,
#      'steyert': 0,
#      'warrene': 10.7718,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.8286,
#      'bloombergm': 0,
#      'buttigiegp': 1.6571,
#      'gabbardt': 0,
#      'klobuchara': 0.8286,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.2429,
#      'steyert': 0,
#      'warrene': 0.4143,
#      'yanga': 0}},
#    {'fips': '19051',
#     'name': 'Davis',
#     'votes': 2.64,
#     'precincts': 8,
#     'votes_align1': 172,
#     'votes_alignfinal': 172,
#     'reporting': 7,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.75,
#      'bloombergm': 0,
#      'buttigiegp': 0.96,
#      'gabbardt': 0,
#      'klobuchara': 0.3,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.24,
#      'steyert': 0,
#      'warrene': 0.39,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0.06,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19053',
#     'name': 'Decatur',
#     'votes': 2.82,
#     'precincts': 7,
#     'votes_align1': 272,
#     'votes_alignfinal': 272,
#     'reporting': 5,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.2353,
#      'bloombergm': 0,
#      'buttigiegp': 0.753,
#      'gabbardt': 0,
#      'klobuchara': 0.5177,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.753,
#      'steyert': 0,
#      'warrene': 0.5647,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.0941,
#      'bloombergm': 0,
#      'buttigiegp': 0.1647,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19055',
#     'name': 'Delaware',
#     'votes': 7.66,
#     'precincts': 12,
#     'votes_align1': 376,
#     'votes_alignfinal': 367,
#     'reporting': 10,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1.5,
#      'bloombergm': 0,
#      'buttigiegp': 2.025,
#      'gabbardt': 0,
#      'klobuchara': 1.8,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.375,
#      'steyert': 0.15,
#      'warrene': 1.8,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0.375,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.15,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19057',
#     'name': 'Des Moines',
#     'votes': 20.16,
#     'precincts': 16,
#     'votes_align1': 1198,
#     'votes_alignfinal': 1171,
#     'reporting': 12,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 4.32,
#      'bloombergm': 0,
#      'buttigiegp': 7.2,
#      'gabbardt': 0,
#      'klobuchara': 0.36,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 5.04,
#      'steyert': 0,
#      'warrene': 2.52,
#      'yanga': 0.72},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.36,
#      'bloombergm': 0,
#      'buttigiegp': 1.8,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.8,
#      'steyert': 0,
#      'warrene': 1.08,
#      'yanga': 0}},
#    {'fips': '19059',
#     'name': 'Dickinson',
#     'votes': 7.01,
#     'precincts': 15,
#     'votes_align1': 447,
#     'votes_alignfinal': 445,
#     'reporting': 12,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1.5,
#      'bloombergm': 0,
#      'buttigiegp': 1.875,
#      'gabbardt': 0,
#      'klobuchara': 1.375,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.75,
#      'steyert': 0,
#      'warrene': 0.5,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.125,
#      'bloombergm': 0,
#      'buttigiegp': 0.875,
#      'gabbardt': 0,
#      'klobuchara': 0.375,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.375,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19061',
#     'name': 'Dubuque',
#     'votes': 44.8,
#     'precincts': 35,
#     'votes_align1': 3255,
#     'votes_alignfinal': 3189,
#     'reporting': 22,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 9.8665,
#      'bloombergm': 0,
#      'buttigiegp': 12.7999,
#      'gabbardt': 0,
#      'klobuchara': 2.9334,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 10.9332,
#      'steyert': 0,
#      'warrene': 7.9997,
#      'yanga': 0.2667},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 4.2667,
#      'bloombergm': 0,
#      'buttigiegp': 6.9333,
#      'gabbardt': 0,
#      'klobuchara': 3.4667,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 5.6,
#      'steyert': 0,
#      'warrene': 4.5333,
#      'yanga': 0}},
#    {'fips': '19063',
#     'name': 'Emmet',
#     'votes': 3.43,
#     'precincts': 11,
#     'votes_align1': 211,
#     'votes_alignfinal': 208,
#     'reporting': 8,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.4572,
#      'bloombergm': 0,
#      'buttigiegp': 1.143,
#      'gabbardt': 0,
#      'klobuchara': 0.3429,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.8001,
#      'steyert': 0.2286,
#      'warrene': 0.4572,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.1143,
#      'bloombergm': 0,
#      'buttigiegp': 0.2286,
#      'gabbardt': 0,
#      'klobuchara': 0.1143,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19065',
#     'name': 'Fayette',
#     'votes': 9.96,
#     'precincts': 25,
#     'votes_align1': 583,
#     'votes_alignfinal': 574,
#     'reporting': 19,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 2.16,
#      'bloombergm': 0,
#      'buttigiegp': 3.6,
#      'gabbardt': 0,
#      'klobuchara': 1.2,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.68,
#      'steyert': 0.36,
#      'warrene': 0.84,
#      'yanga': 0.12},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.24,
#      'bloombergm': 0,
#      'buttigiegp': 0.6,
#      'gabbardt': 0,
#      'klobuchara': 0.12,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.24,
#      'steyert': 0,
#      'warrene': 0.12,
#      'yanga': 0}},
#    {'fips': '19067',
#     'name': 'Floyd',
#     'votes': 9.11,
#     'precincts': 8,
#     'votes_align1': 557,
#     'votes_alignfinal': 553,
#     'reporting': 7,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1.8888,
#      'bloombergm': 0,
#      'buttigiegp': 2.222,
#      'gabbardt': 0,
#      'klobuchara': 2.1109,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.5554,
#      'steyert': 0,
#      'warrene': 1.3332,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19069',
#     'name': 'Franklin',
#     'votes': 4.78,
#     'precincts': 12,
#     'votes_align1': 245,
#     'votes_alignfinal': 243,
#     'reporting': 11,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.9445,
#      'bloombergm': 0,
#      'buttigiegp': 1.2778,
#      'gabbardt': 0,
#      'klobuchara': 0.7223,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.2779,
#      'steyert': 0.1111,
#      'warrene': 0.3889,
#      'yanga': 0.0556},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.0556,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19071',
#     'name': 'Fremont',
#     'votes': 2.49,
#     'precincts': 5,
#     'votes_align1': 161,
#     'votes_alignfinal': 161,
#     'reporting': 4,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.525,
#      'bloombergm': 0,
#      'buttigiegp': 0.675,
#      'gabbardt': 0,
#      'klobuchara': 0.6,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.6,
#      'steyert': 0,
#      'warrene': 0.075,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0.15,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19073',
#     'name': 'Greene',
#     'votes': 6,
#     'precincts': 7,
#     'votes_align1': 362,
#     'votes_alignfinal': 358,
#     'reporting': 7,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.72,
#      'bloombergm': 0,
#      'buttigiegp': 2.04,
#      'gabbardt': 0,
#      'klobuchara': 1.2,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.8,
#      'steyert': 0.12,
#      'warrene': 0.12,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19075',
#     'name': 'Grundy',
#     'votes': 3.2,
#     'precincts': 7,
#     'votes_align1': 185,
#     'votes_alignfinal': 179,
#     'reporting': 5,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.7,
#      'bloombergm': 0,
#      'buttigiegp': 1,
#      'gabbardt': 0,
#      'klobuchara': 0.6,
# ...
#      'patrickd': 0,
#      'sandersb': 0.2588,
#      'steyert': 0,
#      'warrene': 0.1294,
#      'yanga': 0}},
#    {'fips': '19173',
#     'name': 'Taylor',
#     'votes': 3,
#     'precincts': 7,
#     'votes_align1': 97,
#     'votes_alignfinal': 96,
#     'reporting': 7,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.6,
#      'bloombergm': 0,
#      'buttigiegp': 0.9,
#      'gabbardt': 0,
#      'klobuchara': 0.4,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.5,
#      'steyert': 0,
#      'warrene': 0.4,
#      'yanga': 0.2},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19175',
#     'name': 'Union',
#     'votes': 5.87,
#     'precincts': 8,
#     'votes_align1': 337,
#     'votes_alignfinal': 328,
#     'reporting': 7,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.675,
#      'bloombergm': 0,
#      'buttigiegp': 1.575,
#      'gabbardt': 0,
#      'klobuchara': 0.75,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.875,
#      'steyert': 0,
#      'warrene': 0.825,
#      'yanga': 0.15},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19177',
#     'name': 'Van Buren',
#     'votes': 0.8,
#     'precincts': 8,
#     'votes_align1': 35,
#     'votes_alignfinal': 33,
#     'reporting': 3,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.2,
#      'bloombergm': 0,
#      'buttigiegp': 0.2,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.2,
#      'steyert': 0,
#      'warrene': 0.2,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.2,
#      'bloombergm': 0,
#      'buttigiegp': 0.6,
#      'gabbardt': 0,
#      'klobuchara': 0.1,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.4,
#      'steyert': 0,
#      'warrene': 0.2,
#      'yanga': 0}},
#    {'fips': '19179',
#     'name': 'Wapello',
#     'votes': 15.48,
#     'precincts': 22,
#     'votes_align1': 940,
#     'votes_alignfinal': 931,
#     'reporting': 17,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 3.51,
#      'bloombergm': 0,
#      'buttigiegp': 4.77,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 4.68,
#      'steyert': 0.09,
#      'warrene': 2.16,
#      'yanga': 0.27},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.36,
#      'bloombergm': 0,
#      'buttigiegp': 0.63,
#      'gabbardt': 0,
#      'klobuchara': 0.09,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.45,
#      'steyert': 0,
#      'warrene': 0.18,
#      'yanga': 0}},
#    {'fips': '19181',
#     'name': 'Warren',
#     'votes': 31.97,
#     'precincts': 31,
#     'votes_align1': 2653,
#     'votes_alignfinal': 2642,
#     'reporting': 26,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 3.9664,
#      'bloombergm': 0,
#      'buttigiegp': 11.1998,
#      'gabbardt': 0,
#      'klobuchara': 4.4332,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 5.5999,
#      'steyert': 0,
#      'warrene': 6.7667,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.2333,
#      'bloombergm': 0,
#      'buttigiegp': 0.7,
#      'gabbardt': 0,
#      'klobuchara': 0.2333,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.35,
#      'steyert': 0,
#      'warrene': 0.2333,
#      'yanga': 0}},
#    {'fips': '19183',
#     'name': 'Washington',
#     'votes': 8.73,
#     'precincts': 10,
#     'votes_align1': 696,
#     'votes_alignfinal': 690,
#     'reporting': 7,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.9285,
#      'bloombergm': 0,
#      'buttigiegp': 1.6713,
#      'gabbardt': 0,
#      'klobuchara': 1.6713,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 2.5998,
#      'steyert': 0,
#      'warrene': 1.857,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.3714,
#      'bloombergm': 0,
#      'buttigiegp': 1.1143,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.9286,
#      'steyert': 0,
#      'warrene': 0.5571,
#      'yanga': 0}},
#    {'fips': '19185',
#     'name': 'Wayne',
#     'votes': 3.02,
#     'precincts': 4,
#     'votes_align1': 135,
#     'votes_alignfinal': 135,
#     'reporting': 4,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.375,
#      'bloombergm': 0,
#      'buttigiegp': 0.525,
#      'gabbardt': 0,
#      'klobuchara': 0.975,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.525,
#      'steyert': 0,
#      'warrene': 0.6,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19187',
#     'name': 'Webster',
#     'votes': 18.84,
#     'precincts': 28,
#     'votes_align1': 1103,
#     'votes_alignfinal': 1132,
#     'reporting': 25,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 4.4166,
#      'bloombergm': 0,
#      'buttigiegp': 7.5834,
#      'gabbardt': 0,
#      'klobuchara': 1.2501,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 3.9165,
#      'steyert': 0.1667,
#      'warrene': 1.4999,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0.3333,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.1667,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19189',
#     'name': 'Winnebago',
#     'votes': 4.95,
#     'precincts': 10,
#     'votes_align1': 325,
#     'votes_alignfinal': 324,
#     'reporting': 8,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.45,
#      'bloombergm': 0,
#      'buttigiegp': 1.8,
#      'gabbardt': 0,
#      'klobuchara': 0.75,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.6,
#      'steyert': 0,
#      'warrene': 0.9,
#      'yanga': 0.45},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0.3,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.15,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19191',
#     'name': 'Winneshiek',
#     'votes': 13.44,
#     'precincts': 11,
#     'votes_align1': 1590,
#     'votes_alignfinal': 1565,
#     'reporting': 8,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.384,
#      'bloombergm': 0,
#      'buttigiegp': 3.968,
#      'gabbardt': 0,
#      'klobuchara': 3.456,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 2.944,
#      'steyert': 0,
#      'warrene': 2.176,
#      'yanga': 0.512},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0.128,
#      'bloombergm': 0,
#      'buttigiegp': 0.512,
#      'gabbardt': 0,
#      'klobuchara': 0.128,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.128,
#      'steyert': 0,
#      'warrene': 0.128,
#      'yanga': 0}},
#    {'fips': '19193',
#     'name': 'Woodbury',
#     'votes': 37.84,
#     'precincts': 44,
#     'votes_align1': 2330,
#     'votes_alignfinal': 2270,
#     'reporting': 32,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 8.925,
#      'bloombergm': 0,
#      'buttigiegp': 8.075,
#      'gabbardt': 0,
#      'klobuchara': 1.7,
#      'other': 0.2125,
#      'patrickd': 0,
#      'sandersb': 12.325,
#      'steyert': 0,
#      'warrene': 5.95,
#      'yanga': 0.6375},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 1.4875,
#      'bloombergm': 0,
#      'buttigiegp': 3.1875,
#      'gabbardt': 0,
#      'klobuchara': 1.275,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 3.6125,
#      'steyert': 0,
#      'warrene': 2.3375,
#      'yanga': 0}},
#    {'fips': '19195',
#     'name': 'Worth',
#     'votes': 4.4,
#     'precincts': 7,
#     'votes_align1': 256,
#     'votes_alignfinal': 256,
#     'reporting': 6,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0.6,
#      'bloombergm': 0,
#      'buttigiegp': 0.8666,
#      'gabbardt': 0,
#      'klobuchara': 1.2,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0.7333,
#      'steyert': 0,
#      'warrene': 0.6001,
#      'yanga': 0.4},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': '19197',
#     'name': 'Wright',
#     'votes': 5.61,
#     'precincts': 10,
#     'votes_align1': 312,
#     'votes_alignfinal': 312,
#     'reporting': 9,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 1.0665,
#      'bloombergm': 0.1333,
#      'buttigiegp': 2,
#      'gabbardt': 0,
#      'klobuchara': 1.0666,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 1.0666,
#      'steyert': 0,
#      'warrene': 0.2666,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0}},
#    {'fips': 'SAT',
#     'reporting': 0,
#     'vote_counted': {'bennetm': 0,
#      'bidenj': 0,
#      'bloombergm': 0,
#      'buttigiegp': 0,
#      'gabbardt': 0,
#      'klobuchara': 0,
#      'other': 0,
#      'patrickd': 0,
#      'sandersb': 0,
#      'steyert': 0,
#      'warrene': 0,
#      'yanga': 0},
#     'vote_remaining': {'bennetm': 0,
#      'bidenj': 5.2354,
#      'bloombergm': 0.0497,
#      'buttigiegp': 9.1903,
#      'gabbardt': 0.125,
#      'klobuchara': 4.2771,
#      'other': 0.1442,
#      'patrickd': 0,
#      'sandersb': 8.9232,
#      'steyert': 0.2038,
#      'warrene': 7.0189,
#      'yanga': 0.3177}}],
#   'timeseries': [{'vote_counted': 1347.2652,
#     'vote_estimate': 2143.4276,
#     'vote_remaining': 796.1624,
#     'bennetm_align1_wp': 0,
#     'bennetm_alignfinal_wp': 0,
#     'bennetm_delegates_wp': 0,
#     'bennetm_wp': 0,
#     'bidenj_align1_wp': 0,
#     'bidenj_alignfinal_wp': 0,
#     'bidenj_delegates_wp': 0,
#     'bidenj_wp': 0,
#     'bloombergm_align1_wp': 0,
#     'bloombergm_alignfinal_wp': 0,
#     'bloombergm_delegates_wp': 0,
#     'bloombergm_wp': 0,
#     'buttigiegp_align1_wp': 0.1238,
#     'buttigiegp_alignfinal_wp': 0.3838,
#     'buttigiegp_delegates_wp': 0.5337,
#     'buttigiegp_wp': 0.735,
#     'gabbardt_align1_wp': 0,
#     'gabbardt_alignfinal_wp': 0,
#     'gabbardt_delegates_wp': 0,
#     'gabbardt_wp': 0,
#     'klobuchara_align1_wp': 0,
#     'klobuchara_alignfinal_wp': 0,
#     'klobuchara_delegates_wp': 0,
#     'klobuchara_wp': 0,
#     'other_align1_wp': 0,
#     'other_alignfinal_wp': 0,
#     'other_delegates_wp': 0,
#     'other_wp': 0,
#     'patrickd_align1_wp': 0,
#     'patrickd_alignfinal_wp': 0,
#     'patrickd_delegates_wp': 0,
#     'patrickd_wp': 0,
#     'sandersb_align1_wp': 0.8738,
#     'sandersb_alignfinal_wp': 0.6125,
#     'sandersb_delegates_wp': 0.4662,
#     'sandersb_wp': 0.265,
#     'steyert_align1_wp': 0,
#     'steyert_alignfinal_wp': 0,
#     'steyert_delegates_wp': 0,
#     'steyert_wp': 0,
#     'warrene_align1_wp': 0.0025,
#     'warrene_alignfinal_wp': 0.0038,
#     'warrene_delegates_wp': 0,
#     'warrene_wp': 0,
#     'yanga_align1_wp': 0,
#     'yanga_alignfinal_wp': 0,
#     'yanga_delegates_wp': 0,
#     'yanga_wp': 0,
#     'timestamp': '2020-02-05T00:56:41.087Z'},
#    {'vote_counted': 1561.821,
#     'vote_estimate': 2143.6662,
#     'vote_remaining': 581.8452,
#     'bennetm_align1_wp': 0,
#     'bennetm_alignfinal_wp': 0,
#     'bennetm_delegates_wp': 0,
#     'bennetm_wp': 0,
#     'bidenj_align1_wp': 0,
#     'bidenj_alignfinal_wp': 0,
#     'bidenj_delegates_wp': 0,
#     'bidenj_wp': 0,
#     'bloombergm_align1_wp': 0,
#     'bloombergm_alignfinal_wp': 0,
#     'bloombergm_delegates_wp': 0,
#     'bloombergm_wp': 0,
#     'buttigiegp_align1_wp': 0.0612,
#     'buttigiegp_alignfinal_wp': 0.3638,
#     'buttigiegp_delegates_wp': 0.575,
#     'buttigiegp_wp': 0.805,
#     'gabbardt_align1_wp': 0,
#     'gabbardt_alignfinal_wp': 0,
#     'gabbardt_delegates_wp': 0,
#     'gabbardt_wp': 0,
#     'klobuchara_align1_wp': 0,
#     'klobuchara_alignfinal_wp': 0,
#     'klobuchara_delegates_wp': 0,
#     'klobuchara_wp': 0,
#     'other_align1_wp': 0,
#     'other_alignfinal_wp': 0,
#     'other_delegates_wp': 0,
#     'other_wp': 0,
#     'patrickd_align1_wp': 0,
#     'patrickd_alignfinal_wp': 0,
#     'patrickd_delegates_wp': 0,
#     'patrickd_wp': 0,
#     'sandersb_align1_wp': 0.9375,
#     'sandersb_alignfinal_wp': 0.6362,
#     'sandersb_delegates_wp': 0.425,
#     'sandersb_wp': 0.195,
#     'steyert_align1_wp': 0,
#     'steyert_alignfinal_wp': 0,
#     'steyert_delegates_wp': 0,
#     'steyert_wp': 0,
#     'warrene_align1_wp': 0.0012,
#     'warrene_alignfinal_wp': 0,
#     'warrene_delegates_wp': 0,
#     'warrene_wp': 0,
#     'yanga_align1_wp': 0,
#     'yanga_alignfinal_wp': 0,
#     'yanga_delegates_wp': 0,
#     'yanga_wp': 0,
#     'timestamp': '2020-02-05T04:53:31.493Z'},
#    {'vote_counted': 1561.821,
#     'vote_estimate': 2143.6662,
#     'vote_remaining': 581.8452,
#     'bennetm_align1_wp': 0,
#     'bennetm_alignfinal_wp': 0,
#     'bennetm_delegates_wp': 0,
#     'bennetm_wp': 0,
#     'bidenj_align1_wp': 0,
#     'bidenj_alignfinal_wp': 0,
#     'bidenj_delegates_wp': 0,
#     'bidenj_wp': 0,
#     'bloombergm_align1_wp': 0,
#     'bloombergm_alignfinal_wp': 0,
#     'bloombergm_delegates_wp': 0,
#     'bloombergm_wp': 0,
#     'buttigiegp_align1_wp': 0.0612,
#     'buttigiegp_alignfinal_wp': 0.3638,
#     'buttigiegp_delegates_wp': 0.7113,
#     'buttigiegp_wp': 0.805,
#     'gabbardt_align1_wp': 0,
#     'gabbardt_alignfinal_wp': 0,
#     'gabbardt_delegates_wp': 0,
#     'gabbardt_wp': 0,
#     'klobuchara_align1_wp': 0,
#     'klobuchara_alignfinal_wp': 0,
#     'klobuchara_delegates_wp': 0,
#     'klobuchara_wp': 0,
#     'other_align1_wp': 0,
#     'other_alignfinal_wp': 0,
#     'other_delegates_wp': 0,
#     'other_wp': 0,
#     'patrickd_align1_wp': 0,
#     'patrickd_alignfinal_wp': 0,
#     'patrickd_delegates_wp': 0,
#     'patrickd_wp': 0,
#     'sandersb_align1_wp': 0.9375,
#     'sandersb_alignfinal_wp': 0.6362,
#     'sandersb_delegates_wp': 0.2888,
#     'sandersb_wp': 0.195,
#     'steyert_align1_wp': 0,
#     'steyert_alignfinal_wp': 0,
#     'steyert_delegates_wp': 0,
#     'steyert_wp': 0,
#     'warrene_align1_wp': 0.0012,
#     'warrene_alignfinal_wp': 0,
#     'warrene_delegates_wp': 0,
#     'warrene_wp': 0,
#     'yanga_align1_wp': 0,
#     'yanga_alignfinal_wp': 0,
#     'yanga_delegates_wp': 0,
#     'yanga_wp': 0,
#     'timestamp': '2020-02-05T17:36:17.198Z'},
#    {'vote_counted': 1644.1919,
#     'vote_estimate': 2143.7587,
#     'vote_remaining': 499.5668,
#     'bennetm_align1_wp': 0,
#     'bennetm_alignfinal_wp': 0,
#     'bennetm_delegates_wp': 0,
#     'bennetm_wp': 0,
#     'bidenj_align1_wp': 0,
#     'bidenj_alignfinal_wp': 0,
#     'bidenj_delegates_wp': 0,
#     'bidenj_wp': 0,
#     'bloombergm_align1_wp': 0,
#     'bloombergm_alignfinal_wp': 0,
#     'bloombergm_delegates_wp': 0,
#     'bloombergm_wp': 0,
#     'buttigiegp_align1_wp': 0.055,
#     'buttigiegp_alignfinal_wp': 0.4038,
#     'buttigiegp_delegates_wp': 0.76,
#     'buttigiegp_wp': 0.8638,
#     'gabbardt_align1_wp': 0,
#     'gabbardt_alignfinal_wp': 0,
#     'gabbardt_delegates_wp': 0,
#     'gabbardt_wp': 0,
#     'klobuchara_align1_wp': 0,
#     'klobuchara_alignfinal_wp': 0,
#     'klobuchara_delegates_wp': 0,
#     'klobuchara_wp': 0,
#     'other_align1_wp': 0,
#     'other_alignfinal_wp': 0,
#     'other_delegates_wp': 0,
#     'other_wp': 0,
#     'patrickd_align1_wp': 0,
#     'patrickd_alignfinal_wp': 0,
#     'patrickd_delegates_wp': 0,
#     'patrickd_wp': 0,
#     'sandersb_align1_wp': 0.945,
#     'sandersb_alignfinal_wp': 0.595,
#     'sandersb_delegates_wp': 0.24,
#     'sandersb_wp': 0.1362,
#     'steyert_align1_wp': 0,
#     'steyert_alignfinal_wp': 0,
#     'steyert_delegates_wp': 0,
#     'steyert_wp': 0,
#     'warrene_align1_wp': 0,
#     'warrene_alignfinal_wp': 0.0012,
#     'warrene_delegates_wp': 0,
#     'warrene_wp': 0,
#     'yanga_align1_wp': 0,
#     'yanga_alignfinal_wp': 0,
#     'yanga_delegates_wp': 0,
#     'yanga_wp': 0,
#     'timestamp': '2020-02-05T19:27:57.538Z'}]}]

# %%
len(data['races'])
# Out:
# 1

# %%
type(data['races'][0])
# Out:
# dict

# %%
sorted(data['races'][0].keys())
# Out:
# ['bennetm_align1_quantile',
#  'bennetm_align1_voteshare',
#  'bennetm_align1_wp',
#  'bennetm_alignfinal_quantile',
#  'bennetm_alignfinal_voteshare',
#  'bennetm_alignfinal_wp',
#  'bennetm_delegates_quantile',
#  'bennetm_delegates_voteshare',
#  'bennetm_delegates_wp',
#  'bennetm_quantile',
#  'bennetm_vote_counted',
#  'bennetm_vote_estimate',
#  'bennetm_vote_remaining',
#  'bennetm_voteshare',
#  'bennetm_wp',
#  'bidenj_align1_quantile',
#  'bidenj_align1_voteshare',
#  'bidenj_align1_wp',
#  'bidenj_alignfinal_quantile',
#  'bidenj_alignfinal_voteshare',
#  'bidenj_alignfinal_wp',
#  'bidenj_delegates_quantile',
#  'bidenj_delegates_voteshare',
#  'bidenj_delegates_wp',
#  'bidenj_quantile',
#  'bidenj_vote_counted',
#  'bidenj_vote_estimate',
#  'bidenj_vote_remaining',
#  'bidenj_voteshare',
#  'bidenj_wp',
#  'bloombergm_align1_quantile',
#  'bloombergm_align1_voteshare',
#  'bloombergm_align1_wp',
#  'bloombergm_alignfinal_quantile',
#  'bloombergm_alignfinal_voteshare',
#  'bloombergm_alignfinal_wp',
#  'bloombergm_delegates_quantile',
#  'bloombergm_delegates_voteshare',
#  'bloombergm_delegates_wp',
#  'bloombergm_quantile',
#  'bloombergm_vote_counted',
#  'bloombergm_vote_estimate',
#  'bloombergm_vote_remaining',
#  'bloombergm_voteshare',
#  'bloombergm_wp',
#  'buttigiegp_align1_quantile',
#  'buttigiegp_align1_voteshare',
#  'buttigiegp_align1_wp',
#  'buttigiegp_alignfinal_quantile',
#  'buttigiegp_alignfinal_voteshare',
#  'buttigiegp_alignfinal_wp',
#  'buttigiegp_delegates_quantile',
#  'buttigiegp_delegates_voteshare',
#  'buttigiegp_delegates_wp',
#  'buttigiegp_quantile',
#  'buttigiegp_vote_counted',
#  'buttigiegp_vote_estimate',
#  'buttigiegp_vote_remaining',
#  'buttigiegp_voteshare',
#  'buttigiegp_wp',
#  'candidates',
#  'counties',
#  'delegates',
#  'delegates_allocated',
#  'eevp',
#  'election_date',
#  'election_type',
#  'electoral_votes',
#  'gabbardt_align1_quantile',
#  'gabbardt_align1_voteshare',
#  'gabbardt_align1_wp',
#  'gabbardt_alignfinal_quantile',
#  'gabbardt_alignfinal_voteshare',
#  'gabbardt_alignfinal_wp',
#  'gabbardt_delegates_quantile',
#  'gabbardt_delegates_voteshare',
#  'gabbardt_delegates_wp',
#  'gabbardt_quantile',
#  'gabbardt_vote_counted',
#  'gabbardt_vote_estimate',
#  'gabbardt_vote_remaining',
#  'gabbardt_voteshare',
#  'gabbardt_wp',
#  'gain',
#  'has_incumbent',
#  'incumbent_party',
#  'klobuchara_align1_quantile',
#  'klobuchara_align1_voteshare',
#  'klobuchara_align1_wp',
#  'klobuchara_alignfinal_quantile',
#  'klobuchara_alignfinal_voteshare',
#  'klobuchara_alignfinal_wp',
#  'klobuchara_delegates_quantile',
#  'klobuchara_delegates_voteshare',
#  'klobuchara_delegates_wp',
#  'klobuchara_quantile',
#  'klobuchara_vote_counted',
#  'klobuchara_vote_estimate',
#  'klobuchara_vote_remaining',
#  'klobuchara_voteshare',
#  'klobuchara_wp',
#  'leader',
#  'leader_align1',
#  'leader_alignfinal',
#  'leader_delegates',
#  'lost_seat',
#  'margin',
#  'margin_align1',
#  'margin_alignfinal',
#  'margin_delegates',
#  'no_forecast',
#  'nyt_measure_title',
#  'nyt_title',
#  'office',
#  'officeid',
#  'other_align1_quantile',
#  'other_align1_voteshare',
#  'other_align1_wp',
#  'other_alignfinal_quantile',
#  'other_alignfinal_voteshare',
#  'other_alignfinal_wp',
#  'other_delegates_quantile',
#  'other_delegates_voteshare',
#  'other_delegates_wp',
#  'other_quantile',
#  'other_vote_counted',
#  'other_vote_estimate',
#  'other_vote_remaining',
#  'other_voteshare',
#  'other_wp',
#  'party_id',
#  'patrickd_align1_quantile',
#  'patrickd_align1_voteshare',
#  'patrickd_align1_wp',
#  'patrickd_alignfinal_quantile',
#  'patrickd_alignfinal_voteshare',
#  'patrickd_alignfinal_wp',
#  'patrickd_delegates_quantile',
#  'patrickd_delegates_voteshare',
#  'patrickd_delegates_wp',
#  'patrickd_quantile',
#  'patrickd_vote_counted',
#  'patrickd_vote_estimate',
#  'patrickd_vote_remaining',
#  'patrickd_voteshare',
#  'patrickd_wp',
#  'poll_countdown_display',
#  'poll_display',
#  'poll_time',
#  'precinct_map_bounds',
#  'precinct_tileset',
#  'precincts_reporting',
#  'precincts_total',
#  'race_call_note',
#  'race_id',
#  'race_name',
#  'race_slug',
#  'race_text',
#  'race_type',
#  'report',
#  'reporting_display',
#  'result',
#  'runoff',
#  'runoff_eligible',
#  'sandersb_align1_quantile',
#  'sandersb_align1_voteshare',
#  'sandersb_align1_wp',
#  'sandersb_alignfinal_quantile',
#  'sandersb_alignfinal_voteshare',
#  'sandersb_alignfinal_wp',
#  'sandersb_delegates_quantile',
#  'sandersb_delegates_voteshare',
#  'sandersb_delegates_wp',
#  'sandersb_quantile',
#  'sandersb_vote_counted',
#  'sandersb_vote_estimate',
#  'sandersb_vote_remaining',
#  'sandersb_voteshare',
#  'sandersb_wp',
#  'seat',
#  'seat_name',
#  'show_precinct_filters',
#  'state_id',
#  'state_name',
#  'state_nyt_abbrev',
#  'state_slug',
#  'steyert_align1_quantile',
#  'steyert_align1_voteshare',
#  'steyert_align1_wp',
#  'steyert_alignfinal_quantile',
#  'steyert_alignfinal_voteshare',
#  'steyert_alignfinal_wp',
#  'steyert_delegates_quantile',
#  'steyert_delegates_voteshare',
#  'steyert_delegates_wp',
#  'steyert_quantile',
#  'steyert_vote_counted',
#  'steyert_vote_estimate',
#  'steyert_vote_remaining',
#  'steyert_voteshare',
#  'steyert_wp',
#  'timeseries',
#  'timestamp_api',
#  'uncontested',
#  'url',
#  'vote_align1_counted',
#  'vote_align1_estimate',
#  'vote_align1_remaining',
#  'vote_alignfinal_counted',
#  'vote_alignfinal_estimate',
#  'vote_alignfinal_remaining',
#  'vote_counted',
#  'vote_estimate',
#  'vote_remaining',
#  'votes',
#  'votetype',
#  'warrene_align1_quantile',
#  'warrene_align1_voteshare',
#  'warrene_align1_wp',
#  'warrene_alignfinal_quantile',
#  'warrene_alignfinal_voteshare',
#  'warrene_alignfinal_wp',
#  'warrene_delegates_quantile',
#  'warrene_delegates_voteshare',
#  'warrene_delegates_wp',
#  'warrene_quantile',
#  'warrene_vote_counted',
#  'warrene_vote_estimate',
#  'warrene_vote_remaining',
#  'warrene_voteshare',
#  'warrene_wp',
#  'yanga_align1_quantile',
#  'yanga_align1_voteshare',
#  'yanga_align1_wp',
#  'yanga_alignfinal_quantile',
#  'yanga_alignfinal_voteshare',
#  'yanga_alignfinal_wp',
#  'yanga_delegates_quantile',
#  'yanga_delegates_voteshare',
#  'yanga_delegates_wp',
#  'yanga_quantile',
#  'yanga_vote_counted',
#  'yanga_vote_estimate',
#  'yanga_vote_remaining',
#  'yanga_voteshare',
#  'yanga_wp']

# %%
data['races'][0]['counties'][17]
# Out:
# {'fips': '19035',
#  'name': 'Cherokee',
#  'votes': 2.52,
#  'precincts': 7,
#  'votes_align1': 125,
#  'votes_alignfinal': 122,
#  'reporting': 3,
#  'vote_counted': {'bennetm': 0,
#   'bidenj': 0.7637,
#   'bloombergm': 0,
#   'buttigiegp': 0.4364,
#   'gabbardt': 0,
#   'klobuchara': 0.2182,
#   'other': 0,
#   'patrickd': 0,
#   'sandersb': 0.5455,
#   'steyert': 0.1091,
#   'warrene': 0.2182,
#   'yanga': 0.2182},
#  'vote_remaining': {'bennetm': 0,
#   'bidenj': 0.3273,
#   'bloombergm': 0,
#   'buttigiegp': 0.9818,
#   'gabbardt': 0,
#   'klobuchara': 0.3273,
#   'other': 0,
#   'patrickd': 0,
#   'sandersb': 0.7636,
#   'steyert': 0,
#   'warrene': 0.3273,
#   'yanga': 0}}
